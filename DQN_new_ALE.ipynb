# %% [markdown]
# ## DQN (Deep Q-Network)
# ### Function approximation Q-learning
# This tutorial walks through the implementation of deep Q networks (DQNs),
# an RL method which applies the function approximation capabilities of deep neural networks
# to problems in reinforcement learning.
# The model in this tutorial closely follows the work described in the paper
# [Human-level control through deep reinforcement learning](http://www.nature.com/nature/journal/v518/n7540/full/nature14236.html?foxtrotcallback=true), written by Volodomyr Mnih.
#
# To keep these chapters runnable
# by as many people as possible,
# on as many machines as possible,
# and with as few headaches as possible,
# we have so far avoided dependencies on external libraries
# (besides mxnet, numpy and matplotlib).
# However, in this case, we'll need to import the [OpenAI Gym](https://gym.openai.com/docs).
# That's because in reinforcement learning,
# instead of drawing examples from a data structure,
# our data comes from interactions with an environment.
# In this chapter, our environemnts will be classic Atari video games.
#
# ## Preliminaries
# The following code clones and installs the OpenAI gym.
# `git clone https://github.com/openai/gym ; cd gym ; pip install -e .[all]`
# Full documentation for the gym can be found on [at this website](https://gym.openai.com/).
# If you want to see reasonable results before the sun sets on your AI career,
# we suggest running these experiments on a server equipped with GPUs.

# %%
import mxnet as mx
from mxnet import nd, autograd
from mxnet import gluon
from __future__ import print_function
import os
import random
import numpy as np
import matplotlib.pyplot as plt
from IPython import display
import gym
import math
from collections import namedtuple
from ale_python_interface import ALEInterface
import time
f = open('results.txt','w')

# %% [markdown]
# ### Summary of the algorithm
# #### Collect samples
# At the beginning of each episode (one round of the game),
# reset the environment to its initial state using `env.reset()`.
# At each time step ``t``, the environment is at `current_state`.
# With probability $\epsilon$, apply a random action.
# Otherwise, apply $argmax_a~ Q(\phi($ `current_state` $),a,\theta)$,
# where $Q$ is parameterized by paramters $\theta$ and $\phi(\cdot)$ is preprocessor.
# Pass the action through `env.step(action)` to receive next frame, reward and whether the game terminates.
# Append this frame to the end of the `current_state` and construct `next_state` while removeing $frame(t-12)$.
# Store the tuple $(\phi($ `current_state` $), action, reward, \phi($ `next_ state` $))$ in the replay buffer.
#
# #### Update Network
# * Draw batches of tuples from the replay buffer: $(\phi,r,a,\phi')$.
# * Define the following loss
# $$\Large(\small Q(\phi,a,\theta)-r-max_{a'}Q(\phi',a',\theta^-)\Large)^2$$
# * Where $\theta^-$ is the parameter of the target network.( Set $Q(\phi',a',\theta^-)$ to zero if $\phi$ is the preprocessed termination state).
# * Update the $\theta$
# * Update the $\theta^-$ once in a while

# %% [markdown]
# ## Set the hyper-parameters

# %%
class Options:
    def __init__(self):
        #Articheture
        self.batch_size = 32 # The size of the batch to learn the Q-function
        self.image_size = 80 # Resize the raw input frame to square frame of size 80 by 80 
        #Trickes
        self.replay_buffer_size = 1000000 # The size of replay buffer; set it to size of your memory (.5M for 50G available memory)
        self.learning_frequency = 4 # With Freq of 1/4 step update the Q-network
        self.skip_frame = 4 # Skip 4-1 raw frames between steps
        self.internal_skip_frame = 4 # Skip 4-1 raw frames between skipped frames
        self.frame_len = 4 # Each state is formed as a concatination 4 step frames [f(t-12),f(t-8),f(t-4),f(t)]
        self.Target_update = 10000 # Update the target network each 10000 steps
        self.epsilon_min = 0.1 # Minimum level of stochasticity of policy (epsilon)-greedy
        self.annealing_end = 1000000. # The number of step it take to linearly anneal the epsilon to it min value
        self.gamma = 0.99 # The discount factor
        self.replay_start_size = 50000 # Start to backpropagated through the network, learning starts
        self.no_op_max = 30 / self.skip_frame # Run uniform policy for first 30 times step of the beginning of the game
        
        #otimization
        self.num_episode = 10000 # Number episode to run the algorithm
        self.lr = 0.00025 # RMSprop learning rate
        self.gamma1 = 0.95 # RMSprop gamma1
        self.gamma2 = 0.95 # RMSprop gamma2
        self.rms_eps = 0.01 # RMSprop epsilon bias
        self.ctx = mx.gpu() # Enables gpu if available, if not, set it to mx.cpu()
opt = Options()

env_name = 'AssaultNoFrameskip-v4' # Set the desired environment
env = gym.make(env_name)
num_action = env.action_space.n # Extract the number of available action from the environment setting

manualSeed = 1 # random.randint(1, 10000) # Set the desired seed to reproduce the results
mx.random.seed(manualSeed)
attrs = vars(opt)
print (', '.join("%s: %s" % item for item in attrs.items()))
# Out:
# replay_buffer_size: 1000000, annealing_end: 1000000.0, Target_update: 10000, gamma1: 0.95, frame_len: 4, internal_skip_frame: 4, ctx: gpu(0), skip_frame: 4, batch_size: 32, learning_frequency: 4, lr: 0.00025, num_episode: 10000, image_size: 80, epsilon_min: 0.1, replay_start_size: 50000, rms_eps: 0.01, no_op_max: 7, gamma: 0.99, gamma2: 0.95

# %%
ale = ALEInterface()
ale.setInt('random_seed', 1)
ale.loadROM('ROMS/space_invaders.bin')
num_action = len(ale.getLegalActionSet())

# %%
print(ale.getAvailableDifficulties())
ale.setDifficulty(0)
# Out:
# [0 1]

# %% [markdown]
# ### Define the DQN model
# The network is constructed as three CNN layers and a fully connected added on the top. Furthermore, the optimizer is assigned to the parameters.

# %%
DQN = gluon.nn.Sequential()
with DQN.name_scope():
    #first layer
    DQN.add(gluon.nn.Conv2D(channels=32, kernel_size=8,strides = 4,padding = 0))
    DQN.add(gluon.nn.BatchNorm(axis = 1, momentum = 0.1,center=True))
    DQN.add(gluon.nn.Activation('relu'))
    #second layer
    DQN.add(gluon.nn.Conv2D(channels=64, kernel_size=4,strides = 2))
    DQN.add(gluon.nn.BatchNorm(axis = 1, momentum = 0.1,center=True))
    DQN.add(gluon.nn.Activation('relu'))
    #tird layer
    DQN.add(gluon.nn.Conv2D(channels=64, kernel_size=3,strides = 1))
    DQN.add(gluon.nn.BatchNorm(axis = 1, momentum = 0.1,center=True))
    DQN.add(gluon.nn.Activation('relu'))
    DQN.add(gluon.nn.Flatten())
    #fourth layer
    DQN.add(gluon.nn.Dense(512,activation ='relu'))
    #fifth layer
    DQN.add(gluon.nn.Dense(num_action,activation ='relu'))

dqn = DQN
dqn.collect_params().initialize(mx.init.Normal(0.02), ctx=opt.ctx)
DQN_trainer = gluon.Trainer(dqn.collect_params(),'RMSProp', \
                          {'learning_rate': opt.lr ,'gamma1':opt.gamma1,'gamma2': opt.gamma2,'epsilon': opt.rms_eps,'centered' : True})
dqn.collect_params().zero_grad()

# %%
Target_DQN = gluon.nn.Sequential()
with Target_DQN.name_scope():
    #first layer
    Target_DQN.add(gluon.nn.Conv2D(channels=32, kernel_size=8,strides = 4,padding = 0))
    Target_DQN.add(gluon.nn.BatchNorm(axis = 1, momentum = 0.1,center=True))
    Target_DQN.add(gluon.nn.Activation('relu'))
    #second layer
    Target_DQN.add(gluon.nn.Conv2D(channels=64, kernel_size=4,strides = 2))
    Target_DQN.add(gluon.nn.BatchNorm(axis = 1, momentum = 0.1,center=True))
    Target_DQN.add(gluon.nn.Activation('relu'))
    #tird layer
    Target_DQN.add(gluon.nn.Conv2D(channels=64, kernel_size=3,strides = 1))
    Target_DQN.add(gluon.nn.BatchNorm(axis = 1, momentum = 0.1,center=True))
    Target_DQN.add(gluon.nn.Activation('relu'))
    Target_DQN.add(gluon.nn.Flatten())
    #fourth layer
    Target_DQN.add(gluon.nn.Dense(512,activation ='relu'))
    #fifth layer
    Target_DQN.add(gluon.nn.Dense(num_action,activation ='relu'))
target_dqn = Target_DQN
target_dqn.collect_params().initialize(mx.init.Normal(0.02), ctx=opt.ctx)

# %% [markdown]
# ### Replay buffer
# Replay buffer store the tuple of : `state`, action , `next_state`, reward , done.

# %%
Transition = namedtuple('Transition',('state', 'action', 'next_state', 'reward','done'))
class Replay_Buffer():
    def __init__(self, replay_buffer_size):
        self.replay_buffer_size = replay_buffer_size
        self.memory = []
        self.position = 0
    def push(self, *args):
        if len(self.memory) < self.replay_buffer_size:
            self.memory.append(None)
        self.memory[self.position] = Transition(*args)
        self.position = (self.position + 1) % self.replay_buffer_size
    def sample(self, batch_size):
        return random.sample(self.memory, batch_size)

# %% [markdown]
# ### Preprocess frames
# * Take a frame, average over the `RGB` filter and append it to the `state` to construct `next_state`
# * Clip the reward
# * Render the frames

# %%
def preprocess(raw_frame, currentState = None, initial_state = False):
    raw_frame = nd.array(raw_frame,mx.cpu())
    raw_frame = nd.reshape(nd.mean(raw_frame, axis = 2),shape = (raw_frame.shape[0],raw_frame.shape[1],1))
    raw_frame = mx.image.imresize(raw_frame,  opt.image_size, opt.image_size)
    raw_frame = nd.transpose(raw_frame, (2,0,1))
    raw_frame = raw_frame.astype('float32')/255.
    if initial_state == True:
        state = raw_frame
        for _ in range(opt.frame_len-1):
            state = nd.concat(state , raw_frame, dim = 0)
    else:
        state = mx.nd.concat(currentState[1:,:,:], raw_frame, dim = 0)
    return state

def rew_clipper(rew):
    if rew>0.:
        return 1.
    elif rew<0.:
        return -1.
    else:
        return 0

def renderimage(next_frame):
    if render_image:
        plt.imshow(next_frame);
        plt.show()
        display.clear_output(wait=True)
        time.sleep(.1)
        
l2loss = gluon.loss.L2Loss(batch_axis=0)

# %% [markdown]
# ### Initialize arrays

# %%
frame_counter = 0. # Counts the number of steps so far
annealing_count = 0. # Counts the number of annealing steps
epis_count = 0. # Counts the number episodes so far
replay_memory = Replay_Buffer(opt.replay_buffer_size) # Initialize the replay buffer
tot_clipped_reward = np.zeros(opt.num_episode) 
tot_reward = np.zeros(opt.num_episode)
moving_average_clipped = 0.
moving_average = 0.

# %% [markdown]
# ## Changes due to using ALE interface instead of Gym:
# * env.reset() replaced by ale.reset_game()
# * env.step() replaced by ale.act(). Now, we need to compute the new state (Gym code uses ale.getScreenRGB2 which is a slightly modified version of ale.getScreenRGB, which we use). We also need to check if the episode is done, using ale.game_over().

# %% [markdown]
# ### Train the model

# %%
render_image = False # Whether to render Frames and show the game
batch_state = nd.empty((opt.batch_size,opt.frame_len,opt.image_size,opt.image_size), opt.ctx)
batch_state_next = nd.empty((opt.batch_size,opt.frame_len,opt.image_size,opt.image_size), opt.ctx)
for i in range(opt.num_episode):
    cum_clipped_reward = 0
    cum_reward = 0
    ale.reset_game()
    next_frame = ale.getScreenRGB()
    # next_frame = env.reset()
    state = preprocess(next_frame, initial_state = True)
    t = 0.
    done = False
    
    while not done:
        previous_state = state
        # show the frame
        renderimage(next_frame)
        sample = random.random()
        if frame_counter > opt.replay_start_size:
            annealing_count += 1
        if frame_counter == opt.replay_start_size:
            print('annealing and learning are started ')
            
            
        
        eps = np.maximum(1.-annealing_count/opt.annealing_end,opt.epsilon_min)
        effective_eps = eps
        if t < opt.no_op_max:
            effective_eps = 1.
        
        # epsilon greedy policy
        if sample < effective_eps:
            action = random.randint(0, num_action - 1)
        else:
            data = nd.array(state.reshape([1,opt.frame_len,opt.image_size,opt.image_size]),opt.ctx)
            action = int(nd.argmax(dqn(data),axis=1).as_in_context(mx.cpu()).asscalar())
        
        # Skip frame
        rew = 0
        for skip in range(opt.skip_frame-1):
            reward = ale.act(action)
            next_frame = ale.getScreenRGB()
            done = ale.game_over()
            renderimage(next_frame)
            cum_clipped_reward += rew_clipper(reward)
            rew += reward
            for internal_skip in range(opt.internal_skip_frame-1):
                reward = ale.act(action)
                done = ale.game_over()
                cum_clipped_reward += rew_clipper(reward)
                rew += reward
        
        reward = ale.act(action)
        next_frame_new = ale.getScreenRGB()
        done = ale.game_over()        
        renderimage(next_frame)
        cum_clipped_reward += rew_clipper(reward)
        rew += reward
        cum_reward += rew
        
        # Reward clipping
        reward = rew_clipper(rew)
        next_frame = np.maximum(next_frame_new,next_frame)
        state = preprocess(next_frame, state)
        replay_memory.push((previous_state*255.).astype('uint8'),action,(state*255.).astype('uint8'),reward,done)
        # Train
        if frame_counter > opt.replay_start_size:        
            if frame_counter % opt.learning_frequency == 0:
                transitions = replay_memory.sample(opt.batch_size)
                batch = Transition(*zip(*transitions))
                for j in range(opt.batch_size):
                    batch_state[j] = nd.array(batch.state[j],opt.ctx).astype('float32')/255.
                    batch_state_next[j] = nd.array(batch.next_state[j],opt.ctx).astype('float32')/255.
                batch_reward = nd.array(batch.reward,opt.ctx)
                batch_action = nd.array(batch.action,opt.ctx).astype('uint8')
                batch_done = nd.array(batch.done,opt.ctx)
                with autograd.record():
                    Q_sp = nd.max(target_dqn(batch_state_next),axis = 1)
                    Q_sp = Q_sp*(nd.ones(opt.batch_size,ctx = opt.ctx)-batch_done)
                    Q_s_array = dqn(batch_state)
                    Q_s = nd.pick(Q_s_array,batch_action,1)
                    loss = nd.mean(l2loss(Q_s ,  (batch_reward + opt.gamma *Q_sp)))
                loss.backward()
                DQN_trainer.step(opt.batch_size)
                
        

        
        t += 1
        frame_counter += 1
        
        # Save the model and update Target model
        if frame_counter > opt.replay_start_size:
            if frame_counter % opt.Target_update == 0 :
                check_point = frame_counter / (opt.Target_update *100)
                fdqn = './target_%s_%d' % (env_name,int(check_point))
                dqn.save_params(fdqn)
                target_dqn.load_params(fdqn, opt.ctx)
        if done:
            if epis_count % 10. == 0. :
                results = 'epis[%d],eps[%f],durat[%d],fnum=%d, cum_cl_rew = %d, cum_rew = %d,tot_cl = %d , tot = %d'\
                  %(epis_count,eps,t+1,frame_counter,cum_clipped_reward,cum_reward,moving_average_clipped,moving_average)
                print(results)
                f.write('\n' + results)
    epis_count += 1
    tot_clipped_reward[int(epis_count)-1] = cum_clipped_reward
    tot_reward[int(epis_count)-1] = cum_reward
    if epis_count > 50.:
        moving_average_clipped = np.mean(tot_clipped_reward[int(epis_count)-1-50:int(epis_count)-1])
        moving_average = np.mean(tot_reward[int(epis_count)-1-50:int(epis_count)-1])
f.close()
from tempfile import TemporaryFile
outfile = TemporaryFile()
outfile_clip = TemporaryFile()
np.save(outfile, moving_average)
np.save(outfile_clip, moving_average_clipped)
# Out:
# epis[0],eps[1.000000],durat[200],fnum=199, cum_cl_rew = 18, cum_rew = 460,tot_cl = 0 , tot = 0
# epis[10],eps[1.000000],durat[120],fnum=1864, cum_cl_rew = 6, cum_rew = 50,tot_cl = 0 , tot = 0
# epis[20],eps[1.000000],durat[83],fnum=3228, cum_cl_rew = 5, cum_rew = 50,tot_cl = 0 , tot = 0
# epis[30],eps[1.000000],durat[113],fnum=4638, cum_cl_rew = 9, cum_rew = 125,tot_cl = 0 , tot = 0
# epis[40],eps[1.000000],durat[94],fnum=6179, cum_cl_rew = 4, cum_rew = 35,tot_cl = 0 , tot = 0
# epis[50],eps[1.000000],durat[158],fnum=7912, cum_cl_rew = 8, cum_rew = 120,tot_cl = 0 , tot = 0
# epis[60],eps[1.000000],durat[123],fnum=9493, cum_cl_rew = 8, cum_rew = 60,tot_cl = 8 , tot = 126
# epis[70],eps[1.000000],durat[141],fnum=11032, cum_cl_rew = 7, cum_rew = 80,tot_cl = 9 , tot = 131
# epis[80],eps[1.000000],durat[123],fnum=12725, cum_cl_rew = 8, cum_rew = 75,tot_cl = 9 , tot = 136
# epis[90],eps[1.000000],durat[123],fnum=14442, cum_cl_rew = 4, cum_rew = 30,tot_cl = 9 , tot = 128
# epis[100],eps[1.000000],durat[154],fnum=15938, cum_cl_rew = 8, cum_rew = 105,tot_cl = 9 , tot = 128
# epis[110],eps[1.000000],durat[183],fnum=17532, cum_cl_rew = 11, cum_rew = 140,tot_cl = 8 , tot = 117
# epis[120],eps[1.000000],durat[283],fnum=19293, cum_cl_rew = 11, cum_rew = 155,tot_cl = 9 , tot = 123
# epis[130],eps[1.000000],durat[199],fnum=20763, cum_cl_rew = 20, cum_rew = 465,tot_cl = 8 , tot = 120
# epis[140],eps[1.000000],durat[261],fnum=22386, cum_cl_rew = 15, cum_rew = 390,tot_cl = 9 , tot = 130
# epis[150],eps[1.000000],durat[106],fnum=24248, cum_cl_rew = 5, cum_rew = 55,tot_cl = 10 , tot = 163
# epis[160],eps[1.000000],durat[177],fnum=25771, cum_cl_rew = 8, cum_rew = 105,tot_cl = 10 , tot = 163
# epis[170],eps[1.000000],durat[162],fnum=27356, cum_cl_rew = 9, cum_rew = 105,tot_cl = 9 , tot = 158
# epis[180],eps[1.000000],durat[119],fnum=28791, cum_cl_rew = 7, cum_rew = 90,tot_cl = 10 , tot = 157
# epis[190],eps[1.000000],durat[123],fnum=30087, cum_cl_rew = 8, cum_rew = 130,tot_cl = 9 , tot = 143
# epis[200],eps[1.000000],durat[196],fnum=31530, cum_cl_rew = 8, cum_rew = 80,tot_cl = 8 , tot = 108
# epis[210],eps[1.000000],durat[177],fnum=33129, cum_cl_rew = 9, cum_rew = 275,tot_cl = 8 , tot = 107
# epis[220],eps[1.000000],durat[160],fnum=34669, cum_cl_rew = 11, cum_rew = 155,tot_cl = 8 , tot = 124
# epis[230],eps[1.000000],durat[180],fnum=36307, cum_cl_rew = 13, cum_rew = 185,tot_cl = 8 , tot = 129
# epis[240],eps[1.000000],durat[229],fnum=37939, cum_cl_rew = 13, cum_rew = 195,tot_cl = 9 , tot = 138
# epis[250],eps[1.000000],durat[168],fnum=39570, cum_cl_rew = 8, cum_rew = 85,tot_cl = 9 , tot = 155
# epis[260],eps[1.000000],durat[157],fnum=41158, cum_cl_rew = 11, cum_rew = 160,tot_cl = 9 , tot = 154
# epis[270],eps[1.000000],durat[117],fnum=42685, cum_cl_rew = 8, cum_rew = 105,tot_cl = 9 , tot = 140
# epis[280],eps[1.000000],durat[143],fnum=44012, cum_cl_rew = 7, cum_rew = 90,tot_cl = 9 , tot = 131
# epis[290],eps[1.000000],durat[149],fnum=45538, cum_cl_rew = 9, cum_rew = 110,tot_cl = 9 , tot = 128
# epis[300],eps[1.000000],durat[206],fnum=47619, cum_cl_rew = 11, cum_rew = 130,tot_cl = 9 , tot = 126
# epis[310],eps[1.000000],durat[120],fnum=49128, cum_cl_rew = 6, cum_rew = 65,tot_cl = 9 , tot = 130
# annealing and learning are started
# epis[320],eps[0.998965],durat[151],fnum=51036, cum_cl_rew = 13, cum_rew = 165,tot_cl = 9 , tot = 134
# epis[330],eps[0.997228],durat[189],fnum=52773, cum_cl_rew = 12, cum_rew = 165,tot_cl = 10 , tot = 150
# epis[340],eps[0.995704],durat[234],fnum=54297, cum_cl_rew = 16, cum_rew = 205,tot_cl = 10 , tot = 154
# epis[350],eps[0.994337],durat[139],fnum=55664, cum_cl_rew = 7, cum_rew = 90,tot_cl = 9 , tot = 144
# epis[360],eps[0.992957],durat[134],fnum=57044, cum_cl_rew = 8, cum_rew = 75,tot_cl = 9 , tot = 138
# epis[370],eps[0.991552],durat[135],fnum=58449, cum_cl_rew = 7, cum_rew = 95,tot_cl = 9 , tot = 130
# epis[380],eps[0.990051],durat[205],fnum=59950, cum_cl_rew = 18, cum_rew = 240,tot_cl = 8 , tot = 120
# epis[390],eps[0.988552],durat[82],fnum=61449, cum_cl_rew = 3, cum_rew = 40,tot_cl = 9 , tot = 132
# epis[400],eps[0.987062],durat[130],fnum=62939, cum_cl_rew = 6, cum_rew = 65,tot_cl = 9 , tot = 132
# epis[410],eps[0.985550],durat[123],fnum=64451, cum_cl_rew = 4, cum_rew = 25,tot_cl = 9 , tot = 134
# epis[420],eps[0.984017],durat[150],fnum=65984, cum_cl_rew = 8, cum_rew = 105,tot_cl = 9 , tot = 139
# epis[430],eps[0.982054],durat[229],fnum=67947, cum_cl_rew = 17, cum_rew = 235,tot_cl = 10 , tot = 149
# epis[440],eps[0.980576],durat[90],fnum=69425, cum_cl_rew = 3, cum_rew = 20,tot_cl = 9 , tot = 135
# epis[450],eps[0.978952],durat[138],fnum=71049, cum_cl_rew = 7, cum_rew = 110,tot_cl = 10 , tot = 140
# epis[460],eps[0.977426],durat[214],fnum=72575, cum_cl_rew = 11, cum_rew = 155,tot_cl = 9 , tot = 141
# epis[470],eps[0.975974],durat[254],fnum=74027, cum_cl_rew = 22, cum_rew = 320,tot_cl = 9 , tot = 136
# epis[480],eps[0.974642],durat[108],fnum=75359, cum_cl_rew = 6, cum_rew = 65,tot_cl = 9 , tot = 127
# epis[490],eps[0.973074],durat[87],fnum=76927, cum_cl_rew = 3, cum_rew = 15,tot_cl = 8 , tot = 121
# epis[500],eps[0.971524],durat[199],fnum=78477, cum_cl_rew = 13, cum_rew = 215,tot_cl = 8 , tot = 110
# epis[510],eps[0.969748],durat[159],fnum=80253, cum_cl_rew = 6, cum_rew = 60,tot_cl = 9 , tot = 129
# epis[520],eps[0.968045],durat[108],fnum=81956, cum_cl_rew = 6, cum_rew = 85,tot_cl = 9 , tot = 140
# epis[530],eps[0.966641],durat[136],fnum=83360, cum_cl_rew = 4, cum_rew = 40,tot_cl = 9 , tot = 131
# epis[540],eps[0.964827],durat[181],fnum=85174, cum_cl_rew = 11, cum_rew = 140,tot_cl = 9 , tot = 145
# epis[550],eps[0.963198],durat[166],fnum=86803, cum_cl_rew = 7, cum_rew = 110,tot_cl = 10 , tot = 160
# epis[560],eps[0.961352],durat[174],fnum=88649, cum_cl_rew = 14, cum_rew = 225,tot_cl = 9 , tot = 156
# epis[570],eps[0.959801],durat[183],fnum=90200, cum_cl_rew = 12, cum_rew = 210,tot_cl = 9 , tot = 147
# epis[580],eps[0.958189],durat[178],fnum=91812, cum_cl_rew = 13, cum_rew = 195,tot_cl = 9 , tot = 151
# epis[590],eps[0.956189],durat[290],fnum=93812, cum_cl_rew = 19, cum_rew = 455,tot_cl = 10 , tot = 161
# epis[600],eps[0.954728],durat[222],fnum=95273, cum_cl_rew = 14, cum_rew = 170,tot_cl = 10 , tot = 162
# epis[610],eps[0.953049],durat[92],fnum=96952, cum_cl_rew = 4, cum_rew = 35,tot_cl = 10 , tot = 150
# epis[620],eps[0.951354],durat[133],fnum=98647, cum_cl_rew = 3, cum_rew = 20,tot_cl = 10 , tot = 165
# epis[630],eps[0.949740],durat[152],fnum=100261, cum_cl_rew = 9, cum_rew = 135,tot_cl = 11 , tot = 175
# epis[640],eps[0.948159],durat[140],fnum=101842, cum_cl_rew = 8, cum_rew = 90,tot_cl = 10 , tot = 155
# epis[650],eps[0.946408],durat[158],fnum=103593, cum_cl_rew = 7, cum_rew = 110,tot_cl = 10 , tot = 156
# epis[660],eps[0.944822],durat[141],fnum=105179, cum_cl_rew = 7, cum_rew = 80,tot_cl = 10 , tot = 161
# epis[670],eps[0.943019],durat[161],fnum=106982, cum_cl_rew = 9, cum_rew = 135,tot_cl = 10 , tot = 151
# epis[680],eps[0.941272],durat[117],fnum=108729, cum_cl_rew = 10, cum_rew = 100,tot_cl = 10 , tot = 158
# epis[690],eps[0.939726],durat[132],fnum=110275, cum_cl_rew = 5, cum_rew = 45,tot_cl = 10 , tot = 159
# epis[700],eps[0.938212],durat[152],fnum=111789, cum_cl_rew = 8, cum_rew = 70,tot_cl = 10 , tot = 151
# epis[710],eps[0.936531],durat[92],fnum=113470, cum_cl_rew = 3, cum_rew = 40,tot_cl = 9 , tot = 143
# epis[720],eps[0.934881],durat[183],fnum=115120, cum_cl_rew = 13, cum_rew = 145,tot_cl = 9 , tot = 139
# epis[730],eps[0.933266],durat[151],fnum=116735, cum_cl_rew = 8, cum_rew = 95,tot_cl = 9 , tot = 130
# epis[740],eps[0.931477],durat[209],fnum=118524, cum_cl_rew = 17, cum_rew = 285,tot_cl = 9 , tot = 136
# epis[750],eps[0.930028],durat[149],fnum=119973, cum_cl_rew = 6, cum_rew = 80,tot_cl = 9 , tot = 137
# epis[760],eps[0.928360],durat[149],fnum=121641, cum_cl_rew = 7, cum_rew = 110,tot_cl = 10 , tot = 142
# epis[770],eps[0.926737],durat[234],fnum=123264, cum_cl_rew = 16, cum_rew = 380,tot_cl = 9 , tot = 143
# epis[780],eps[0.925085],durat[112],fnum=124916, cum_cl_rew = 5, cum_rew = 35,tot_cl = 9 , tot = 149
# epis[790],eps[0.923680],durat[79],fnum=126321, cum_cl_rew = 2, cum_rew = 10,tot_cl = 9 , tot = 143
# epis[800],eps[0.922141],durat[117],fnum=127860, cum_cl_rew = 4, cum_rew = 45,tot_cl = 9 , tot = 139
# epis[810],eps[0.920548],durat[114],fnum=129453, cum_cl_rew = 3, cum_rew = 20,tot_cl = 9 , tot = 132
# epis[820],eps[0.919163],durat[104],fnum=130838, cum_cl_rew = 4, cum_rew = 65,tot_cl = 9 , tot = 126
# epis[830],eps[0.917173],durat[259],fnum=132828, cum_cl_rew = 21, cum_rew = 325,tot_cl = 9 , tot = 122
# epis[840],eps[0.915561],durat[148],fnum=134440, cum_cl_rew = 7, cum_rew = 110,tot_cl = 9 , tot = 129
# epis[850],eps[0.914161],durat[134],fnum=135840, cum_cl_rew = 10, cum_rew = 155,tot_cl = 9 , tot = 134
# epis[860],eps[0.912288],durat[221],fnum=137713, cum_cl_rew = 18, cum_rew = 235,tot_cl = 10 , tot = 146
# epis[870],eps[0.910977],durat[83],fnum=139024, cum_cl_rew = 5, cum_rew = 55,tot_cl = 10 , tot = 147
# epis[880],eps[0.909416],durat[92],fnum=140585, cum_cl_rew = 4, cum_rew = 60,tot_cl = 10 , tot = 140
# epis[890],eps[0.907911],durat[88],fnum=142090, cum_cl_rew = 4, cum_rew = 30,tot_cl = 9 , tot = 131
# epis[900],eps[0.906299],durat[88],fnum=143702, cum_cl_rew = 4, cum_rew = 35,tot_cl = 9 , tot = 128
# epis[910],eps[0.904837],durat[150],fnum=145164, cum_cl_rew = 6, cum_rew = 80,tot_cl = 8 , tot = 112
# epis[920],eps[0.903411],durat[125],fnum=146590, cum_cl_rew = 10, cum_rew = 135,tot_cl = 8 , tot = 111
# epis[930],eps[0.901859],durat[221],fnum=148142, cum_cl_rew = 12, cum_rew = 340,tot_cl = 9 , tot = 119
# epis[940],eps[0.900229],durat[158],fnum=149772, cum_cl_rew = 12, cum_rew = 170,tot_cl = 9 , tot = 128
# epis[950],eps[0.898466],durat[129],fnum=151535, cum_cl_rew = 7, cum_rew = 95,tot_cl = 9 , tot = 139
# epis[960],eps[0.896863],durat[268],fnum=153138, cum_cl_rew = 21, cum_rew = 675,tot_cl = 9 , tot = 145
# epis[970],eps[0.895218],durat[257],fnum=154783, cum_cl_rew = 14, cum_rew = 180,tot_cl = 10 , tot = 156
# epis[980],eps[0.893690],durat[206],fnum=156311, cum_cl_rew = 12, cum_rew = 145,tot_cl = 10 , tot = 153
# epis[990],eps[0.891847],durat[274],fnum=158154, cum_cl_rew = 17, cum_rew = 435,tot_cl = 9 , tot = 147
# epis[1000],eps[0.890195],durat[176],fnum=159806, cum_cl_rew = 10, cum_rew = 155,tot_cl = 9 , tot = 153
# epis[1010],eps[0.888605],durat[127],fnum=161396, cum_cl_rew = 6, cum_rew = 80,tot_cl = 10 , tot = 162
# epis[1020],eps[0.887061],durat[221],fnum=162940, cum_cl_rew = 13, cum_rew = 355,tot_cl = 10 , tot = 162
# epis[1030],eps[0.885543],durat[115],fnum=164458, cum_cl_rew = 4, cum_rew = 40,tot_cl = 9 , tot = 163
# epis[1040],eps[0.884041],durat[85],fnum=165960, cum_cl_rew = 5, cum_rew = 50,tot_cl = 10 , tot = 161
# epis[1050],eps[0.882464],durat[89],fnum=167537, cum_cl_rew = 3, cum_rew = 30,tot_cl = 9 , tot = 145
# epis[1060],eps[0.880711],durat[148],fnum=169290, cum_cl_rew = 11, cum_rew = 140,tot_cl = 9 , tot = 136
# epis[1070],eps[0.879229],durat[124],fnum=170772, cum_cl_rew = 4, cum_rew = 65,tot_cl = 9 , tot = 129
# epis[1080],eps[0.877366],durat[354],fnum=172635, cum_cl_rew = 32, cum_rew = 530,tot_cl = 9 , tot = 125
# epis[1090],eps[0.875717],durat[224],fnum=174284, cum_cl_rew = 12, cum_rew = 145,tot_cl = 10 , tot = 145
# epis[1100],eps[0.874158],durat[85],fnum=175843, cum_cl_rew = 1, cum_rew = 5,tot_cl = 9 , tot = 146
# epis[1110],eps[0.872629],durat[237],fnum=177372, cum_cl_rew = 22, cum_rew = 345,tot_cl = 9 , tot = 143
# epis[1120],eps[0.871074],durat[121],fnum=178927, cum_cl_rew = 7, cum_rew = 110,tot_cl = 9 , tot = 146
# epis[1130],eps[0.869588],durat[94],fnum=180413, cum_cl_rew = 6, cum_rew = 105,tot_cl = 9 , tot = 145
# epis[1140],eps[0.867878],durat[140],fnum=182123, cum_cl_rew = 8, cum_rew = 90,tot_cl = 9 , tot = 130
# epis[1150],eps[0.866013],durat[125],fnum=183988, cum_cl_rew = 6, cum_rew = 50,tot_cl = 9 , tot = 139
# epis[1160],eps[0.864711],durat[218],fnum=185290, cum_cl_rew = 14, cum_rew = 190,tot_cl = 9 , tot = 140
# epis[1170],eps[0.863118],durat[237],fnum=186883, cum_cl_rew = 20, cum_rew = 265,tot_cl = 9 , tot = 136
# epis[1180],eps[0.861322],durat[181],fnum=188679, cum_cl_rew = 6, cum_rew = 55,tot_cl = 10 , tot = 150
# epis[1190],eps[0.859881],durat[187],fnum=190120, cum_cl_rew = 13, cum_rew = 175,tot_cl = 9 , tot = 136
# epis[1200],eps[0.858207],durat[300],fnum=191794, cum_cl_rew = 22, cum_rew = 305,tot_cl = 9 , tot = 127
# epis[1210],eps[0.856476],durat[228],fnum=193525, cum_cl_rew = 17, cum_rew = 260,tot_cl = 10 , tot = 137
# epis[1220],eps[0.854878],durat[176],fnum=195123, cum_cl_rew = 16, cum_rew = 205,tot_cl = 10 , tot = 146
# epis[1230],eps[0.853469],durat[127],fnum=196532, cum_cl_rew = 2, cum_rew = 35,tot_cl = 10 , tot = 131
# epis[1240],eps[0.851738],durat[148],fnum=198263, cum_cl_rew = 11, cum_rew = 140,tot_cl = 10 , tot = 147
# epis[1250],eps[0.849700],durat[301],fnum=200301, cum_cl_rew = 15, cum_rew = 425,tot_cl = 11 , tot = 160
# epis[1260],eps[0.848288],durat[190],fnum=201713, cum_cl_rew = 10, cum_rew = 115,tot_cl = 10 , tot = 162
# epis[1270],eps[0.846779],durat[171],fnum=203222, cum_cl_rew = 10, cum_rew = 145,tot_cl = 10 , tot = 153
# epis[1280],eps[0.845173],durat[192],fnum=204828, cum_cl_rew = 8, cum_rew = 85,tot_cl = 10 , tot = 153
# epis[1290],eps[0.843703],durat[243],fnum=206298, cum_cl_rew = 17, cum_rew = 230,tot_cl = 9 , tot = 149
# epis[1300],eps[0.841849],durat[289],fnum=208152, cum_cl_rew = 16, cum_rew = 430,tot_cl = 9 , tot = 153
# epis[1310],eps[0.840378],durat[127],fnum=209623, cum_cl_rew = 6, cum_rew = 80,tot_cl = 9 , tot = 146
# epis[1320],eps[0.838843],durat[82],fnum=211158, cum_cl_rew = 4, cum_rew = 50,tot_cl = 9 , tot = 146
# epis[1330],eps[0.837439],durat[104],fnum=212562, cum_cl_rew = 7, cum_rew = 95,tot_cl = 9 , tot = 147
# epis[1340],eps[0.835594],durat[219],fnum=214407, cum_cl_rew = 15, cum_rew = 190,tot_cl = 9 , tot = 151
# epis[1350],eps[0.833634],durat[159],fnum=216367, cum_cl_rew = 8, cum_rew = 120,tot_cl = 10 , tot = 150
# epis[1360],eps[0.832226],durat[144],fnum=217775, cum_cl_rew = 7, cum_rew = 80,tot_cl = 10 , tot = 146
# epis[1370],eps[0.830810],durat[173],fnum=219191, cum_cl_rew = 11, cum_rew = 135,tot_cl = 9 , tot = 141
# epis[1380],eps[0.829189],durat[194],fnum=220812, cum_cl_rew = 10, cum_rew = 115,tot_cl = 10 , tot = 139
# epis[1390],eps[0.827948],durat[124],fnum=222053, cum_cl_rew = 9, cum_rew = 125,tot_cl = 9 , tot = 127
# epis[1400],eps[0.826405],durat[296],fnum=223596, cum_cl_rew = 24, cum_rew = 355,tot_cl = 8 , tot = 105
# epis[1410],eps[0.824627],durat[184],fnum=225374, cum_cl_rew = 15, cum_rew = 200,tot_cl = 8 , tot = 121
# epis[1420],eps[0.823009],durat[156],fnum=226992, cum_cl_rew = 6, cum_rew = 60,tot_cl = 9 , tot = 128
# epis[1430],eps[0.821479],durat[170],fnum=228522, cum_cl_rew = 9, cum_rew = 110,tot_cl = 9 , tot = 130
# epis[1440],eps[0.819672],durat[208],fnum=230329, cum_cl_rew = 7, cum_rew = 115,tot_cl = 9 , tot = 140
# epis[1450],eps[0.818459],durat[140],fnum=231542, cum_cl_rew = 11, cum_rew = 180,tot_cl = 9 , tot = 137
# epis[1460],eps[0.816796],durat[126],fnum=233205, cum_cl_rew = 6, cum_rew = 75,tot_cl = 8 , tot = 120
# epis[1470],eps[0.815314],durat[315],fnum=234687, cum_cl_rew = 24, cum_rew = 360,tot_cl = 8 , tot = 109
# epis[1480],eps[0.813692],durat[93],fnum=236309, cum_cl_rew = 5, cum_rew = 60,tot_cl = 9 , tot = 138
# epis[1490],eps[0.811818],durat[212],fnum=238183, cum_cl_rew = 15, cum_rew = 200,tot_cl = 9 , tot = 136
# epis[1500],eps[0.810098],durat[122],fnum=239903, cum_cl_rew = 5, cum_rew = 90,tot_cl = 10 , tot = 156
# epis[1510],eps[0.808630],durat[90],fnum=241371, cum_cl_rew = 7, cum_rew = 60,tot_cl = 10 , tot = 162
# epis[1520],eps[0.807209],durat[134],fnum=242792, cum_cl_rew = 6, cum_rew = 55,tot_cl = 10 , tot = 170
# epis[1530],eps[0.805569],durat[128],fnum=244432, cum_cl_rew = 5, cum_rew = 75,tot_cl = 10 , tot = 142
# epis[1540],eps[0.803551],durat[199],fnum=246450, cum_cl_rew = 17, cum_rew = 220,tot_cl = 10 , tot = 154
# epis[1550],eps[0.802003],durat[144],fnum=247998, cum_cl_rew = 13, cum_rew = 185,tot_cl = 10 , tot = 142
# epis[1560],eps[0.800437],durat[185],fnum=249564, cum_cl_rew = 17, cum_rew = 240,tot_cl = 10 , tot = 142
# epis[1570],eps[0.799018],durat[218],fnum=250983, cum_cl_rew = 16, cum_rew = 420,tot_cl = 10 , tot = 140
# epis[1580],eps[0.797470],durat[167],fnum=252531, cum_cl_rew = 8, cum_rew = 75,tot_cl = 10 , tot = 144
# epis[1590],eps[0.795909],durat[167],fnum=254092, cum_cl_rew = 9, cum_rew = 120,tot_cl = 9 , tot = 124
# epis[1600],eps[0.794280],durat[152],fnum=255721, cum_cl_rew = 11, cum_rew = 160,tot_cl = 9 , tot = 127
# epis[1610],eps[0.792895],durat[158],fnum=257106, cum_cl_rew = 12, cum_rew = 125,tot_cl = 9 , tot = 129
# epis[1620],eps[0.791039],durat[152],fnum=258962, cum_cl_rew = 11, cum_rew = 145,tot_cl = 10 , tot = 138
# epis[1630],eps[0.789600],durat[167],fnum=260401, cum_cl_rew = 10, cum_rew = 160,tot_cl = 9 , tot = 130
# epis[1640],eps[0.787895],durat[293],fnum=262106, cum_cl_rew = 15, cum_rew = 230,tot_cl = 10 , tot = 133
# epis[1650],eps[0.786375],durat[253],fnum=263626, cum_cl_rew = 20, cum_rew = 265,tot_cl = 9 , tot = 123
# epis[1660],eps[0.784916],durat[82],fnum=265085, cum_cl_rew = 2, cum_rew = 10,tot_cl = 9 , tot = 116
# epis[1670],eps[0.783348],durat[164],fnum=266653, cum_cl_rew = 9, cum_rew = 280,tot_cl = 9 , tot = 109
# epis[1680],eps[0.781449],durat[271],fnum=268552, cum_cl_rew = 22, cum_rew = 475,tot_cl = 9 , tot = 123
# epis[1690],eps[0.779877],durat[154],fnum=270124, cum_cl_rew = 11, cum_rew = 160,tot_cl = 9 , tot = 131
# epis[1700],eps[0.778066],durat[246],fnum=271935, cum_cl_rew = 20, cum_rew = 285,tot_cl = 10 , tot = 141
# epis[1710],eps[0.776524],durat[146],fnum=273477, cum_cl_rew = 10, cum_rew = 155,tot_cl = 10 , tot = 149
# epis[1720],eps[0.775234],durat[149],fnum=274767, cum_cl_rew = 7, cum_rew = 65,tot_cl = 10 , tot = 146
# epis[1730],eps[0.773529],durat[303],fnum=276472, cum_cl_rew = 23, cum_rew = 330,tot_cl = 10 , tot = 137
# epis[1740],eps[0.772022],durat[146],fnum=277979, cum_cl_rew = 9, cum_rew = 95,tot_cl = 10 , tot = 129
# epis[1750],eps[0.770625],durat[118],fnum=279376, cum_cl_rew = 8, cum_rew = 70,tot_cl = 10 , tot = 124
# epis[1760],eps[0.769078],durat[145],fnum=280923, cum_cl_rew = 12, cum_rew = 150,tot_cl = 9 , tot = 115
# epis[1770],eps[0.767303],durat[223],fnum=282698, cum_cl_rew = 10, cum_rew = 130,tot_cl = 10 , tot = 128
# epis[1780],eps[0.765832],durat[87],fnum=284169, cum_cl_rew = 8, cum_rew = 95,tot_cl = 10 , tot = 128
# epis[1790],eps[0.764264],durat[119],fnum=285737, cum_cl_rew = 5, cum_rew = 30,tot_cl = 9 , tot = 124
# epis[1800],eps[0.762785],durat[153],fnum=287216, cum_cl_rew = 12, cum_rew = 135,tot_cl = 9 , tot = 124
# epis[1810],eps[0.761329],durat[220],fnum=288672, cum_cl_rew = 19, cum_rew = 250,tot_cl = 9 , tot = 124
# epis[1820],eps[0.759731],durat[214],fnum=290270, cum_cl_rew = 12, cum_rew = 170,tot_cl = 9 , tot = 119
# epis[1830],eps[0.757900],durat[151],fnum=292101, cum_cl_rew = 7, cum_rew = 110,tot_cl = 10 , tot = 130
# epis[1840],eps[0.756118],durat[241],fnum=293883, cum_cl_rew = 23, cum_rew = 350,tot_cl = 10 , tot = 143
# epis[1850],eps[0.754372],durat[117],fnum=295629, cum_cl_rew = 6, cum_rew = 75,tot_cl = 10 , tot = 151
# epis[1860],eps[0.752778],durat[116],fnum=297223, cum_cl_rew = 6, cum_rew = 60,tot_cl = 10 , tot = 147
# epis[1870],eps[0.750834],durat[251],fnum=299167, cum_cl_rew = 16, cum_rew = 235,tot_cl = 11 , tot = 166
# epis[1880],eps[0.749154],durat[156],fnum=300847, cum_cl_rew = 5, cum_rew = 45,tot_cl = 11 , tot = 158
# epis[1890],eps[0.747469],durat[215],fnum=302532, cum_cl_rew = 25, cum_rew = 350,tot_cl = 11 , tot = 151
# epis[1900],eps[0.745725],durat[140],fnum=304276, cum_cl_rew = 4, cum_rew = 35,tot_cl = 11 , tot = 161
# epis[1910],eps[0.744157],durat[87],fnum=305844, cum_cl_rew = 6, cum_rew = 80,tot_cl = 12 , tot = 166
# epis[1920],eps[0.742270],durat[249],fnum=307731, cum_cl_rew = 11, cum_rew = 120,tot_cl = 11 , tot = 158
# epis[1930],eps[0.740663],durat[99],fnum=309338, cum_cl_rew = 8, cum_rew = 85,tot_cl = 11 , tot = 161
# epis[1940],eps[0.738998],durat[198],fnum=311003, cum_cl_rew = 18, cum_rew = 255,tot_cl = 12 , tot = 168
# epis[1950],eps[0.737519],durat[226],fnum=312482, cum_cl_rew = 22, cum_rew = 310,tot_cl = 10 , tot = 149
# epis[1960],eps[0.735895],durat[177],fnum=314106, cum_cl_rew = 9, cum_rew = 120,tot_cl = 11 , tot = 154
# epis[1970],eps[0.734255],durat[172],fnum=315746, cum_cl_rew = 12, cum_rew = 175,tot_cl = 10 , tot = 142
# epis[1980],eps[0.732855],durat[238],fnum=317146, cum_cl_rew = 18, cum_rew = 425,tot_cl = 10 , tot = 133
# epis[1990],eps[0.731265],durat[181],fnum=318736, cum_cl_rew = 17, cum_rew = 410,tot_cl = 10 , tot = 135
# epis[2000],eps[0.729442],durat[142],fnum=320559, cum_cl_rew = 12, cum_rew = 125,tot_cl = 11 , tot = 152
# epis[2010],eps[0.727902],durat[163],fnum=322099, cum_cl_rew = 11, cum_rew = 95,tot_cl = 10 , tot = 152
# epis[2020],eps[0.726219],durat[172],fnum=323782, cum_cl_rew = 10, cum_rew = 85,tot_cl = 10 , tot = 149
# epis[2030],eps[0.724670],durat[99],fnum=325331, cum_cl_rew = 6, cum_rew = 65,tot_cl = 11 , tot = 165
# epis[2040],eps[0.722729],durat[257],fnum=327272, cum_cl_rew = 22, cum_rew = 320,tot_cl = 11 , tot = 161
# epis[2050],eps[0.721187],durat[207],fnum=328814, cum_cl_rew = 12, cum_rew = 150,tot_cl = 11 , tot = 148
# epis[2060],eps[0.719689],durat[151],fnum=330312, cum_cl_rew = 10, cum_rew = 110,tot_cl = 10 , tot = 138
# epis[2070],eps[0.717969],durat[167],fnum=332032, cum_cl_rew = 8, cum_rew = 110,tot_cl = 11 , tot = 144
# epis[2080],eps[0.716113],durat[284],fnum=333888, cum_cl_rew = 21, cum_rew = 285,tot_cl = 11 , tot = 138
# epis[2090],eps[0.714286],durat[194],fnum=335715, cum_cl_rew = 17, cum_rew = 240,tot_cl = 11 , tot = 142
# epis[2100],eps[0.712926],durat[209],fnum=337075, cum_cl_rew = 15, cum_rew = 360,tot_cl = 11 , tot = 142
# epis[2110],eps[0.711262],durat[190],fnum=338739, cum_cl_rew = 16, cum_rew = 215,tot_cl = 11 , tot = 155
# epis[2120],eps[0.709690],durat[140],fnum=340311, cum_cl_rew = 8, cum_rew = 95,tot_cl = 11 , tot = 154
# epis[2130],eps[0.707753],durat[141],fnum=342248, cum_cl_rew = 8, cum_rew = 105,tot_cl = 12 , tot = 167
# epis[2140],eps[0.706148],durat[189],fnum=343853, cum_cl_rew = 11, cum_rew = 150,tot_cl = 11 , tot = 158
# epis[2150],eps[0.704586],durat[192],fnum=345415, cum_cl_rew = 17, cum_rew = 220,tot_cl = 11 , tot = 154
# epis[2160],eps[0.702841],durat[180],fnum=347160, cum_cl_rew = 11, cum_rew = 350,tot_cl = 11 , tot = 163
# epis[2170],eps[0.701364],durat[114],fnum=348637, cum_cl_rew = 6, cum_rew = 75,tot_cl = 11 , tot = 165
# epis[2180],eps[0.699579],durat[347],fnum=350422, cum_cl_rew = 25, cum_rew = 345,tot_cl = 10 , tot = 144
# epis[2190],eps[0.697916],durat[179],fnum=352085, cum_cl_rew = 11, cum_rew = 120,tot_cl = 11 , tot = 150
# epis[2200],eps[0.695866],durat[293],fnum=354135, cum_cl_rew = 20, cum_rew = 490,tot_cl = 11 , tot = 172
# epis[2210],eps[0.694253],durat[142],fnum=355748, cum_cl_rew = 6, cum_rew = 40,tot_cl = 11 , tot = 173
# epis[2220],eps[0.692387],durat[228],fnum=357614, cum_cl_rew = 24, cum_rew = 335,tot_cl = 11 , tot = 165
# epis[2230],eps[0.690833],durat[247],fnum=359168, cum_cl_rew = 19, cum_rew = 350,tot_cl = 11 , tot = 171
# epis[2240],eps[0.689048],durat[210],fnum=360953, cum_cl_rew = 20, cum_rew = 250,tot_cl = 11 , tot = 170
# epis[2250],eps[0.687454],durat[125],fnum=362547, cum_cl_rew = 9, cum_rew = 100,tot_cl = 11 , tot = 160
# epis[2260],eps[0.685885],durat[196],fnum=364116, cum_cl_rew = 16, cum_rew = 185,tot_cl = 11 , tot = 145
# epis[2270],eps[0.684279],durat[212],fnum=365722, cum_cl_rew = 12, cum_rew = 340,tot_cl = 11 , tot = 154
# epis[2280],eps[0.682788],durat[112],fnum=367213, cum_cl_rew = 5, cum_rew = 45,tot_cl = 11 , tot = 158
# epis[2290],eps[0.681001],durat[95],fnum=369000, cum_cl_rew = 5, cum_rew = 55,tot_cl = 11 , tot = 160
# epis[2300],eps[0.679558],durat[196],fnum=370443, cum_cl_rew = 12, cum_rew = 165,tot_cl = 10 , tot = 146
# epis[2310],eps[0.677864],durat[190],fnum=372137, cum_cl_rew = 15, cum_rew = 195,tot_cl = 10 , tot = 155
# epis[2320],eps[0.676385],durat[163],fnum=373616, cum_cl_rew = 11, cum_rew = 125,tot_cl = 10 , tot = 147
# epis[2330],eps[0.675152],durat[114],fnum=374849, cum_cl_rew = 9, cum_rew = 115,tot_cl = 9 , tot = 129
# epis[2340],eps[0.673660],durat[158],fnum=376341, cum_cl_rew = 10, cum_rew = 100,tot_cl = 9 , tot = 116
# epis[2350],eps[0.672135],durat[84],fnum=377866, cum_cl_rew = 4, cum_rew = 35,tot_cl = 9 , tot = 119
# epis[2360],eps[0.670447],durat[144],fnum=379554, cum_cl_rew = 10, cum_rew = 110,tot_cl = 9 , tot = 111
# epis[2370],eps[0.668828],durat[203],fnum=381173, cum_cl_rew = 13, cum_rew = 360,tot_cl = 9 , tot = 118
# epis[2380],eps[0.667301],durat[238],fnum=382700, cum_cl_rew = 16, cum_rew = 190,tot_cl = 10 , tot = 131
# epis[2390],eps[0.665818],durat[86],fnum=384183, cum_cl_rew = 4, cum_rew = 55,tot_cl = 10 , tot = 137
# epis[2400],eps[0.664448],durat[91],fnum=385553, cum_cl_rew = 3, cum_rew = 30,tot_cl = 10 , tot = 133
# epis[2410],eps[0.662891],durat[105],fnum=387110, cum_cl_rew = 6, cum_rew = 55,tot_cl = 9 , tot = 124
# epis[2420],eps[0.661474],durat[184],fnum=388527, cum_cl_rew = 14, cum_rew = 375,tot_cl = 9 , tot = 117
# epis[2430],eps[0.659754],durat[196],fnum=390247, cum_cl_rew = 13, cum_rew = 185,tot_cl = 9 , tot = 120
# epis[2440],eps[0.658335],durat[114],fnum=391666, cum_cl_rew = 6, cum_rew = 45,tot_cl = 9 , tot = 125
# epis[2450],eps[0.656968],durat[123],fnum=393033, cum_cl_rew = 10, cum_rew = 110,tot_cl = 9 , tot = 130
# epis[2460],eps[0.655251],durat[84],fnum=394750, cum_cl_rew = 3, cum_rew = 30,tot_cl = 10 , tot = 143
# epis[2470],eps[0.653568],durat[188],fnum=396433, cum_cl_rew = 16, cum_rew = 225,tot_cl = 10 , tot = 147
# epis[2480],eps[0.651987],durat[167],fnum=398014, cum_cl_rew = 8, cum_rew = 105,tot_cl = 10 , tot = 147
# epis[2490],eps[0.650332],durat[218],fnum=399669, cum_cl_rew = 22, cum_rew = 350,tot_cl = 10 , tot = 143
# epis[2500],eps[0.648641],durat[148],fnum=401360, cum_cl_rew = 9, cum_rew = 265,tot_cl = 11 , tot = 149
# epis[2510],eps[0.647165],durat[124],fnum=402836, cum_cl_rew = 7, cum_rew = 60,tot_cl = 10 , tot = 150
# epis[2520],eps[0.645703],durat[89],fnum=404298, cum_cl_rew = 9, cum_rew = 100,tot_cl = 10 , tot = 144
# epis[2530],eps[0.644280],durat[284],fnum=405721, cum_cl_rew = 20, cum_rew = 290,tot_cl = 9 , tot = 130
# epis[2540],eps[0.642829],durat[214],fnum=407172, cum_cl_rew = 19, cum_rew = 225,tot_cl = 9 , tot = 122
# epis[2550],eps[0.641115],durat[176],fnum=408886, cum_cl_rew = 12, cum_rew = 350,tot_cl = 9 , tot = 131
# epis[2560],eps[0.639653],durat[91],fnum=410348, cum_cl_rew = 7, cum_rew = 50,tot_cl = 9 , tot = 133
# epis[2570],eps[0.638169],durat[152],fnum=411832, cum_cl_rew = 6, cum_rew = 50,tot_cl = 10 , tot = 132
# epis[2580],eps[0.636578],durat[156],fnum=413423, cum_cl_rew = 13, cum_rew = 165,tot_cl = 10 , tot = 144
# epis[2590],eps[0.635273],durat[209],fnum=414728, cum_cl_rew = 10, cum_rew = 100,tot_cl = 10 , tot = 147
# epis[2600],eps[0.633645],durat[176],fnum=416356, cum_cl_rew = 11, cum_rew = 110,tot_cl = 10 , tot = 139
# epis[2610],eps[0.631927],durat[120],fnum=418074, cum_cl_rew = 7, cum_rew = 80,tot_cl = 10 , tot = 136
# epis[2620],eps[0.630392],durat[130],fnum=419609, cum_cl_rew = 8, cum_rew = 80,tot_cl = 10 , tot = 140
# epis[2630],eps[0.628843],durat[157],fnum=421158, cum_cl_rew = 11, cum_rew = 150,tot_cl = 10 , tot = 142
# epis[2640],eps[0.627416],durat[108],fnum=422585, cum_cl_rew = 10, cum_rew = 95,tot_cl = 10 , tot = 146
# epis[2650],eps[0.625970],durat[156],fnum=424031, cum_cl_rew = 12, cum_rew = 170,tot_cl = 10 , tot = 133
# epis[2660],eps[0.624459],durat[80],fnum=425542, cum_cl_rew = 1, cum_rew = 5,tot_cl = 10 , tot = 135
# epis[2670],eps[0.622698],durat[207],fnum=427303, cum_cl_rew = 14, cum_rew = 180,tot_cl = 10 , tot = 136
# epis[2680],eps[0.621236],durat[119],fnum=428765, cum_cl_rew = 6, cum_rew = 50,tot_cl = 10 , tot = 138
# epis[2690],eps[0.619705],durat[153],fnum=430296, cum_cl_rew = 12, cum_rew = 145,tot_cl = 10 , tot = 131
# epis[2700],eps[0.618080],durat[107],fnum=431921, cum_cl_rew = 4, cum_rew = 40,tot_cl = 10 , tot = 145
# epis[2710],eps[0.616322],durat[220],fnum=433679, cum_cl_rew = 16, cum_rew = 200,tot_cl = 10 , tot = 138
# epis[2720],eps[0.614758],durat[112],fnum=435243, cum_cl_rew = 8, cum_rew = 95,tot_cl = 11 , tot = 145
# epis[2730],eps[0.613189],durat[136],fnum=436812, cum_cl_rew = 7, cum_rew = 120,tot_cl = 10 , tot = 138
# epis[2740],eps[0.611573],durat[151],fnum=438428, cum_cl_rew = 10, cum_rew = 70,tot_cl = 11 , tot = 147
# epis[2750],eps[0.609642],durat[220],fnum=440359, cum_cl_rew = 13, cum_rew = 145,tot_cl = 11 , tot = 158
# epis[2760],eps[0.607851],durat[158],fnum=442150, cum_cl_rew = 12, cum_rew = 130,tot_cl = 12 , tot = 166
# epis[2770],eps[0.606473],durat[115],fnum=443528, cum_cl_rew = 7, cum_rew = 80,tot_cl = 11 , tot = 155
# epis[2780],eps[0.605091],durat[176],fnum=444910, cum_cl_rew = 11, cum_rew = 125,tot_cl = 11 , tot = 161
# epis[2790],eps[0.603530],durat[226],fnum=446471, cum_cl_rew = 21, cum_rew = 320,tot_cl = 11 , tot = 154
# epis[2800],eps[0.601861],durat[181],fnum=448140, cum_cl_rew = 16, cum_rew = 215,tot_cl = 11 , tot = 146
# epis[2810],eps[0.600474],durat[113],fnum=449527, cum_cl_rew = 4, cum_rew = 20,tot_cl = 10 , tot = 138
# epis[2820],eps[0.598818],durat[164],fnum=451183, cum_cl_rew = 13, cum_rew = 195,tot_cl = 10 , tot = 134
# epis[2830],eps[0.597135],durat[229],fnum=452866, cum_cl_rew = 17, cum_rew = 460,tot_cl = 11 , tot = 136
# epis[2840],eps[0.595391],durat[320],fnum=454610, cum_cl_rew = 25, cum_rew = 565,tot_cl = 11 , tot = 143
# epis[2850],eps[0.593895],durat[115],fnum=456106, cum_cl_rew = 6, cum_rew = 40,tot_cl = 10 , tot = 140
# epis[2860],eps[0.592323],durat[117],fnum=457678, cum_cl_rew = 6, cum_rew = 70,tot_cl = 10 , tot = 138
# epis[2870],eps[0.590710],durat[122],fnum=459291, cum_cl_rew = 4, cum_rew = 30,tot_cl = 11 , tot = 144
# epis[2880],eps[0.589450],durat[148],fnum=460551, cum_cl_rew = 12, cum_rew = 160,tot_cl = 10 , tot = 129
# epis[2890],eps[0.587626],durat[151],fnum=462375, cum_cl_rew = 10, cum_rew = 150,tot_cl = 10 , tot = 133
# epis[2900],eps[0.586142],durat[118],fnum=463859, cum_cl_rew = 4, cum_rew = 35,tot_cl = 10 , tot = 128
# epis[2910],eps[0.584589],durat[222],fnum=465412, cum_cl_rew = 20, cum_rew = 295,tot_cl = 10 , tot = 128
# epis[2920],eps[0.582977],durat[204],fnum=467024, cum_cl_rew = 22, cum_rew = 505,tot_cl = 10 , tot = 130
# epis[2930],eps[0.581725],durat[113],fnum=468276, cum_cl_rew = 7, cum_rew = 85,tot_cl = 11 , tot = 144
# epis[2940],eps[0.580330],durat[113],fnum=469671, cum_cl_rew = 2, cum_rew = 30,tot_cl = 10 , tot = 135
# epis[2950],eps[0.578530],durat[266],fnum=471471, cum_cl_rew = 24, cum_rew = 400,tot_cl = 10 , tot = 134
# epis[2960],eps[0.577000],durat[157],fnum=473001, cum_cl_rew = 9, cum_rew = 145,tot_cl = 10 , tot = 150
# epis[2970],eps[0.575431],durat[175],fnum=474570, cum_cl_rew = 15, cum_rew = 185,tot_cl = 10 , tot = 148
# epis[2980],eps[0.574006],durat[127],fnum=475995, cum_cl_rew = 4, cum_rew = 25,tot_cl = 10 , tot = 144
# epis[2990],eps[0.572394],durat[94],fnum=477607, cum_cl_rew = 4, cum_rew = 50,tot_cl = 11 , tot = 148
# epis[3000],eps[0.570985],durat[90],fnum=479016, cum_cl_rew = 2, cum_rew = 10,tot_cl = 11 , tot = 147
# epis[3010],eps[0.569470],durat[76],fnum=480531, cum_cl_rew = 3, cum_rew = 20,tot_cl = 10 , tot = 131
# epis[3020],eps[0.567947],durat[89],fnum=482054, cum_cl_rew = 3, cum_rew = 20,tot_cl = 10 , tot = 129
# epis[3030],eps[0.566497],durat[110],fnum=483504, cum_cl_rew = 3, cum_rew = 45,tot_cl = 9 , tot = 125
# epis[3040],eps[0.564825],durat[180],fnum=485176, cum_cl_rew = 16, cum_rew = 170,tot_cl = 9 , tot = 123
# epis[3050],eps[0.563105],durat[156],fnum=486896, cum_cl_rew = 11, cum_rew = 110,tot_cl = 10 , tot = 132
# epis[3060],eps[0.561468],durat[107],fnum=488533, cum_cl_rew = 6, cum_rew = 50,tot_cl = 11 , tot = 141
# epis[3070],eps[0.559796],durat[126],fnum=490205, cum_cl_rew = 8, cum_rew = 85,tot_cl = 11 , tot = 147
# epis[3080],eps[0.558264],durat[145],fnum=491737, cum_cl_rew = 10, cum_rew = 100,tot_cl = 11 , tot = 149
# epis[3090],eps[0.556703],durat[199],fnum=493298, cum_cl_rew = 13, cum_rew = 140,tot_cl = 11 , tot = 142
# epis[3100],eps[0.555008],durat[214],fnum=494993, cum_cl_rew = 13, cum_rew = 155,tot_cl = 11 , tot = 136
# epis[3110],eps[0.553325],durat[230],fnum=496676, cum_cl_rew = 12, cum_rew = 125,tot_cl = 10 , tot = 128
# epis[3120],eps[0.551403],durat[152],fnum=498598, cum_cl_rew = 8, cum_rew = 55,tot_cl = 10 , tot = 133
# epis[3130],eps[0.549770],durat[122],fnum=500231, cum_cl_rew = 7, cum_rew = 55,tot_cl = 11 , tot = 138
# epis[3140],eps[0.548014],durat[145],fnum=501987, cum_cl_rew = 5, cum_rew = 35,tot_cl = 11 , tot = 153
# epis[3150],eps[0.546545],durat[118],fnum=503456, cum_cl_rew = 4, cum_rew = 60,tot_cl = 11 , tot = 149
# epis[3160],eps[0.544950],durat[76],fnum=505051, cum_cl_rew = 2, cum_rew = 30,tot_cl = 11 , tot = 158
# epis[3170],eps[0.543060],durat[183],fnum=506941, cum_cl_rew = 7, cum_rew = 55,tot_cl = 11 , tot = 155
# epis[3180],eps[0.541224],durat[135],fnum=508777, cum_cl_rew = 10, cum_rew = 130,tot_cl = 11 , tot = 170
# epis[3190],eps[0.539823],durat[170],fnum=510178, cum_cl_rew = 8, cum_rew = 120,tot_cl = 11 , tot = 159
# epis[3200],eps[0.537996],durat[222],fnum=512005, cum_cl_rew = 15, cum_rew = 200,tot_cl = 11 , tot = 162
# epis[3210],eps[0.536195],durat[116],fnum=513806, cum_cl_rew = 6, cum_rew = 60,tot_cl = 11 , tot = 165
# epis[3220],eps[0.534365],durat[192],fnum=515636, cum_cl_rew = 17, cum_rew = 275,tot_cl = 11 , tot = 165
# epis[3230],eps[0.532637],durat[194],fnum=517364, cum_cl_rew = 9, cum_rew = 125,tot_cl = 11 , tot = 155
# epis[3240],eps[0.531028],durat[203],fnum=518973, cum_cl_rew = 11, cum_rew = 125,tot_cl = 11 , tot = 160
# epis[3250],eps[0.529314],durat[147],fnum=520687, cum_cl_rew = 10, cum_rew = 150,tot_cl = 11 , tot = 160
# epis[3260],eps[0.527806],durat[112],fnum=522195, cum_cl_rew = 12, cum_rew = 105,tot_cl = 11 , tot = 164
# epis[3270],eps[0.525974],durat[144],fnum=524027, cum_cl_rew = 12, cum_rew = 120,tot_cl = 11 , tot = 172
# epis[3280],eps[0.524345],durat[126],fnum=525656, cum_cl_rew = 6, cum_rew = 50,tot_cl = 11 , tot = 170
# epis[3290],eps[0.522689],durat[179],fnum=527312, cum_cl_rew = 16, cum_rew = 235,tot_cl = 11 , tot = 166
# epis[3300],eps[0.520375],durat[274],fnum=529626, cum_cl_rew = 16, cum_rew = 185,tot_cl = 12 , tot = 187
# epis[3310],eps[0.518692],durat[216],fnum=531309, cum_cl_rew = 13, cum_rew = 150,tot_cl = 12 , tot = 183
# epis[3320],eps[0.516797],durat[119],fnum=533204, cum_cl_rew = 9, cum_rew = 100,tot_cl = 12 , tot = 184

# %% [markdown]
# ### Plot the overall performace

# %%
bandwidth = 500 # Moving average bandwidth
total_clipped = np.zeros(int(epis_count)-bandwidth)
total_rew = np.zeros(int(epis_count)-bandwidth)
for i in range(int(epis_count)-bandwidth):
    total_clipped[i] = np.sum(tot_clipped_reward[i:i+bandwidth])/bandwidth
    total_rew[i] = np.sum(tot_reward[i:i+bandwidth])/bandwidth
t = np.arange(int(epis_count)-bandwidth)
belplt = plt.plot(t,total_rew[0:int(epis_count)-bandwidth],"r", label = "Return")
plt.legend()#handles[likplt,belplt])
print('Running after %d number of episodes' %epis_count)
plt.xlabel("Number of episode")
plt.ylabel("Average Reward per episode")
plt.show()
likplt = plt.plot(t,total_clipped[0:opt.num_episode-bandwidth],"b", label = "Clipped Return")
plt.legend()#handles[likplt,belplt])
plt.xlabel("Number of episode")
plt.ylabel("Average clipped Reward per episode")
plt.show()

# %% [markdown]
# ### Accumulated average reward after 1000 episodes of game Assault
# |![](./Assault.png)|![](./Assault-clipped.png)|
# |:---------------:|:---------------:|
# |Average reward|Average clipped reward|
