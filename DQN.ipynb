# %% [markdown]
# ## DQN (Deep Q-Network)
# ### Function approximation Q-learning
# This tutorial walks through the implementation of deep Q networks (DQNs),
# an RL method which applies the function approximation capabilities of deep neural networks
# to problems in reinforcement learning.
# The model in this tutorial closely follows the work described in the paper
# [Human-level control through deep reinforcement learning](http://www.nature.com/nature/journal/v518/n7540/full/nature14236.html?foxtrotcallback=true), written by Volodomyr Mnih.
#
# To keep these chapters runnable
# by as many people as possible,
# on as many machines as possible,
# and with as few headaches as possible,
# we have so far avoided dependencies on external libraries
# (besides mxnet, numpy and matplotlib).
# However, in this case, we'll need to import the [OpenAI Gym](https://gym.openai.com/docs).
# That's because in reinforcement learning,
# instead of drawing examples from a data structure,
# our data comes from interactions with an environment.
# In this chapter, our environemnts will be classic Atari video games.
#
# ## Preliminaries
# The following code clones and installs the OpenAI gym.
# `git clone https://github.com/openai/gym ; cd gym ; pip install -e .[all]`
# Full documentation for the gym can be found on [at this website](https://gym.openai.com/).
# If you want to see reasonable results before the sun sets on your AI career,
# we suggest running these experiments on a server equipped with GPUs.

# %%
import mxnet as mx
from mxnet import nd, autograd
from mxnet import gluon
from __future__ import print_function
import os
import random
import numpy as np
import matplotlib.pyplot as plt
from IPython import display
import gym
import math
from collections import namedtuple
import time
f = open('results.txt','w')

# %% [markdown]
# ### Summary of the algorithm
# #### Collect samples
# At the beginning of each episode (one round of the game),
# reset the environment to its initial state using `env.reset()`.
# At each time step ``t``, the environment is at `current_state`.
# With probability $\epsilon$, apply a random action.
# Otherwise, apply $argmax_a~ Q(\phi($ `current_state` $),a,\theta)$,
# where $Q$ is parameterized by paramters $\theta$ and $\phi(\cdot)$ is preprocessor.
# Pass the action through `env.step(action)` to receive next frame, reward and whether the game terminates.
# Append this frame to the end of the `current_state` and construct `next_state` while removeing $frame(t-12)$.
# Store the tuple $(\phi($ `current_state` $), action, reward, \phi($ `next_ state` $))$ in the replay buffer.
#
# #### Update Network
# * Draw batches of tuples from the replay buffer: $(\phi,r,a,\phi')$.
# * Define the following loss
# $$\Large(\small Q(\phi,a,\theta)-r-max_{a'}Q(\phi',a',\theta^-)\Large)^2$$
# * Where $\theta^-$ is the parameter of the target network.( Set $Q(\phi',a',\theta^-)$ to zero if $\phi$ is the preprocessed termination state).
# * Update the $\theta$
# * Update the $\theta^-$ once in a while

# %% [markdown]
# ## Set the hyper-parameters

# %%
class Options:
    def __init__(self):
        #Articheture
        self.batch_size = 32 # The size of the batch to learn the Q-function
        self.image_size = 80 # Resize the raw input frame to square frame of size 80 by 80 
        #Trickes
        self.replay_buffer_size = 1000000 # The size of replay buffer; set it to size of your memory (.5M for 50G available memory)
        self.learning_frequency = 4 # With Freq of 1/4 step update the Q-network
        self.skip_frame = 4 # Skip 4-1 raw frames between steps
        self.internal_skip_frame = 4 # Skip 4-1 raw frames between skipped frames
        self.frame_len = 4 # Each state is formed as a concatination 4 step frames [f(t-12),f(t-8),f(t-4),f(t)]
        self.Target_update = 10000 # Update the target network each 10000 steps
        self.epsilon_min = 0.1 # Minimum level of stochasticity of policy (epsilon)-greedy
        self.annealing_end = 1000000. # The number of step it take to linearly anneal the epsilon to it min value
        self.gamma = 0.99 # The discount factor
        self.replay_start_size = 50000 # Start to backpropagated through the network, learning starts
        self.no_op_max = 30 / self.skip_frame # Run uniform policy for first 30 times step of the beginning of the game
        
        #otimization
        self.num_episode = 3000 # Number episode to run the algorithm
        self.lr = 0.00025 # RMSprop learning rate
        self.gamma1 = 0.95 # RMSprop gamma1
        self.gamma2 = 0.95 # RMSprop gamma2
        self.rms_eps = 0.01 # RMSprop epsilon bias
        self.ctx = mx.gpu() # Enables gpu if available, if not, set it to mx.cpu()
opt = Options()

env_name = 'AssaultNoFrameskip-v4' # Set the desired environment
env = gym.make(env_name)
num_action = env.action_space.n # Extract the number of available action from the environment setting

manualSeed = 1 # random.randint(1, 10000) # Set the desired seed to reproduce the results
mx.random.seed(manualSeed)
attrs = vars(opt)
print (', '.join("%s: %s" % item for item in attrs.items()))
# Out:
# replay_buffer_size: 1000000, annealing_end: 1000000.0, Target_update: 10000, gamma1: 0.95, frame_len: 4, internal_skip_frame: 4, ctx: gpu(0), skip_frame: 4, batch_size: 32, learning_frequency: 4, lr: 0.00025, num_episode: 3000, image_size: 80, epsilon_min: 0.1, replay_start_size: 50000, rms_eps: 0.01, no_op_max: 7, gamma: 0.99, gamma2: 0.95

# %% [markdown]
# ### Define the DQN model
# The network is constructed as three CNN layers and a fully connected added on the top. Furthermore, the optimizer is assigned to the parameters.

# %%
DQN = gluon.nn.Sequential()
with DQN.name_scope():
    #first layer
    DQN.add(gluon.nn.Conv2D(channels=32, kernel_size=8,strides = 4,padding = 0))
    DQN.add(gluon.nn.BatchNorm(axis = 1, momentum = 0.1,center=True))
    DQN.add(gluon.nn.Activation('relu'))
    #second layer
    DQN.add(gluon.nn.Conv2D(channels=64, kernel_size=4,strides = 2))
    DQN.add(gluon.nn.BatchNorm(axis = 1, momentum = 0.1,center=True))
    DQN.add(gluon.nn.Activation('relu'))
    #tird layer
    DQN.add(gluon.nn.Conv2D(channels=64, kernel_size=3,strides = 1))
    DQN.add(gluon.nn.BatchNorm(axis = 1, momentum = 0.1,center=True))
    DQN.add(gluon.nn.Activation('relu'))
    DQN.add(gluon.nn.Flatten())
    #fourth layer
    DQN.add(gluon.nn.Dense(512,activation ='relu'))
    #fifth layer
    DQN.add(gluon.nn.Dense(num_action,activation ='relu'))

dqn = DQN
dqn.collect_params().initialize(mx.init.Normal(0.02), ctx=opt.ctx)
DQN_trainer = gluon.Trainer(dqn.collect_params(),'RMSProp', \
                          {'learning_rate': opt.lr ,'gamma1':opt.gamma1,'gamma2': opt.gamma2,'epsilon': opt.rms_eps,'centered' : True})
dqn.collect_params().zero_grad()

# %%
Target_DQN = gluon.nn.Sequential()
with Target_DQN.name_scope():
    #first layer
    Target_DQN.add(gluon.nn.Conv2D(channels=32, kernel_size=8,strides = 4,padding = 0))
    Target_DQN.add(gluon.nn.BatchNorm(axis = 1, momentum = 0.1,center=True))
    Target_DQN.add(gluon.nn.Activation('relu'))
    #second layer
    Target_DQN.add(gluon.nn.Conv2D(channels=64, kernel_size=4,strides = 2))
    Target_DQN.add(gluon.nn.BatchNorm(axis = 1, momentum = 0.1,center=True))
    Target_DQN.add(gluon.nn.Activation('relu'))
    #tird layer
    Target_DQN.add(gluon.nn.Conv2D(channels=64, kernel_size=3,strides = 1))
    Target_DQN.add(gluon.nn.BatchNorm(axis = 1, momentum = 0.1,center=True))
    Target_DQN.add(gluon.nn.Activation('relu'))
    Target_DQN.add(gluon.nn.Flatten())
    #fourth layer
    Target_DQN.add(gluon.nn.Dense(512,activation ='relu'))
    #fifth layer
    Target_DQN.add(gluon.nn.Dense(num_action,activation ='relu'))
target_dqn = Target_DQN
target_dqn.collect_params().initialize(mx.init.Normal(0.02), ctx=opt.ctx)

# %% [markdown]
# ### Replay buffer
# Replay buffer store the tuple of : `state`, action , `next_state`, reward , done.

# %%
Transition = namedtuple('Transition',('state', 'action', 'next_state', 'reward','done'))
class Replay_Buffer():
    def __init__(self, replay_buffer_size):
        self.replay_buffer_size = replay_buffer_size
        self.memory = []
        self.position = 0
    def push(self, *args):
        if len(self.memory) < self.replay_buffer_size:
            self.memory.append(None)
        self.memory[self.position] = Transition(*args)
        self.position = (self.position + 1) % self.replay_buffer_size
    def sample(self, batch_size):
        return random.sample(self.memory, batch_size)

# %% [markdown]
# ### Preprocess frames
# * Take a frame, average over the `RGB` filter and append it to the `state` to construct `next_state`
# * Clip the reward
# * Render the frames

# %%
def preprocess(raw_frame, currentState = None, initial_state = False):
    raw_frame = nd.array(raw_frame,mx.cpu())
    raw_frame = nd.reshape(nd.mean(raw_frame, axis = 2),shape = (raw_frame.shape[0],raw_frame.shape[1],1))
    raw_frame = mx.image.imresize(raw_frame,  opt.image_size, opt.image_size)
    raw_frame = nd.transpose(raw_frame, (2,0,1))
    raw_frame = raw_frame.astype('float32')/255.
    if initial_state == True:
        state = raw_frame
        for _ in range(opt.frame_len-1):
            state = nd.concat(state , raw_frame, dim = 0)
    else:
        state = mx.nd.concat(currentState[1:,:,:], raw_frame, dim = 0)
    return state

def rew_clipper(rew):
    if rew>0.:
        return 1.
    elif rew<0.:
        return -1.
    else:
        return 0

def renderimage(next_frame):
    if render_image:
        plt.imshow(next_frame);
        plt.show()
        display.clear_output(wait=True)
        time.sleep(.1)
        
l2loss = gluon.loss.L2Loss(batch_axis=0)

# %% [markdown]
# ### Initialize arrays

# %%
frame_counter = 0. # Counts the number of steps so far
annealing_count = 0. # Counts the number of annealing steps
epis_count = 0. # Counts the number episodes so far
replay_memory = Replay_Buffer(opt.replay_buffer_size) # Initialize the replay buffer
tot_clipped_reward = np.zeros(opt.num_episode) 
tot_reward = np.zeros(opt.num_episode)
moving_average_clipped = 0.
moving_average = 0.

# %% [markdown]
# ### Train the model

# %%
render_image = False # Whether to render Frames and show the game
batch_state = nd.empty((opt.batch_size,opt.frame_len,opt.image_size,opt.image_size), opt.ctx)
batch_state_next = nd.empty((opt.batch_size,opt.frame_len,opt.image_size,opt.image_size), opt.ctx)
for i in range(opt.num_episode):
    cum_clipped_reward = 0
    cum_reward = 0
    next_frame = env.reset()
    state = preprocess(next_frame, initial_state = True)
    t = 0.
    done = False
    

    while not done:
        previous_state = state
        # show the frame
        renderimage(next_frame)
        sample = random.random()
        if frame_counter > opt.replay_start_size:
            annealing_count += 1
        if frame_counter == opt.replay_start_size:
            print('annealing and laerning are started ')
            
            
        
        eps = np.maximum(1.-annealing_count/opt.annealing_end,opt.epsilon_min)
        effective_eps = eps
        if t < opt.no_op_max:
            effective_eps = 1.
        
        # epsilon greedy policy
        if sample < effective_eps:
            action = random.randint(0, num_action - 1)
        else:
            data = nd.array(state.reshape([1,opt.frame_len,opt.image_size,opt.image_size]),opt.ctx)
            action = int(nd.argmax(dqn(data),axis=1).as_in_context(mx.cpu()).asscalar())
        
        # Skip frame
        rew = 0
        for skip in range(opt.skip_frame-1):
            next_frame, reward, done,_ = env.step(action)
            renderimage(next_frame)
            cum_clipped_reward += rew_clipper(reward)
            rew += reward
            for internal_skip in range(opt.internal_skip_frame-1):
                _ , reward, done,_ = env.step(action)
                cum_clipped_reward += rew_clipper(reward)
                rew += reward
                
        next_frame_new, reward, done, _ = env.step(action)
        renderimage(next_frame)
        cum_clipped_reward += rew_clipper(reward)
        rew += reward
        cum_reward += rew
        
        # Reward clipping
        reward = rew_clipper(rew)
        next_frame = np.maximum(next_frame_new,next_frame)
        state = preprocess(next_frame, state)
        replay_memory.push((previous_state*255.).astype('uint8'),action,(state*255.).astype('uint8'),reward,done)
        # Train
        if frame_counter > opt.replay_start_size:        
            if frame_counter % opt.learning_frequency == 0:
                transitions = replay_memory.sample(opt.batch_size)
                batch = Transition(*zip(*transitions))
                for j in range(opt.batch_size):
                    batch_state[j] = nd.array(batch.state[j],opt.ctx).astype('float32')/255.
                    batch_state_next[j] = nd.array(batch.next_state[j],opt.ctx).astype('float32')/255.
                batch_reward = nd.array(batch.reward,opt.ctx)
                batch_action = nd.array(batch.action,opt.ctx).astype('uint8')
                batch_done = nd.array(batch.done,opt.ctx)
                with autograd.record():
                    Q_sp = nd.max(target_dqn(batch_state_next),axis = 1)
                    Q_sp = Q_sp*(nd.ones(opt.batch_size,ctx = opt.ctx)-batch_done)
                    Q_s_array = dqn(batch_state)
                    Q_s = nd.pick(Q_s_array,batch_action,1)
                    loss = nd.mean(l2loss(Q_s ,  (batch_reward + opt.gamma *Q_sp)))
                loss.backward()
                DQN_trainer.step(opt.batch_size)
                
        

        
        t += 1
        frame_counter += 1
        
        # Save the model and update Target model
        if frame_counter > opt.replay_start_size:
            if frame_counter % opt.Target_update == 0 :
                check_point = frame_counter / (opt.Target_update *100)
                fdqn = './target_%s_%d' % (env_name,int(check_point))
                dqn.save_params(fdqn)
                target_dqn.load_params(fdqn, opt.ctx)
        if done:
            if epis_count % 10. == 0. :
                results = 'epis[%d],eps[%f],durat[%d],fnum=%d, cum_cl_rew = %d, cum_rew = %d,tot_cl = %d , tot = %d'\
                  %(epis_count,eps,t+1,frame_counter,cum_clipped_reward,cum_reward,moving_average_clipped,moving_average)
                print(results)
                f.write('\n' + results)
    epis_count += 1
    tot_clipped_reward[int(epis_count)-1] = cum_clipped_reward
    tot_reward[int(epis_count)-1] = cum_reward
    if epis_count > 50.:
        moving_average_clipped = np.mean(tot_clipped_reward[int(epis_count)-1-50:int(epis_count)-1])
        moving_average = np.mean(tot_reward[int(epis_count)-1-50:int(epis_count)-1])
f.close()
from tempfile import TemporaryFile
outfile = TemporaryFile()
outfile_clip = TemporaryFile()
np.save(outfile, moving_average)
np.save(outfile_clip, moving_average_clipped)
# Out:
# epis[0],eps[1.000000],durat[376],fnum=375, cum_cl_rew = 15, cum_rew = 315,tot_cl = 0 , tot = 0
# epis[10],eps[1.000000],durat[353],fnum=2959, cum_cl_rew = 13, cum_rew = 273,tot_cl = 0 , tot = 0
# epis[20],eps[1.000000],durat[151],fnum=5981, cum_cl_rew = 3, cum_rew = 63,tot_cl = 0 , tot = 0
# epis[30],eps[1.000000],durat[278],fnum=8354, cum_cl_rew = 8, cum_rew = 168,tot_cl = 0 , tot = 0
# epis[40],eps[1.000000],durat[240],fnum=10861, cum_cl_rew = 12, cum_rew = 252,tot_cl = 0 , tot = 0
# epis[50],eps[1.000000],durat[228],fnum=13609, cum_cl_rew = 9, cum_rew = 189,tot_cl = 0 , tot = 0
# epis[60],eps[1.000000],durat[258],fnum=16169, cum_cl_rew = 12, cum_rew = 252,tot_cl = 8 , tot = 185
# epis[70],eps[1.000000],durat[337],fnum=18938, cum_cl_rew = 8, cum_rew = 168,tot_cl = 8 , tot = 179
# epis[80],eps[1.000000],durat[289],fnum=21820, cum_cl_rew = 9, cum_rew = 189,tot_cl = 9 , tot = 194
# epis[90],eps[1.000000],durat[432],fnum=24464, cum_cl_rew = 9, cum_rew = 189,tot_cl = 9 , tot = 196
# epis[100],eps[1.000000],durat[289],fnum=27372, cum_cl_rew = 15, cum_rew = 315,tot_cl = 9 , tot = 190
# epis[110],eps[1.000000],durat[189],fnum=29923, cum_cl_rew = 9, cum_rew = 189,tot_cl = 9 , tot = 199
# epis[120],eps[1.000000],durat[319],fnum=32845, cum_cl_rew = 13, cum_rew = 273,tot_cl = 9 , tot = 200
# epis[130],eps[1.000000],durat[299],fnum=35185, cum_cl_rew = 9, cum_rew = 189,tot_cl = 9 , tot = 196
# epis[140],eps[1.000000],durat[248],fnum=37708, cum_cl_rew = 9, cum_rew = 189,tot_cl = 9 , tot = 198
# epis[150],eps[1.000000],durat[268],fnum=40413, cum_cl_rew = 11, cum_rew = 231,tot_cl = 9 , tot = 196
# epis[160],eps[1.000000],durat[189],fnum=43198, cum_cl_rew = 6, cum_rew = 126,tot_cl = 9 , tot = 204
# epis[170],eps[1.000000],durat[284],fnum=45712, cum_cl_rew = 11, cum_rew = 231,tot_cl = 9 , tot = 196
# epis[180],eps[1.000000],durat[208],fnum=48258, cum_cl_rew = 9, cum_rew = 189,tot_cl = 9 , tot = 194
# annealing and laerning are started
# epis[190],eps[0.999137],durat[255],fnum=50864, cum_cl_rew = 14, cum_rew = 294,tot_cl = 9 , tot = 197
# epis[200],eps[0.996462],durat[255],fnum=53539, cum_cl_rew = 5, cum_rew = 105,tot_cl = 10 , tot = 214
# epis[210],eps[0.993953],durat[319],fnum=56048, cum_cl_rew = 9, cum_rew = 189,tot_cl = 9 , tot = 196
# epis[220],eps[0.991462],durat[282],fnum=58539, cum_cl_rew = 5, cum_rew = 105,tot_cl = 9 , tot = 201
# epis[230],eps[0.988471],durat[289],fnum=61530, cum_cl_rew = 10, cum_rew = 210,tot_cl = 9 , tot = 207
# epis[240],eps[0.986129],durat[91],fnum=63872, cum_cl_rew = 2, cum_rew = 42,tot_cl = 9 , tot = 207
# epis[250],eps[0.983426],durat[353],fnum=66575, cum_cl_rew = 14, cum_rew = 294,tot_cl = 9 , tot = 191
# epis[260],eps[0.980893],durat[255],fnum=69108, cum_cl_rew = 5, cum_rew = 105,tot_cl = 9 , tot = 201
# epis[270],eps[0.978346],durat[164],fnum=71655, cum_cl_rew = 6, cum_rew = 126,tot_cl = 9 , tot = 202
# epis[280],eps[0.975555],durat[311],fnum=74446, cum_cl_rew = 8, cum_rew = 168,tot_cl = 9 , tot = 203
# epis[290],eps[0.972722],durat[307],fnum=77279, cum_cl_rew = 11, cum_rew = 231,tot_cl = 9 , tot = 199
# epis[300],eps[0.969813],durat[201],fnum=80188, cum_cl_rew = 9, cum_rew = 189,tot_cl = 10 , tot = 210
# epis[310],eps[0.966842],durat[420],fnum=83159, cum_cl_rew = 19, cum_rew = 399,tot_cl = 10 , tot = 210
# epis[320],eps[0.964208],durat[265],fnum=85793, cum_cl_rew = 5, cum_rew = 105,tot_cl = 10 , tot = 216
# epis[330],eps[0.961900],durat[284],fnum=88101, cum_cl_rew = 9, cum_rew = 189,tot_cl = 9 , tot = 202
# epis[340],eps[0.959139],durat[321],fnum=90862, cum_cl_rew = 10, cum_rew = 210,tot_cl = 9 , tot = 204
# epis[350],eps[0.956566],durat[199],fnum=93435, cum_cl_rew = 7, cum_rew = 147,tot_cl = 9 , tot = 197
# epis[360],eps[0.953683],durat[457],fnum=96318, cum_cl_rew = 16, cum_rew = 336,tot_cl = 9 , tot = 190
# epis[370],eps[0.951128],durat[137],fnum=98873, cum_cl_rew = 3, cum_rew = 63,tot_cl = 9 , tot = 189
# epis[380],eps[0.948256],durat[302],fnum=101745, cum_cl_rew = 8, cum_rew = 168,tot_cl = 9 , tot = 200
# epis[390],eps[0.945646],durat[100],fnum=104355, cum_cl_rew = 5, cum_rew = 105,tot_cl = 9 , tot = 196
# epis[400],eps[0.942972],durat[223],fnum=107029, cum_cl_rew = 9, cum_rew = 189,tot_cl = 9 , tot = 194
# epis[410],eps[0.940475],durat[331],fnum=109526, cum_cl_rew = 11, cum_rew = 231,tot_cl = 9 , tot = 195
# epis[420],eps[0.937546],durat[427],fnum=112455, cum_cl_rew = 8, cum_rew = 168,tot_cl = 9 , tot = 196
# epis[430],eps[0.935084],durat[151],fnum=114917, cum_cl_rew = 4, cum_rew = 84,tot_cl = 9 , tot = 194
# epis[440],eps[0.932390],durat[338],fnum=117611, cum_cl_rew = 10, cum_rew = 210,tot_cl = 9 , tot = 196
# epis[450],eps[0.929455],durat[385],fnum=120546, cum_cl_rew = 11, cum_rew = 231,tot_cl = 9 , tot = 194
# epis[460],eps[0.926680],durat[363],fnum=123321, cum_cl_rew = 9, cum_rew = 189,tot_cl = 9 , tot = 197
# epis[470],eps[0.923914],durat[173],fnum=126087, cum_cl_rew = 6, cum_rew = 126,tot_cl = 9 , tot = 193
# epis[480],eps[0.921238],durat[297],fnum=128763, cum_cl_rew = 13, cum_rew = 273,tot_cl = 8 , tot = 188
# epis[490],eps[0.918302],durat[269],fnum=131699, cum_cl_rew = 11, cum_rew = 231,tot_cl = 9 , tot = 196
# epis[500],eps[0.915716],durat[228],fnum=134285, cum_cl_rew = 9, cum_rew = 189,tot_cl = 9 , tot = 202
# epis[510],eps[0.912700],durat[326],fnum=137301, cum_cl_rew = 10, cum_rew = 210,tot_cl = 9 , tot = 203
# epis[520],eps[0.910630],durat[179],fnum=139371, cum_cl_rew = 9, cum_rew = 189,tot_cl = 9 , tot = 196
# epis[530],eps[0.908041],durat[334],fnum=141960, cum_cl_rew = 15, cum_rew = 315,tot_cl = 9 , tot = 196
# epis[540],eps[0.905487],durat[260],fnum=144514, cum_cl_rew = 7, cum_rew = 147,tot_cl = 8 , tot = 187
# epis[550],eps[0.902352],durat[287],fnum=147649, cum_cl_rew = 11, cum_rew = 231,tot_cl = 9 , tot = 191
# epis[560],eps[0.899991],durat[209],fnum=150010, cum_cl_rew = 5, cum_rew = 105,tot_cl = 8 , tot = 186
# epis[570],eps[0.897366],durat[274],fnum=152635, cum_cl_rew = 9, cum_rew = 189,tot_cl = 9 , tot = 191
# epis[580],eps[0.894490],durat[265],fnum=155511, cum_cl_rew = 9, cum_rew = 189,tot_cl = 9 , tot = 203
# epis[590],eps[0.890956],durat[277],fnum=159045, cum_cl_rew = 11, cum_rew = 231,tot_cl = 10 , tot = 224
# epis[600],eps[0.888596],durat[179],fnum=161405, cum_cl_rew = 6, cum_rew = 126,tot_cl = 10 , tot = 219
# epis[610],eps[0.885664],durat[228],fnum=164337, cum_cl_rew = 9, cum_rew = 189,tot_cl = 10 , tot = 224
# epis[620],eps[0.882778],durat[378],fnum=167223, cum_cl_rew = 13, cum_rew = 273,tot_cl = 10 , tot = 225
# epis[630],eps[0.880161],durat[346],fnum=169840, cum_cl_rew = 11, cum_rew = 231,tot_cl = 10 , tot = 220
# epis[640],eps[0.877635],durat[218],fnum=172366, cum_cl_rew = 9, cum_rew = 189,tot_cl = 9 , tot = 196
# epis[650],eps[0.874612],durat[218],fnum=175389, cum_cl_rew = 5, cum_rew = 105,tot_cl = 9 , tot = 206
# epis[660],eps[0.871704],durat[260],fnum=178297, cum_cl_rew = 9, cum_rew = 189,tot_cl = 10 , tot = 212
# epis[670],eps[0.868815],durat[299],fnum=181186, cum_cl_rew = 12, cum_rew = 252,tot_cl = 10 , tot = 217
# epis[680],eps[0.866155],durat[150],fnum=183846, cum_cl_rew = 6, cum_rew = 126,tot_cl = 10 , tot = 228
# epis[690],eps[0.863296],durat[378],fnum=186705, cum_cl_rew = 9, cum_rew = 189,tot_cl = 11 , tot = 238
# epis[700],eps[0.860623],durat[248],fnum=189378, cum_cl_rew = 13, cum_rew = 273,tot_cl = 11 , tot = 238
# epis[710],eps[0.858106],durat[287],fnum=191895, cum_cl_rew = 9, cum_rew = 189,tot_cl = 10 , tot = 226
# epis[720],eps[0.855475],durat[333],fnum=194526, cum_cl_rew = 13, cum_rew = 273,tot_cl = 10 , tot = 229
# epis[730],eps[0.853094],durat[250],fnum=196907, cum_cl_rew = 9, cum_rew = 189,tot_cl = 10 , tot = 217
# epis[740],eps[0.850466],durat[267],fnum=199535, cum_cl_rew = 14, cum_rew = 294,tot_cl = 10 , tot = 222
# epis[750],eps[0.848141],durat[164],fnum=201860, cum_cl_rew = 5, cum_rew = 105,tot_cl = 10 , tot = 218
# epis[760],eps[0.845946],durat[272],fnum=204055, cum_cl_rew = 12, cum_rew = 252,tot_cl = 10 , tot = 222
# epis[770],eps[0.843472],durat[248],fnum=206529, cum_cl_rew = 13, cum_rew = 273,tot_cl = 10 , tot = 220
# epis[780],eps[0.841346],durat[282],fnum=208655, cum_cl_rew = 19, cum_rew = 399,tot_cl = 10 , tot = 225
# epis[790],eps[0.838930],durat[225],fnum=211071, cum_cl_rew = 9, cum_rew = 189,tot_cl = 10 , tot = 223
# epis[800],eps[0.836507],durat[189],fnum=213494, cum_cl_rew = 9, cum_rew = 189,tot_cl = 10 , tot = 228
# epis[810],eps[0.834236],durat[304],fnum=215765, cum_cl_rew = 10, cum_rew = 210,tot_cl = 10 , tot = 228
# epis[820],eps[0.831863],durat[317],fnum=218138, cum_cl_rew = 18, cum_rew = 378,tot_cl = 11 , tot = 231
# epis[830],eps[0.829303],durat[238],fnum=220698, cum_cl_rew = 12, cum_rew = 252,tot_cl = 11 , tot = 235
# epis[840],eps[0.826615],durat[329],fnum=223386, cum_cl_rew = 14, cum_rew = 294,tot_cl = 11 , tot = 244
# epis[850],eps[0.824299],durat[268],fnum=225702, cum_cl_rew = 17, cum_rew = 357,tot_cl = 11 , tot = 242
# epis[860],eps[0.821840],durat[218],fnum=228161, cum_cl_rew = 11, cum_rew = 231,tot_cl = 12 , tot = 254
# epis[870],eps[0.819419],durat[203],fnum=230582, cum_cl_rew = 14, cum_rew = 294,tot_cl = 12 , tot = 258
# epis[880],eps[0.817004],durat[245],fnum=232997, cum_cl_rew = 15, cum_rew = 315,tot_cl = 12 , tot = 260
# epis[890],eps[0.814697],durat[269],fnum=235304, cum_cl_rew = 16, cum_rew = 336,tot_cl = 12 , tot = 261
# epis[900],eps[0.812260],durat[199],fnum=237741, cum_cl_rew = 5, cum_rew = 105,tot_cl = 13 , tot = 273
# epis[910],eps[0.809736],durat[208],fnum=240265, cum_cl_rew = 4, cum_rew = 84,tot_cl = 12 , tot = 266
# epis[920],eps[0.807360],durat[237],fnum=242641, cum_cl_rew = 11, cum_rew = 231,tot_cl = 12 , tot = 271
# epis[930],eps[0.805068],durat[199],fnum=244933, cum_cl_rew = 9, cum_rew = 189,tot_cl = 13 , tot = 278
# epis[940],eps[0.802925],durat[237],fnum=247076, cum_cl_rew = 16, cum_rew = 336,tot_cl = 12 , tot = 272
# epis[950],eps[0.800594],durat[252],fnum=249407, cum_cl_rew = 14, cum_rew = 294,tot_cl = 12 , tot = 269
# epis[960],eps[0.798365],durat[191],fnum=251636, cum_cl_rew = 9, cum_rew = 189,tot_cl = 13 , tot = 277
# epis[970],eps[0.795861],durat[142],fnum=254140, cum_cl_rew = 9, cum_rew = 189,tot_cl = 13 , tot = 280
# epis[980],eps[0.793551],durat[238],fnum=256450, cum_cl_rew = 12, cum_rew = 252,tot_cl = 13 , tot = 283
# epis[990],eps[0.791231],durat[160],fnum=258770, cum_cl_rew = 5, cum_rew = 105,tot_cl = 13 , tot = 284
# epis[1000],eps[0.788825],durat[267],fnum=261176, cum_cl_rew = 19, cum_rew = 399,tot_cl = 13 , tot = 281
# epis[1010],eps[0.786457],durat[274],fnum=263544, cum_cl_rew = 13, cum_rew = 273,tot_cl = 13 , tot = 284
# epis[1020],eps[0.784212],durat[183],fnum=265789, cum_cl_rew = 9, cum_rew = 189,tot_cl = 12 , tot = 271
# epis[1030],eps[0.781851],durat[252],fnum=268150, cum_cl_rew = 18, cum_rew = 378,tot_cl = 12 , tot = 270
# epis[1040],eps[0.779687],durat[245],fnum=270314, cum_cl_rew = 15, cum_rew = 315,tot_cl = 13 , tot = 273
# epis[1050],eps[0.777411],durat[255],fnum=272590, cum_cl_rew = 14, cum_rew = 294,tot_cl = 13 , tot = 279
# epis[1060],eps[0.774904],durat[233],fnum=275097, cum_cl_rew = 11, cum_rew = 231,tot_cl = 13 , tot = 283
# epis[1070],eps[0.772906],durat[149],fnum=277095, cum_cl_rew = 11, cum_rew = 231,tot_cl = 13 , tot = 291
# epis[1080],eps[0.770611],durat[208],fnum=279390, cum_cl_rew = 9, cum_rew = 189,tot_cl = 13 , tot = 283
# epis[1090],eps[0.768425],durat[199],fnum=281576, cum_cl_rew = 9, cum_rew = 189,tot_cl = 13 , tot = 284
# epis[1100],eps[0.766400],durat[228],fnum=283601, cum_cl_rew = 15, cum_rew = 315,tot_cl = 12 , tot = 270
# epis[1110],eps[0.764021],durat[250],fnum=285980, cum_cl_rew = 9, cum_rew = 189,tot_cl = 12 , tot = 264
# epis[1120],eps[0.761675],durat[199],fnum=288326, cum_cl_rew = 16, cum_rew = 336,tot_cl = 12 , tot = 268
# epis[1130],eps[0.759268],durat[166],fnum=290733, cum_cl_rew = 11, cum_rew = 231,tot_cl = 13 , tot = 281
# epis[1140],eps[0.757069],durat[191],fnum=292932, cum_cl_rew = 17, cum_rew = 357,tot_cl = 13 , tot = 280
# epis[1150],eps[0.754935],durat[229],fnum=295066, cum_cl_rew = 22, cum_rew = 462,tot_cl = 13 , tot = 283
# epis[1160],eps[0.752519],durat[321],fnum=297482, cum_cl_rew = 19, cum_rew = 399,tot_cl = 14 , tot = 296
# epis[1170],eps[0.750223],durat[159],fnum=299778, cum_cl_rew = 8, cum_rew = 168,tot_cl = 14 , tot = 299
# epis[1180],eps[0.747816],durat[189],fnum=302185, cum_cl_rew = 13, cum_rew = 273,tot_cl = 14 , tot = 296
# epis[1190],eps[0.745770],durat[230],fnum=304231, cum_cl_rew = 14, cum_rew = 294,tot_cl = 14 , tot = 295
# epis[1200],eps[0.743622],durat[242],fnum=306379, cum_cl_rew = 20, cum_rew = 420,tot_cl = 14 , tot = 299
# epis[1210],eps[0.741356],durat[173],fnum=308645, cum_cl_rew = 9, cum_rew = 189,tot_cl = 14 , tot = 301
# epis[1220],eps[0.739171],durat[225],fnum=310830, cum_cl_rew = 12, cum_rew = 252,tot_cl = 14 , tot = 298
# epis[1230],eps[0.737120],durat[203],fnum=312881, cum_cl_rew = 23, cum_rew = 483,tot_cl = 13 , tot = 293
# epis[1240],eps[0.735119],durat[272],fnum=314882, cum_cl_rew = 11, cum_rew = 231,tot_cl = 13 , tot = 293
# epis[1250],eps[0.732950],durat[242],fnum=317051, cum_cl_rew = 15, cum_rew = 315,tot_cl = 14 , tot = 296
# epis[1260],eps[0.730889],durat[137],fnum=319112, cum_cl_rew = 8, cum_rew = 168,tot_cl = 13 , tot = 287
# epis[1270],eps[0.728681],durat[176],fnum=321320, cum_cl_rew = 5, cum_rew = 105,tot_cl = 13 , tot = 275
# epis[1280],eps[0.726500],durat[181],fnum=323501, cum_cl_rew = 16, cum_rew = 336,tot_cl = 13 , tot = 283
# epis[1290],eps[0.724429],durat[193],fnum=325572, cum_cl_rew = 15, cum_rew = 315,tot_cl = 13 , tot = 284
# epis[1300],eps[0.722452],durat[161],fnum=327549, cum_cl_rew = 17, cum_rew = 357,tot_cl = 13 , tot = 281
# epis[1310],eps[0.720187],durat[209],fnum=329814, cum_cl_rew = 10, cum_rew = 210,tot_cl = 13 , tot = 286
# epis[1320],eps[0.718159],durat[189],fnum=331842, cum_cl_rew = 13, cum_rew = 273,tot_cl = 13 , tot = 285
# epis[1330],eps[0.716203],durat[169],fnum=333798, cum_cl_rew = 15, cum_rew = 315,tot_cl = 12 , tot = 272
# epis[1340],eps[0.713882],durat[199],fnum=336119, cum_cl_rew = 9, cum_rew = 189,tot_cl = 12 , tot = 272
# epis[1350],eps[0.711824],durat[210],fnum=338177, cum_cl_rew = 19, cum_rew = 399,tot_cl = 13 , tot = 277
# epis[1360],eps[0.709669],durat[154],fnum=340332, cum_cl_rew = 10, cum_rew = 210,tot_cl = 12 , tot = 270
# epis[1370],eps[0.707608],durat[228],fnum=342393, cum_cl_rew = 17, cum_rew = 357,tot_cl = 13 , tot = 284
# epis[1380],eps[0.705636],durat[183],fnum=344365, cum_cl_rew = 12, cum_rew = 252,tot_cl = 13 , tot = 290
# epis[1390],eps[0.703370],durat[218],fnum=346631, cum_cl_rew = 13, cum_rew = 273,tot_cl = 14 , tot = 295
# epis[1400],eps[0.701194],durat[215],fnum=348807, cum_cl_rew = 12, cum_rew = 252,tot_cl = 14 , tot = 296
# epis[1410],eps[0.698830],durat[140],fnum=351171, cum_cl_rew = 8, cum_rew = 168,tot_cl = 14 , tot = 304
# epis[1420],eps[0.696792],durat[146],fnum=353209, cum_cl_rew = 9, cum_rew = 189,tot_cl = 14 , tot = 297
# epis[1430],eps[0.694797],durat[228],fnum=355204, cum_cl_rew = 15, cum_rew = 315,tot_cl = 14 , tot = 297
# epis[1440],eps[0.692653],durat[237],fnum=357348, cum_cl_rew = 23, cum_rew = 483,tot_cl = 14 , tot = 298
# epis[1450],eps[0.690588],durat[189],fnum=359413, cum_cl_rew = 12, cum_rew = 252,tot_cl = 14 , tot = 309
# epis[1460],eps[0.688127],durat[233],fnum=361874, cum_cl_rew = 15, cum_rew = 315,tot_cl = 14 , tot = 302
# epis[1470],eps[0.685837],durat[228],fnum=364164, cum_cl_rew = 17, cum_rew = 357,tot_cl = 14 , tot = 307
# epis[1480],eps[0.683606],durat[228],fnum=366395, cum_cl_rew = 16, cum_rew = 336,tot_cl = 15 , tot = 317
# epis[1490],eps[0.681733],durat[188],fnum=368268, cum_cl_rew = 9, cum_rew = 189,tot_cl = 14 , tot = 307
# epis[1500],eps[0.679744],durat[179],fnum=370257, cum_cl_rew = 11, cum_rew = 231,tot_cl = 14 , tot = 295
# epis[1510],eps[0.677538],durat[159],fnum=372463, cum_cl_rew = 13, cum_rew = 273,tot_cl = 14 , tot = 295
# epis[1520],eps[0.675204],durat[250],fnum=374797, cum_cl_rew = 20, cum_rew = 420,tot_cl = 14 , tot = 295
# epis[1530],eps[0.673165],durat[188],fnum=376836, cum_cl_rew = 14, cum_rew = 294,tot_cl = 13 , tot = 291
# epis[1540],eps[0.670862],durat[267],fnum=379139, cum_cl_rew = 21, cum_rew = 441,tot_cl = 14 , tot = 301
# epis[1550],eps[0.668790],durat[250],fnum=381211, cum_cl_rew = 21, cum_rew = 441,tot_cl = 14 , tot = 311
# epis[1560],eps[0.666655],durat[181],fnum=383346, cum_cl_rew = 12, cum_rew = 252,tot_cl = 14 , tot = 310
# epis[1570],eps[0.664513],durat[203],fnum=385488, cum_cl_rew = 16, cum_rew = 336,tot_cl = 14 , tot = 309
# epis[1580],eps[0.662395],durat[277],fnum=387606, cum_cl_rew = 15, cum_rew = 315,tot_cl = 14 , tot = 310
# epis[1590],eps[0.659921],durat[311],fnum=390080, cum_cl_rew = 28, cum_rew = 588,tot_cl = 15 , tot = 328
# epis[1600],eps[0.657717],durat[242],fnum=392284, cum_cl_rew = 18, cum_rew = 378,tot_cl = 15 , tot = 324
# epis[1610],eps[0.655800],durat[228],fnum=394201, cum_cl_rew = 18, cum_rew = 378,tot_cl = 14 , tot = 314
# epis[1620],eps[0.653686],durat[277],fnum=396315, cum_cl_rew = 15, cum_rew = 315,tot_cl = 15 , tot = 318
# epis[1630],eps[0.651472],durat[274],fnum=398529, cum_cl_rew = 16, cum_rew = 336,tot_cl = 15 , tot = 317
# epis[1640],eps[0.649574],durat[199],fnum=400427, cum_cl_rew = 16, cum_rew = 336,tot_cl = 14 , tot = 295
# epis[1650],eps[0.647355],durat[252],fnum=402646, cum_cl_rew = 16, cum_rew = 336,tot_cl = 14 , tot = 296
# epis[1660],eps[0.645351],durat[213],fnum=404650, cum_cl_rew = 19, cum_rew = 399,tot_cl = 15 , tot = 316
# epis[1670],eps[0.643093],durat[189],fnum=406908, cum_cl_rew = 12, cum_rew = 252,tot_cl = 15 , tot = 325
# epis[1680],eps[0.641026],durat[205],fnum=408975, cum_cl_rew = 15, cum_rew = 315,tot_cl = 15 , tot = 319
# epis[1690],eps[0.639179],durat[134],fnum=410822, cum_cl_rew = 7, cum_rew = 147,tot_cl = 15 , tot = 322
# epis[1700],eps[0.637115],durat[146],fnum=412886, cum_cl_rew = 10, cum_rew = 210,tot_cl = 15 , tot = 321
# epis[1710],eps[0.635086],durat[173],fnum=414915, cum_cl_rew = 13, cum_rew = 273,tot_cl = 14 , tot = 311
# epis[1720],eps[0.632987],durat[130],fnum=417014, cum_cl_rew = 10, cum_rew = 210,tot_cl = 14 , tot = 302
# epis[1730],eps[0.630632],durat[210],fnum=419369, cum_cl_rew = 13, cum_rew = 273,tot_cl = 15 , tot = 315
# epis[1740],eps[0.628598],durat[209],fnum=421403, cum_cl_rew = 12, cum_rew = 252,tot_cl = 15 , tot = 315
# epis[1750],eps[0.626489],durat[161],fnum=423512, cum_cl_rew = 14, cum_rew = 294,tot_cl = 14 , tot = 311
# epis[1760],eps[0.624261],durat[189],fnum=425740, cum_cl_rew = 9, cum_rew = 189,tot_cl = 15 , tot = 320
# epis[1770],eps[0.622322],durat[91],fnum=427679, cum_cl_rew = 8, cum_rew = 168,tot_cl = 15 , tot = 315
# epis[1780],eps[0.619786],durat[181],fnum=430215, cum_cl_rew = 13, cum_rew = 273,tot_cl = 15 , tot = 322
# epis[1790],eps[0.617712],durat[223],fnum=432289, cum_cl_rew = 20, cum_rew = 420,tot_cl = 15 , tot = 327
# epis[1800],eps[0.615478],durat[245],fnum=434523, cum_cl_rew = 17, cum_rew = 357,tot_cl = 15 , tot = 330
# epis[1810],eps[0.613540],durat[225],fnum=436461, cum_cl_rew = 20, cum_rew = 420,tot_cl = 15 , tot = 326
# epis[1820],eps[0.611291],durat[252],fnum=438710, cum_cl_rew = 14, cum_rew = 294,tot_cl = 15 , tot = 328
# epis[1830],eps[0.609162],durat[247],fnum=440839, cum_cl_rew = 20, cum_rew = 420,tot_cl = 14 , tot = 312
# epis[1840],eps[0.607122],durat[213],fnum=442879, cum_cl_rew = 14, cum_rew = 294,tot_cl = 14 , tot = 305
# epis[1850],eps[0.605012],durat[228],fnum=444989, cum_cl_rew = 11, cum_rew = 231,tot_cl = 15 , tot = 315
# epis[1860],eps[0.602731],durat[274],fnum=447270, cum_cl_rew = 22, cum_rew = 462,tot_cl = 15 , tot = 317
# epis[1870],eps[0.600587],durat[183],fnum=449414, cum_cl_rew = 10, cum_rew = 210,tot_cl = 15 , tot = 318
# epis[1880],eps[0.598708],durat[267],fnum=451293, cum_cl_rew = 16, cum_rew = 336,tot_cl = 14 , tot = 312
# epis[1890],eps[0.596413],durat[228],fnum=453588, cum_cl_rew = 18, cum_rew = 378,tot_cl = 15 , tot = 321
# epis[1900],eps[0.594444],durat[230],fnum=455557, cum_cl_rew = 18, cum_rew = 378,tot_cl = 14 , tot = 306
# epis[1910],eps[0.592241],durat[297],fnum=457760, cum_cl_rew = 29, cum_rew = 609,tot_cl = 14 , tot = 307
# epis[1920],eps[0.589957],durat[85],fnum=460044, cum_cl_rew = 4, cum_rew = 84,tot_cl = 15 , tot = 320
# epis[1930],eps[0.587994],durat[267],fnum=462007, cum_cl_rew = 20, cum_rew = 420,tot_cl = 15 , tot = 319
# epis[1940],eps[0.586038],durat[149],fnum=463963, cum_cl_rew = 12, cum_rew = 252,tot_cl = 15 , tot = 316
# epis[1950],eps[0.583776],durat[209],fnum=466225, cum_cl_rew = 18, cum_rew = 378,tot_cl = 15 , tot = 326
# epis[1960],eps[0.581799],durat[169],fnum=468202, cum_cl_rew = 10, cum_rew = 210,tot_cl = 15 , tot = 327
# epis[1970],eps[0.579402],durat[278],fnum=470599, cum_cl_rew = 28, cum_rew = 588,tot_cl = 15 , tot = 329
# epis[1980],eps[0.577316],durat[176],fnum=472685, cum_cl_rew = 17, cum_rew = 357,tot_cl = 16 , tot = 342
# epis[1990],eps[0.575257],durat[156],fnum=474744, cum_cl_rew = 13, cum_rew = 273,tot_cl = 16 , tot = 346
# epis[2000],eps[0.572977],durat[237],fnum=477024, cum_cl_rew = 17, cum_rew = 357,tot_cl = 16 , tot = 347
# epis[2010],eps[0.570850],durat[203],fnum=479151, cum_cl_rew = 14, cum_rew = 294,tot_cl = 16 , tot = 352
# epis[2020],eps[0.568600],durat[267],fnum=481401, cum_cl_rew = 21, cum_rew = 441,tot_cl = 16 , tot = 336
# epis[2030],eps[0.566675],durat[105],fnum=483326, cum_cl_rew = 8, cum_rew = 168,tot_cl = 16 , tot = 341
# epis[2040],eps[0.564400],durat[169],fnum=485601, cum_cl_rew = 15, cum_rew = 315,tot_cl = 16 , tot = 341
# epis[2050],eps[0.562279],durat[215],fnum=487722, cum_cl_rew = 16, cum_rew = 336,tot_cl = 15 , tot = 333
# epis[2060],eps[0.560149],durat[287],fnum=489852, cum_cl_rew = 24, cum_rew = 504,tot_cl = 15 , tot = 322
# epis[2070],eps[0.558034],durat[166],fnum=491967, cum_cl_rew = 13, cum_rew = 273,tot_cl = 15 , tot = 328
# epis[2080],eps[0.555900],durat[218],fnum=494101, cum_cl_rew = 11, cum_rew = 231,tot_cl = 15 , tot = 317
# epis[2090],eps[0.553975],durat[260],fnum=496026, cum_cl_rew = 19, cum_rew = 399,tot_cl = 14 , tot = 310
# epis[2100],eps[0.551945],durat[196],fnum=498056, cum_cl_rew = 11, cum_rew = 231,tot_cl = 15 , tot = 320
# epis[2110],eps[0.549965],durat[262],fnum=500036, cum_cl_rew = 22, cum_rew = 462,tot_cl = 15 , tot = 317
# epis[2120],eps[0.547828],durat[196],fnum=502173, cum_cl_rew = 17, cum_rew = 357,tot_cl = 15 , tot = 322
# epis[2130],eps[0.545730],durat[247],fnum=504271, cum_cl_rew = 23, cum_rew = 483,tot_cl = 15 , tot = 326
# epis[2140],eps[0.543580],durat[269],fnum=506421, cum_cl_rew = 21, cum_rew = 441,tot_cl = 15 , tot = 326
# epis[2150],eps[0.541294],durat[282],fnum=508707, cum_cl_rew = 21, cum_rew = 441,tot_cl = 15 , tot = 335
# epis[2160],eps[0.539402],durat[274],fnum=510599, cum_cl_rew = 21, cum_rew = 441,tot_cl = 16 , tot = 336
# epis[2170],eps[0.537679],durat[120],fnum=512322, cum_cl_rew = 9, cum_rew = 189,tot_cl = 15 , tot = 321
# epis[2180],eps[0.535407],durat[262],fnum=514594, cum_cl_rew = 12, cum_rew = 252,tot_cl = 15 , tot = 324
# epis[2190],eps[0.533103],durat[173],fnum=516898, cum_cl_rew = 11, cum_rew = 231,tot_cl = 16 , tot = 337
# epis[2200],eps[0.530928],durat[154],fnum=519073, cum_cl_rew = 10, cum_rew = 210,tot_cl = 15 , tot = 333
# epis[2210],eps[0.528839],durat[248],fnum=521162, cum_cl_rew = 16, cum_rew = 336,tot_cl = 16 , tot = 337
# epis[2220],eps[0.526668],durat[178],fnum=523333, cum_cl_rew = 14, cum_rew = 294,tot_cl = 16 , tot = 350
# epis[2230],eps[0.524655],durat[274],fnum=525346, cum_cl_rew = 20, cum_rew = 420,tot_cl = 16 , tot = 346
# epis[2240],eps[0.522533],durat[203],fnum=527468, cum_cl_rew = 13, cum_rew = 273,tot_cl = 16 , tot = 337
# epis[2250],eps[0.520522],durat[225],fnum=529479, cum_cl_rew = 19, cum_rew = 399,tot_cl = 15 , tot = 325
# epis[2260],eps[0.518560],durat[140],fnum=531441, cum_cl_rew = 12, cum_rew = 252,tot_cl = 15 , tot = 329
# epis[2270],eps[0.516444],durat[183],fnum=533557, cum_cl_rew = 16, cum_rew = 336,tot_cl = 15 , tot = 326
# epis[2280],eps[0.514205],durat[230],fnum=535796, cum_cl_rew = 19, cum_rew = 399,tot_cl = 15 , tot = 325
# epis[2290],eps[0.512157],durat[179],fnum=537844, cum_cl_rew = 20, cum_rew = 420,tot_cl = 15 , tot = 326
# epis[2300],eps[0.510132],durat[173],fnum=539869, cum_cl_rew = 16, cum_rew = 336,tot_cl = 15 , tot = 331
# epis[2310],eps[0.508045],durat[228],fnum=541956, cum_cl_rew = 11, cum_rew = 231,tot_cl = 15 , tot = 327
# epis[2320],eps[0.505925],durat[178],fnum=544076, cum_cl_rew = 10, cum_rew = 210,tot_cl = 15 , tot = 328
# epis[2330],eps[0.503677],durat[181],fnum=546324, cum_cl_rew = 13, cum_rew = 273,tot_cl = 15 , tot = 329
# epis[2340],eps[0.501525],durat[208],fnum=548476, cum_cl_rew = 13, cum_rew = 273,tot_cl = 15 , tot = 329
# epis[2350],eps[0.499565],durat[179],fnum=550436, cum_cl_rew = 16, cum_rew = 336,tot_cl = 15 , tot = 328
# epis[2360],eps[0.497334],durat[278],fnum=552667, cum_cl_rew = 23, cum_rew = 483,tot_cl = 16 , tot = 338
# epis[2370],eps[0.495452],durat[178],fnum=554549, cum_cl_rew = 10, cum_rew = 210,tot_cl = 16 , tot = 337
# epis[2380],eps[0.493374],durat[278],fnum=556627, cum_cl_rew = 25, cum_rew = 525,tot_cl = 16 , tot = 339
# epis[2390],eps[0.491363],durat[220],fnum=558638, cum_cl_rew = 12, cum_rew = 252,tot_cl = 16 , tot = 337
# epis[2400],eps[0.489076],durat[213],fnum=560925, cum_cl_rew = 18, cum_rew = 378,tot_cl = 16 , tot = 337
# epis[2410],eps[0.486957],durat[206],fnum=563044, cum_cl_rew = 13, cum_rew = 273,tot_cl = 15 , tot = 327
# epis[2420],eps[0.484958],durat[223],fnum=565043, cum_cl_rew = 19, cum_rew = 399,tot_cl = 15 , tot = 324
# epis[2430],eps[0.483039],durat[188],fnum=566962, cum_cl_rew = 14, cum_rew = 294,tot_cl = 15 , tot = 315
# epis[2440],eps[0.480581],durat[209],fnum=569420, cum_cl_rew = 9, cum_rew = 189,tot_cl = 15 , tot = 324
# epis[2450],eps[0.478433],durat[218],fnum=571568, cum_cl_rew = 16, cum_rew = 336,tot_cl = 15 , tot = 317
# epis[2460],eps[0.476666],durat[189],fnum=573335, cum_cl_rew = 9, cum_rew = 189,tot_cl = 14 , tot = 314
# epis[2470],eps[0.474705],durat[208],fnum=575296, cum_cl_rew = 19, cum_rew = 399,tot_cl = 14 , tot = 310
# epis[2480],eps[0.472510],durat[292],fnum=577491, cum_cl_rew = 24, cum_rew = 504,tot_cl = 15 , tot = 323
# epis[2490],eps[0.470389],durat[178],fnum=579612, cum_cl_rew = 13, cum_rew = 273,tot_cl = 15 , tot = 316
# epis[2500],eps[0.468327],durat[189],fnum=581674, cum_cl_rew = 18, cum_rew = 378,tot_cl = 15 , tot = 323
# epis[2510],eps[0.466344],durat[237],fnum=583657, cum_cl_rew = 17, cum_rew = 357,tot_cl = 15 , tot = 323
# epis[2520],eps[0.464037],durat[199],fnum=585964, cum_cl_rew = 14, cum_rew = 294,tot_cl = 15 , tot = 331
# epis[2530],eps[0.461791],durat[252],fnum=588210, cum_cl_rew = 20, cum_rew = 420,tot_cl = 15 , tot = 324
# epis[2540],eps[0.459874],durat[201],fnum=590127, cum_cl_rew = 11, cum_rew = 231,tot_cl = 15 , tot = 326
# epis[2550],eps[0.457631],durat[210],fnum=592370, cum_cl_rew = 19, cum_rew = 399,tot_cl = 15 , tot = 326
# epis[2560],eps[0.455395],durat[186],fnum=594606, cum_cl_rew = 11, cum_rew = 231,tot_cl = 16 , tot = 339
# epis[2570],eps[0.453418],durat[206],fnum=596583, cum_cl_rew = 19, cum_rew = 399,tot_cl = 16 , tot = 344
# epis[2580],eps[0.451600],durat[213],fnum=598401, cum_cl_rew = 20, cum_rew = 420,tot_cl = 16 , tot = 341
# epis[2590],eps[0.449561],durat[191],fnum=600440, cum_cl_rew = 12, cum_rew = 252,tot_cl = 16 , tot = 340
# epis[2600],eps[0.447519],durat[230],fnum=602482, cum_cl_rew = 19, cum_rew = 399,tot_cl = 16 , tot = 336
# epis[2610],eps[0.445299],durat[183],fnum=604702, cum_cl_rew = 14, cum_rew = 294,tot_cl = 15 , tot = 333
# epis[2620],eps[0.443310],durat[213],fnum=606691, cum_cl_rew = 18, cum_rew = 378,tot_cl = 15 , tot = 325
# epis[2630],eps[0.441329],durat[191],fnum=608672, cum_cl_rew = 18, cum_rew = 378,tot_cl = 15 , tot = 330
# epis[2640],eps[0.439065],durat[179],fnum=610936, cum_cl_rew = 18, cum_rew = 378,tot_cl = 15 , tot = 335
# epis[2650],eps[0.436949],durat[171],fnum=613052, cum_cl_rew = 5, cum_rew = 105,tot_cl = 16 , tot = 342
# epis[2660],eps[0.435008],durat[213],fnum=614993, cum_cl_rew = 15, cum_rew = 315,tot_cl = 15 , tot = 332
# epis[2670],eps[0.432759],durat[225],fnum=617242, cum_cl_rew = 17, cum_rew = 357,tot_cl = 16 , tot = 340
# epis[2680],eps[0.430616],durat[268],fnum=619385, cum_cl_rew = 19, cum_rew = 399,tot_cl = 16 , tot = 340
# epis[2690],eps[0.428530],durat[278],fnum=621471, cum_cl_rew = 18, cum_rew = 378,tot_cl = 16 , tot = 338
# epis[2700],eps[0.426664],durat[137],fnum=623337, cum_cl_rew = 9, cum_rew = 189,tot_cl = 15 , tot = 334
# epis[2710],eps[0.424455],durat[166],fnum=625546, cum_cl_rew = 10, cum_rew = 210,tot_cl = 16 , tot = 339
# epis[2720],eps[0.422379],durat[164],fnum=627622, cum_cl_rew = 14, cum_rew = 294,tot_cl = 16 , tot = 338
# epis[2730],eps[0.419962],durat[230],fnum=630039, cum_cl_rew = 21, cum_rew = 441,tot_cl = 16 , tot = 353
# epis[2740],eps[0.417857],durat[159],fnum=632144, cum_cl_rew = 12, cum_rew = 252,tot_cl = 16 , tot = 346
# epis[2750],eps[0.415316],durat[228],fnum=634685, cum_cl_rew = 17, cum_rew = 357,tot_cl = 16 , tot = 354
# epis[2760],eps[0.413432],durat[210],fnum=636569, cum_cl_rew = 19, cum_rew = 399,tot_cl = 16 , tot = 341
# epis[2770],eps[0.411022],durat[249],fnum=638979, cum_cl_rew = 21, cum_rew = 441,tot_cl = 15 , tot = 334
# epis[2780],eps[0.409084],durat[179],fnum=640917, cum_cl_rew = 12, cum_rew = 252,tot_cl = 14 , tot = 309
# epis[2790],eps[0.407022],durat[161],fnum=642979, cum_cl_rew = 9, cum_rew = 189,tot_cl = 14 , tot = 306
# epis[2800],eps[0.405158],durat[178],fnum=644843, cum_cl_rew = 19, cum_rew = 399,tot_cl = 14 , tot = 296
# epis[2810],eps[0.402988],durat[260],fnum=647013, cum_cl_rew = 18, cum_rew = 378,tot_cl = 15 , tot = 316
# epis[2820],eps[0.400963],durat[196],fnum=649038, cum_cl_rew = 14, cum_rew = 294,tot_cl = 15 , tot = 327
# epis[2830],eps[0.399001],durat[160],fnum=651000, cum_cl_rew = 14, cum_rew = 294,tot_cl = 15 , tot = 329
# epis[2840],eps[0.396821],durat[205],fnum=653180, cum_cl_rew = 13, cum_rew = 273,tot_cl = 16 , tot = 338
# epis[2850],eps[0.394903],durat[196],fnum=655098, cum_cl_rew = 16, cum_rew = 336,tot_cl = 15 , tot = 334
# epis[2860],eps[0.392823],durat[130],fnum=657178, cum_cl_rew = 9, cum_rew = 189,tot_cl = 15 , tot = 324
# epis[2870],eps[0.390717],durat[304],fnum=659284, cum_cl_rew = 28, cum_rew = 588,tot_cl = 14 , tot = 314
# epis[2880],eps[0.388607],durat[213],fnum=661394, cum_cl_rew = 10, cum_rew = 210,tot_cl = 15 , tot = 318
# epis[2890],eps[0.386060],durat[260],fnum=663941, cum_cl_rew = 18, cum_rew = 378,tot_cl = 15 , tot = 324
# epis[2900],eps[0.384012],durat[242],fnum=665989, cum_cl_rew = 22, cum_rew = 462,tot_cl = 16 , tot = 338
# epis[2910],eps[0.381941],durat[201],fnum=668060, cum_cl_rew = 19, cum_rew = 399,tot_cl = 16 , tot = 341
# epis[2920],eps[0.379665],durat[265],fnum=670336, cum_cl_rew = 21, cum_rew = 441,tot_cl = 16 , tot = 351
# epis[2930],eps[0.377496],durat[166],fnum=672505, cum_cl_rew = 12, cum_rew = 252,tot_cl = 17 , tot = 368
# epis[2940],eps[0.375379],durat[220],fnum=674622, cum_cl_rew = 20, cum_rew = 420,tot_cl = 17 , tot = 358
# epis[2950],eps[0.373244],durat[262],fnum=676757, cum_cl_rew = 18, cum_rew = 378,tot_cl = 16 , tot = 355
# epis[2960],eps[0.371244],durat[218],fnum=678757, cum_cl_rew = 20, cum_rew = 420,tot_cl = 16 , tot = 353
# epis[2970],eps[0.368949],durat[178],fnum=681052, cum_cl_rew = 10, cum_rew = 210,tot_cl = 16 , tot = 347
# epis[2980],eps[0.366634],durat[287],fnum=683367, cum_cl_rew = 19, cum_rew = 399,tot_cl = 15 , tot = 332
# epis[2990],eps[0.364312],durat[198],fnum=685689, cum_cl_rew = 17, cum_rew = 357,tot_cl = 16 , tot = 340

# %% [markdown]
# ### Plot the overall performace

# %%
bandwidth = 250 # Moving average bandwidth
total_clipped = np.zeros(int(epis_count)-bandwidth)
total_rew = np.zeros(int(epis_count)-bandwidth)
for i in range(int(epis_count)-bandwidth):
    total_clipped[i] = np.sum(tot_clipped_reward[i:i+bandwidth])/bandwidth
    total_rew[i] = np.sum(tot_reward[i:i+bandwidth])/bandwidth
t = np.arange(int(epis_count)-bandwidth)
belplt = plt.plot(t,total_rew[0:int(epis_count)-bandwidth],"r", label = "Return")
plt.legend()#handles[likplt,belplt])
print('Running after %d number of episodes' %epis_count)
plt.xlabel("Number of episode")
plt.ylabel("Average Reward per episode")
plt.show()
likplt = plt.plot(t,total_clipped[0:opt.num_episode-bandwidth],"b", label = "Clipped Return")
plt.legend()#handles[likplt,belplt])
plt.xlabel("Number of episode")
plt.ylabel("Average clipped Reward per episode")
plt.show()
# Out:
# Running after 3000 number of episodes

# %% [markdown]
# ### Accumulated average reward after 1000 episodes of game Assault
# |![](./Assault.png)|![](./Assault-clipped.png)|
# |:---------------:|:---------------:|
# |Average reward|Average clipped reward|
