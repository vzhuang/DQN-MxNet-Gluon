# %% [markdown]
# ## DQN (Deep Q-Network)
# ### Function approximation Q-learning
# This tutorial walks through the implementation of deep Q networks (DQNs),
# an RL method which applies the function approximation capabilities of deep neural networks
# to problems in reinforcement learning.
# The model in this tutorial closely follows the work described in the paper
# [Human-level control through deep reinforcement learning](http://www.nature.com/nature/journal/v518/n7540/full/nature14236.html?foxtrotcallback=true), written by Volodomyr Mnih.
#
# To keep these chapters runnable
# by as many people as possible,
# on as many machines as possible,
# and with as few headaches as possible,
# we have so far avoided dependencies on external libraries
# (besides mxnet, numpy and matplotlib).
# However, in this case, we'll need to import the [OpenAI Gym](https://gym.openai.com/docs).
# That's because in reinforcement learning,
# instead of drawing examples from a data structure,
# our data comes from interactions with an environment.
# In this chapter, our environemnts will be classic Atari video games.
#
# ## Preliminaries
# The following code clones and installs the OpenAI gym.
# `git clone https://github.com/openai/gym ; cd gym ; pip install -e .[all]`
# Full documentation for the gym can be found on [at this website](https://gym.openai.com/).
# If you want to see reasonable results before the sun sets on your AI career,
# we suggest running these experiments on a server equipped with GPUs.

# %%
import mxnet as mx
from mxnet import nd, autograd
from mxnet import gluon
from __future__ import print_function
import os
import random
import numpy as np
import matplotlib.pyplot as plt
from IPython import display
import gym
import math
from collections import namedtuple
from ale_python_interface import ALEInterface
import logging

import time
f = open('results_diff0.txt','w')

# %% [markdown]
# ### Summary of the algorithm
# #### Collect samples
# At the beginning of each episode (one round of the game),
# reset the environment to its initial state using `env.reset()`.
# At each time step ``t``, the environment is at `current_state`.
# With probability $\epsilon$, apply a random action.
# Otherwise, apply $argmax_a~ Q(\phi($ `current_state` $),a,\theta)$,
# where $Q$ is parameterized by paramters $\theta$ and $\phi(\cdot)$ is preprocessor.
# Pass the action through `env.step(action)` to receive next frame, reward and whether the game terminates.
# Append this frame to the end of the `current_state` and construct `next_state` while removeing $frame(t-12)$.
# Store the tuple $(\phi($ `current_state` $), action, reward, \phi($ `next_ state` $))$ in the replay buffer.
#
# #### Update Network
# * Draw batches of tuples from the replay buffer: $(\phi,r,a,\phi')$.
# * Define the following loss
# $$\Large(\small Q(\phi,a,\theta)-r-max_{a'}Q(\phi',a',\theta^-)\Large)^2$$
# * Where $\theta^-$ is the parameter of the target network.( Set $Q(\phi',a',\theta^-)$ to zero if $\phi$ is the preprocessed termination state).
# * Update the $\theta$
# * Update the $\theta^-$ once in a while

# %% [markdown]
# ## Set the hyper-parameters

# %%
class Options:
    def __init__(self):
        #Articheture
        self.batch_size = 32 # The size of the batch to learn the Q-function
        self.image_size = 84 # Resize the raw input frame to square frame of size 80 by 80 
        #Trickes
        self.replay_buffer_size = 1000000 # The size of replay buffer; set it to size of your memory (.5M for 50G available memory)
        self.learning_frequency = 4 # With Freq of 1/4 step update the Q-network
        self.skip_frame = 4 # Skip 4-1 raw frames between steps
        self.internal_skip_frame = 4 # Skip 4-1 raw frames between skipped frames
        self.frame_len = 4 # Each state is formed as a concatination 4 step frames [f(t-12),f(t-8),f(t-4),f(t)]
        self.Target_update = 10000 # Update the target network each 10000 steps
        self.epsilon_min = 0.1 # Minimum level of stochasticity of policy (epsilon)-greedy
        self.annealing_end = 1000000. # The number of step it take to linearly anneal the epsilon to it min value
        self.gamma = 0.99 # The discount factor
        self.replay_start_size = 50000 # Start to backpropagated through the network, learning starts
        self.no_op_max = 30 / self.skip_frame # Run uniform policy for first 30 times step of the beginning of the game
        
        #otimization
        self.num_episode = 20000 # Number episode to run the algorithm
        self.lr = 0.00025 # RMSprop learning rate
        self.gamma1 = 0.95 # RMSprop gamma1
        self.gamma2 = 0.95 # RMSprop gamma2
        self.rms_eps = 0.01 # RMSprop epsilon bias
        self.ctx = mx.gpu() # Enables gpu if available, if not, set it to mx.cpu()
opt = Options()

env_name = 'Assault_diff0' # Set the desired environment
#env = gym.make(env_name)
#num_action = env.action_space.n # Extract the number of available action from the environment setting

manualSeed = 1 # random.randint(1, 10000) # Set the desired seed to reproduce the results
mx.random.seed(manualSeed)
attrs = vars(opt)
print (', '.join("%s: %s" % item for item in attrs.items()))
# Out:
# replay_buffer_size: 1000000, annealing_end: 1000000.0, Target_update: 10000, gamma1: 0.95, frame_len: 4, internal_skip_frame: 4, ctx: gpu(0), skip_frame: 4, batch_size: 32, learning_frequency: 4, lr: 0.00025, num_episode: 20000, image_size: 84, epsilon_min: 0.1, replay_start_size: 50000, rms_eps: 0.01, no_op_max: 7, gamma: 0.99, gamma2: 0.95

# %%
ale = ALEInterface()
ale.setInt('random_seed', 1)
ale.loadROM('ROMS/space_invaders.bin')
num_action = len(ale.getLegalActionSet())

# %%
print(ale.getAvailableDifficulties())
ale.setDifficulty(0)
# Out:
# [0 1]

# %% [markdown]
# ### Define the DQN model
# The network is constructed as three CNN layers and a fully connected added on the top. Furthermore, the optimizer is assigned to the parameters.

# %%
DQN = gluon.nn.Sequential()
with DQN.name_scope():
    #first layer
    DQN.add(gluon.nn.Conv2D(channels=32, kernel_size=8,strides = 4,padding = 0))
    DQN.add(gluon.nn.BatchNorm(axis = 1, momentum = 0.1,center=True))
    DQN.add(gluon.nn.Activation('relu'))
    #second layer
    DQN.add(gluon.nn.Conv2D(channels=64, kernel_size=4,strides = 2))
    DQN.add(gluon.nn.BatchNorm(axis = 1, momentum = 0.1,center=True))
    DQN.add(gluon.nn.Activation('relu'))
    #tird layer
    DQN.add(gluon.nn.Conv2D(channels=64, kernel_size=3,strides = 1))
    DQN.add(gluon.nn.BatchNorm(axis = 1, momentum = 0.1,center=True))
    DQN.add(gluon.nn.Activation('relu'))
    DQN.add(gluon.nn.Flatten())
    #fourth layer
    DQN.add(gluon.nn.Dense(512,activation ='relu'))
    #fifth layer
    DQN.add(gluon.nn.Dense(num_action,activation ='relu'))

dqn = DQN
dqn.collect_params().initialize(mx.init.Normal(0.02), ctx=opt.ctx)
DQN_trainer = gluon.Trainer(dqn.collect_params(),'RMSProp', \
                          {'learning_rate': opt.lr ,'gamma1':opt.gamma1,'gamma2': opt.gamma2,'epsilon': opt.rms_eps,'centered' : True})
dqn.collect_params().zero_grad()

# %%
Target_DQN = gluon.nn.Sequential()
with Target_DQN.name_scope():
    #first layer
    Target_DQN.add(gluon.nn.Conv2D(channels=32, kernel_size=8,strides = 4,padding = 0))
    Target_DQN.add(gluon.nn.BatchNorm(axis = 1, momentum = 0.1,center=True))
    Target_DQN.add(gluon.nn.Activation('relu'))
    #second layer
    Target_DQN.add(gluon.nn.Conv2D(channels=64, kernel_size=4,strides = 2))
    Target_DQN.add(gluon.nn.BatchNorm(axis = 1, momentum = 0.1,center=True))
    Target_DQN.add(gluon.nn.Activation('relu'))
    #tird layer
    Target_DQN.add(gluon.nn.Conv2D(channels=64, kernel_size=3,strides = 1))
    Target_DQN.add(gluon.nn.BatchNorm(axis = 1, momentum = 0.1,center=True))
    Target_DQN.add(gluon.nn.Activation('relu'))
    Target_DQN.add(gluon.nn.Flatten())
    #fourth layer
    Target_DQN.add(gluon.nn.Dense(512,activation ='relu'))
    #fifth layer
    Target_DQN.add(gluon.nn.Dense(num_action,activation ='relu'))
target_dqn = Target_DQN
target_dqn.collect_params().initialize(mx.init.Normal(0.02), ctx=opt.ctx)

# %% [markdown]
# ### Replay buffer
# Replay buffer store the tuple of : `state`, action , `next_state`, reward , done.

# %%
Transition = namedtuple('Transition',('state', 'action', 'reward','done','initial_state'))
class Replay_Buffer():
    def __init__(self, replay_buffer_size):
        self.replay_buffer_size = replay_buffer_size
        self.memory = []
        self.position = 0
    def push(self, *args):
        if len(self.memory) < self.replay_buffer_size:
            self.memory.append(None)
        self.memory[self.position] = Transition(*args)
        self.position = (self.position + 1) % self.replay_buffer_size
    def sample(self, batch_size,batch_state,batch_state_next,batch_reward,batch_action,batch_done):
        for i in range(batch_size):
            j = random.randint(opt.frame_len-1,len(self.memory)-2)
            for jj in range(opt.frame_len):
                batch_state[i,opt.frame_len-1-jj] =  self.memory[j-jj].state[0].as_in_context(opt.ctx).astype('float32')/255.
                batch_state_next[i,opt.frame_len-1-jj] = self.memory[j-jj+1].state.as_in_context(opt.ctx)[0].astype('float32')/255.
                if self.memory[j-jj].initial_state:
                    for kk in range(opt.frame_len-jj-1):
                        batch_state[i,opt.frame_len-2-kk] =  self.memory[j-jj].state[0].as_in_context(opt.ctx).astype('float32')/255.
                        batch_state_next[i,opt.frame_len-2-kk] = self.memory[j-jj].state.as_in_context(opt.ctx)[0].astype('float32')/255.
                    break
            if self.memory[j].done:
                batch_state_next[i,opt.frame_len-1] = batch_state[i,opt.frame_len-1]
            batch_reward[i] = self.memory[j].reward
            batch_action[i] = self.memory[j].action
            batch_done[i] = self.memory[j].done

# %% [markdown]
# ### Preprocess frames
# * Take a frame, average over the `RGB` filter and append it to the `state` to construct `next_state`
# * Clip the reward
# * Render the frames

# %%
def preprocess(raw_frame, currentState = None, initial_state = False):
    raw_frame = nd.array(raw_frame,mx.cpu())
    raw_frame = nd.reshape(nd.mean(raw_frame, axis = 2),shape = (raw_frame.shape[0],raw_frame.shape[1],1))
    raw_frame = mx.image.imresize(raw_frame,  opt.image_size, opt.image_size)
    raw_frame = nd.transpose(raw_frame, (2,0,1))
    raw_frame = raw_frame.astype('float32')/255.
    if initial_state == True:
        state = raw_frame
        for _ in range(opt.frame_len-1):
            state = nd.concat(state , raw_frame, dim = 0)
    else:
        state = mx.nd.concat(currentState[1:,:,:], raw_frame, dim = 0)
    return state, raw_frame

def rew_clipper(rew):
    if rew>0.:
        return 1.
    elif rew<0.:
        return -1.
    else:
        return 0

def renderimage(next_frame):
    if render_image:
        plt.imshow(next_frame);
        plt.show()
        display.clear_output(wait=True)
        time.sleep(.1)
        
l2loss = gluon.loss.L2Loss(batch_axis=0)

# %% [markdown]
# ### Initialize arrays

# %%
frame_counter = 0. # Counts the number of steps so far
annealing_count = 0. # Counts the number of annealing steps
epis_count = 0. # Counts the number episodes so far
replay_memory = Replay_Buffer(opt.replay_buffer_size) # Initialize the replay buffer
tot_clipped_reward = np.zeros(opt.num_episode) 
tot_reward = np.zeros(opt.num_episode)
moving_average_clipped = 0.
moving_average = 0.

# %% [markdown]
# ### Train the model

# %%
render_image = False # Whether to render Frames and show the game
batch_state = nd.empty((opt.batch_size,opt.frame_len,opt.image_size,opt.image_size), opt.ctx)
batch_state_next = nd.empty((opt.batch_size,opt.frame_len,opt.image_size,opt.image_size), opt.ctx)
batch_reward = nd.empty((opt.batch_size),opt.ctx)
batch_action = nd.empty((opt.batch_size),opt.ctx)
batch_done = nd.empty((opt.batch_size),opt.ctx)
initial_state = True
while epis_count < opt.num_episode:
    cum_clipped_reward = 0
    cum_reward = 0
    ale.reset_game()
    next_frame = ale.getScreenRGB()
    state, current_frame = preprocess(next_frame, initial_state = True)
    t = 0.
    done = False
    initial_state = True


    while not done:
        mx.nd.waitall()
        previous_state = state
        # show the frame
        renderimage(next_frame)
        sample = random.random()
        if frame_counter > opt.replay_start_size:
            annealing_count += 1
        if frame_counter == opt.replay_start_size:
            logging.error('annealing and laerning are started ')
            
            
        
        eps = np.maximum(1.-annealing_count/opt.annealing_end,opt.epsilon_min)
        effective_eps = eps
        if t < opt.no_op_max:
            effective_eps = 1.
        
        # epsilon greedy policy
        if sample < effective_eps:
            action = random.randint(0, num_action - 1)
        else:
            data = state.reshape([1,opt.frame_len,opt.image_size,opt.image_size]).as_in_context(opt.ctx)
            action = int(nd.argmax(dqn(data),axis=1).as_in_context(mx.cpu()).asscalar())
        
        # Skip frame
        rew = 0
        for skip in range(opt.skip_frame-1):
            reward = ale.act(action)
            next_frame = ale.getScreenRGB()
            done = ale.game_over()
            renderimage(next_frame)
            cum_clipped_reward += rew_clipper(reward)
            rew += reward
            for internal_skip in range(opt.internal_skip_frame-1):
                reward = ale.act(action)
                done = ale.game_over()
                cum_clipped_reward += rew_clipper(reward)
                rew += reward
                
        reward = ale.act(action)
        next_frame_new = ale.getScreenRGB()
        done = ale.game_over()        
        renderimage(next_frame)
        cum_clipped_reward += rew_clipper(reward)
        rew += reward
        cum_reward += rew
        
        # Reward clipping
        reward = rew_clipper(rew)
        next_frame = np.maximum(next_frame_new,next_frame)
        replay_memory.push((current_frame*255.).astype(np.uint8)\
                           ,action,reward,done, initial_state)
        state, current_frame = preprocess(next_frame, state)
        initial_state = False
        # Train
        if frame_counter > opt.replay_start_size:        
            if frame_counter % opt.learning_frequency == 0:
                replay_memory.sample(opt.batch_size,batch_state,batch_state_next,batch_reward,batch_action,batch_done)
                with autograd.record():
                    Q_sp = nd.max(target_dqn(batch_state_next),axis = 1)
                    Q_sp = Q_sp*(nd.ones(opt.batch_size,ctx = opt.ctx)-batch_done)
                    Q_s_array = dqn(batch_state)
                    Q_s = nd.pick(Q_s_array,batch_action,1)
                    loss = nd.mean(l2loss(Q_s ,  (batch_reward + opt.gamma *Q_sp)))
                loss.backward()
                DQN_trainer.step(opt.batch_size)
                
        

        
        t += 1
        frame_counter += 1
        
        # Save the model and update Target model
        if frame_counter > opt.replay_start_size:
            if frame_counter % opt.Target_update == 0 :
                check_point = frame_counter / (opt.Target_update *100)
                fdqn = './target_%s_%d' % (env_name,int(check_point))
                dqn.save_params(fdqn)
                target_dqn.load_params(fdqn, opt.ctx)
        if done:
            if epis_count % 10. == 0. :
                results = 'epis[%d],eps[%f],durat[%d],fnum=%d, cum_cl_rew = %d, cum_rew = %d,tot_cl = %d , tot = %d'\
                  %(epis_count,eps,t+1,frame_counter,cum_clipped_reward,cum_reward,moving_average_clipped,moving_average)
                print(results)
                f.write('\n' + results)
    epis_count += 1
    tot_clipped_reward[int(epis_count)-1] = cum_clipped_reward
    tot_reward[int(epis_count)-1] = cum_reward
    if epis_count > 50.:
        moving_average_clipped = np.mean(tot_clipped_reward[int(epis_count)-1-50:int(epis_count)-1])
        moving_average = np.mean(tot_reward[int(epis_count)-1-50:int(epis_count)-1])
f.close()
from tempfile import TemporaryFile
outfile = TemporaryFile()
outfile_clip = TemporaryFile()
np.save(outfile, moving_average)
np.save(outfile_clip, moving_average_clipped)
# Out:
# epis[0],eps[1.000000],durat[360],fnum=359, cum_cl_rew = 29, cum_rew = 640,tot_cl = 0 , tot = 0
# epis[10],eps[1.000000],durat[114],fnum=2130, cum_cl_rew = 6, cum_rew = 80,tot_cl = 0 , tot = 0
# epis[20],eps[1.000000],durat[165],fnum=3676, cum_cl_rew = 8, cum_rew = 120,tot_cl = 0 , tot = 0
# epis[30],eps[1.000000],durat[141],fnum=5580, cum_cl_rew = 9, cum_rew = 100,tot_cl = 0 , tot = 0
# epis[40],eps[1.000000],durat[156],fnum=7106, cum_cl_rew = 10, cum_rew = 150,tot_cl = 0 , tot = 0
# epis[50],eps[1.000000],durat[196],fnum=8429, cum_cl_rew = 16, cum_rew = 215,tot_cl = 0 , tot = 0
# epis[60],eps[1.000000],durat[147],fnum=9753, cum_cl_rew = 9, cum_rew = 135,tot_cl = 9 , tot = 137
# epis[70],eps[1.000000],durat[149],fnum=11357, cum_cl_rew = 11, cum_rew = 140,tot_cl = 9 , tot = 135
# epis[80],eps[1.000000],durat[108],fnum=13075, cum_cl_rew = 6, cum_rew = 50,tot_cl = 8 , tot = 130
# epis[90],eps[1.000000],durat[239],fnum=14605, cum_cl_rew = 24, cum_rew = 560,tot_cl = 8 , tot = 122
# epis[100],eps[1.000000],durat[187],fnum=16244, cum_cl_rew = 13, cum_rew = 195,tot_cl = 9 , tot = 142
# epis[110],eps[1.000000],durat[138],fnum=17782, cum_cl_rew = 5, cum_rew = 75,tot_cl = 9 , tot = 148
# epis[120],eps[1.000000],durat[217],fnum=19622, cum_cl_rew = 13, cum_rew = 150,tot_cl = 9 , tot = 147
# epis[130],eps[1.000000],durat[134],fnum=21195, cum_cl_rew = 7, cum_rew = 90,tot_cl = 9 , tot = 143
# epis[140],eps[1.000000],durat[244],fnum=22849, cum_cl_rew = 17, cum_rew = 225,tot_cl = 9 , tot = 146
# epis[150],eps[1.000000],durat[146],fnum=24598, cum_cl_rew = 8, cum_rew = 105,tot_cl = 9 , tot = 136
# epis[160],eps[1.000000],durat[86],fnum=25978, cum_cl_rew = 5, cum_rew = 45,tot_cl = 10 , tot = 136
# epis[170],eps[1.000000],durat[150],fnum=27533, cum_cl_rew = 9, cum_rew = 140,tot_cl = 10 , tot = 143
# epis[180],eps[1.000000],durat[119],fnum=28998, cum_cl_rew = 6, cum_rew = 50,tot_cl = 10 , tot = 143
# epis[190],eps[1.000000],durat[156],fnum=30777, cum_cl_rew = 10, cum_rew = 120,tot_cl = 10 , tot = 141
# epis[200],eps[1.000000],durat[90],fnum=32431, cum_cl_rew = 4, cum_rew = 40,tot_cl = 10 , tot = 139
# epis[210],eps[1.000000],durat[146],fnum=34134, cum_cl_rew = 8, cum_rew = 110,tot_cl = 10 , tot = 150
# epis[220],eps[1.000000],durat[253],fnum=36066, cum_cl_rew = 10, cum_rew = 105,tot_cl = 10 , tot = 149
# epis[230],eps[1.000000],durat[89],fnum=37410, cum_cl_rew = 6, cum_rew = 75,tot_cl = 10 , tot = 144
# epis[240],eps[1.000000],durat[91],fnum=39106, cum_cl_rew = 6, cum_rew = 60,tot_cl = 10 , tot = 147
# epis[250],eps[1.000000],durat[226],fnum=40683, cum_cl_rew = 17, cum_rew = 285,tot_cl = 9 , tot = 138
# epis[260],eps[1.000000],durat[87],fnum=41917, cum_cl_rew = 4, cum_rew = 25,tot_cl = 8 , tot = 119
# epis[270],eps[1.000000],durat[201],fnum=43731, cum_cl_rew = 11, cum_rew = 145,tot_cl = 8 , tot = 105
# epis[280],eps[1.000000],durat[149],fnum=45126, cum_cl_rew = 4, cum_rew = 45,tot_cl = 8 , tot = 105
# epis[290],eps[1.000000],durat[149],fnum=46906, cum_cl_rew = 11, cum_rew = 180,tot_cl = 8 , tot = 100
# epis[300],eps[1.000000],durat[171],fnum=48418, cum_cl_rew = 9, cum_rew = 125,tot_cl = 8 , tot = 111
# ERROR:root:annealing and laerning are started
# epis[310],eps[0.999965],durat[91],fnum=50036, cum_cl_rew = 8, cum_rew = 75,tot_cl = 9 , tot = 128
# epis[320],eps[0.998369],durat[206],fnum=51632, cum_cl_rew = 11, cum_rew = 155,tot_cl = 9 , tot = 134
# epis[330],eps[0.996534],durat[205],fnum=53467, cum_cl_rew = 12, cum_rew = 145,tot_cl = 9 , tot = 144
# epis[340],eps[0.995072],durat[232],fnum=54929, cum_cl_rew = 18, cum_rew = 245,tot_cl = 9 , tot = 143
# epis[350],eps[0.993691],durat[163],fnum=56310, cum_cl_rew = 12, cum_rew = 150,tot_cl = 9 , tot = 132
# epis[360],eps[0.992414],durat[262],fnum=57587, cum_cl_rew = 21, cum_rew = 310,tot_cl = 8 , tot = 113
# epis[370],eps[0.990488],durat[182],fnum=59513, cum_cl_rew = 13, cum_rew = 195,tot_cl = 9 , tot = 123
# epis[380],eps[0.988971],durat[139],fnum=61030, cum_cl_rew = 7, cum_rew = 70,tot_cl = 8 , tot = 121
# epis[390],eps[0.987009],durat[223],fnum=62992, cum_cl_rew = 19, cum_rew = 300,tot_cl = 9 , tot = 141
# epis[400],eps[0.985614],durat[84],fnum=64387, cum_cl_rew = 8, cum_rew = 90,tot_cl = 9 , tot = 146
# epis[410],eps[0.984127],durat[219],fnum=65874, cum_cl_rew = 13, cum_rew = 200,tot_cl = 9 , tot = 147
# epis[420],eps[0.982720],durat[158],fnum=67281, cum_cl_rew = 6, cum_rew = 50,tot_cl = 8 , tot = 132
# epis[430],eps[0.981014],durat[122],fnum=68987, cum_cl_rew = 9, cum_rew = 120,tot_cl = 9 , tot = 137
# epis[440],eps[0.979597],durat[184],fnum=70404, cum_cl_rew = 19, cum_rew = 270,tot_cl = 8 , tot = 122
# epis[450],eps[0.977890],durat[184],fnum=72111, cum_cl_rew = 15, cum_rew = 215,tot_cl = 8 , tot = 126
# epis[460],eps[0.976262],durat[127],fnum=73739, cum_cl_rew = 8, cum_rew = 105,tot_cl = 9 , tot = 139
# epis[470],eps[0.974632],durat[86],fnum=75369, cum_cl_rew = 6, cum_rew = 80,tot_cl = 10 , tot = 155
# epis[480],eps[0.973300],durat[160],fnum=76701, cum_cl_rew = 17, cum_rew = 210,tot_cl = 9 , tot = 142
# epis[490],eps[0.971684],durat[254],fnum=78317, cum_cl_rew = 21, cum_rew = 305,tot_cl = 9 , tot = 137
# epis[500],eps[0.969910],durat[280],fnum=80091, cum_cl_rew = 23, cum_rew = 350,tot_cl = 10 , tot = 141
# epis[510],eps[0.968261],durat[115],fnum=81740, cum_cl_rew = 4, cum_rew = 35,tot_cl = 10 , tot = 142
# epis[520],eps[0.966541],durat[119],fnum=83460, cum_cl_rew = 5, cum_rew = 50,tot_cl = 10 , tot = 136
# epis[530],eps[0.965071],durat[92],fnum=84930, cum_cl_rew = 3, cum_rew = 20,tot_cl = 10 , tot = 138
# epis[540],eps[0.963622],durat[86],fnum=86379, cum_cl_rew = 2, cum_rew = 15,tot_cl = 10 , tot = 145
# epis[550],eps[0.962119],durat[81],fnum=87882, cum_cl_rew = 3, cum_rew = 35,tot_cl = 9 , tot = 128
# epis[560],eps[0.960350],durat[223],fnum=89651, cum_cl_rew = 15, cum_rew = 230,tot_cl = 9 , tot = 126
# epis[570],eps[0.958603],durat[163],fnum=91398, cum_cl_rew = 13, cum_rew = 215,tot_cl = 9 , tot = 134
# epis[580],eps[0.956721],durat[247],fnum=93280, cum_cl_rew = 20, cum_rew = 285,tot_cl = 10 , tot = 145
# epis[590],eps[0.955302],durat[122],fnum=94699, cum_cl_rew = 6, cum_rew = 105,tot_cl = 10 , tot = 143
# epis[600],eps[0.953729],durat[124],fnum=96272, cum_cl_rew = 7, cum_rew = 90,tot_cl = 10 , tot = 150
# epis[610],eps[0.952116],durat[307],fnum=97885, cum_cl_rew = 24, cum_rew = 350,tot_cl = 10 , tot = 144
# epis[620],eps[0.950370],durat[135],fnum=99631, cum_cl_rew = 6, cum_rew = 45,tot_cl = 10 , tot = 142
# epis[630],eps[0.948986],durat[149],fnum=101015, cum_cl_rew = 7, cum_rew = 110,tot_cl = 9 , tot = 131
# epis[640],eps[0.947707],durat[149],fnum=102294, cum_cl_rew = 9, cum_rew = 150,tot_cl = 9 , tot = 124
# epis[650],eps[0.945958],durat[135],fnum=104043, cum_cl_rew = 6, cum_rew = 70,tot_cl = 9 , tot = 126
# epis[660],eps[0.944325],durat[250],fnum=105676, cum_cl_rew = 16, cum_rew = 440,tot_cl = 9 , tot = 128
# epis[670],eps[0.942505],durat[114],fnum=107496, cum_cl_rew = 8, cum_rew = 115,tot_cl = 9 , tot = 142
# epis[680],eps[0.941075],durat[120],fnum=108926, cum_cl_rew = 4, cum_rew = 30,tot_cl = 9 , tot = 144
# epis[690],eps[0.939552],durat[92],fnum=110449, cum_cl_rew = 2, cum_rew = 20,tot_cl = 9 , tot = 144
# epis[700],eps[0.938094],durat[116],fnum=111907, cum_cl_rew = 8, cum_rew = 100,tot_cl = 9 , tot = 141
# epis[710],eps[0.936398],durat[117],fnum=113603, cum_cl_rew = 7, cum_rew = 90,tot_cl = 9 , tot = 150
# epis[720],eps[0.934764],durat[123],fnum=115237, cum_cl_rew = 6, cum_rew = 70,tot_cl = 9 , tot = 129
# epis[730],eps[0.933296],durat[145],fnum=116705, cum_cl_rew = 8, cum_rew = 120,tot_cl = 9 , tot = 131
# epis[740],eps[0.931800],durat[155],fnum=118201, cum_cl_rew = 9, cum_rew = 115,tot_cl = 9 , tot = 139
# epis[750],eps[0.930232],durat[126],fnum=119769, cum_cl_rew = 6, cum_rew = 65,tot_cl = 10 , tot = 144
# epis[760],eps[0.928724],durat[128],fnum=121277, cum_cl_rew = 6, cum_rew = 75,tot_cl = 9 , tot = 135
# epis[770],eps[0.927082],durat[384],fnum=122919, cum_cl_rew = 24, cum_rew = 350,tot_cl = 9 , tot = 123
# epis[780],eps[0.925609],durat[180],fnum=124392, cum_cl_rew = 14, cum_rew = 370,tot_cl = 9 , tot = 135
# epis[790],eps[0.923842],durat[112],fnum=126159, cum_cl_rew = 10, cum_rew = 150,tot_cl = 9 , tot = 141
# epis[800],eps[0.922267],durat[125],fnum=127734, cum_cl_rew = 7, cum_rew = 80,tot_cl = 9 , tot = 148
# epis[810],eps[0.920600],durat[191],fnum=129401, cum_cl_rew = 10, cum_rew = 100,tot_cl = 9 , tot = 149
# epis[820],eps[0.919357],durat[82],fnum=130644, cum_cl_rew = 4, cum_rew = 50,tot_cl = 10 , tot = 153
# epis[830],eps[0.917907],durat[89],fnum=132094, cum_cl_rew = 4, cum_rew = 50,tot_cl = 9 , tot = 129
# epis[840],eps[0.916274],durat[237],fnum=133727, cum_cl_rew = 10, cum_rew = 130,tot_cl = 8 , tot = 122
# epis[850],eps[0.914641],durat[190],fnum=135360, cum_cl_rew = 8, cum_rew = 115,tot_cl = 8 , tot = 121
# epis[860],eps[0.913100],durat[89],fnum=136901, cum_cl_rew = 4, cum_rew = 35,tot_cl = 8 , tot = 118
# epis[870],eps[0.911339],durat[169],fnum=138662, cum_cl_rew = 12, cum_rew = 210,tot_cl = 9 , tot = 125
# epis[880],eps[0.909750],durat[122],fnum=140251, cum_cl_rew = 9, cum_rew = 125,tot_cl = 9 , tot = 140
# epis[890],eps[0.908336],durat[182],fnum=141665, cum_cl_rew = 13, cum_rew = 215,tot_cl = 9 , tot = 140
# epis[900],eps[0.906728],durat[121],fnum=143273, cum_cl_rew = 7, cum_rew = 80,tot_cl = 9 , tot = 134
# epis[910],eps[0.905179],durat[158],fnum=144822, cum_cl_rew = 9, cum_rew = 125,tot_cl = 9 , tot = 137
# epis[920],eps[0.903463],durat[261],fnum=146538, cum_cl_rew = 18, cum_rew = 290,tot_cl = 9 , tot = 131
# epis[930],eps[0.901904],durat[248],fnum=148097, cum_cl_rew = 23, cum_rew = 555,tot_cl = 9 , tot = 129
# epis[940],eps[0.900548],durat[117],fnum=149453, cum_cl_rew = 6, cum_rew = 55,tot_cl = 9 , tot = 136
# epis[950],eps[0.899031],durat[156],fnum=150970, cum_cl_rew = 9, cum_rew = 105,tot_cl = 9 , tot = 139
# epis[960],eps[0.897196],durat[232],fnum=152805, cum_cl_rew = 16, cum_rew = 395,tot_cl = 9 , tot = 147
# epis[970],eps[0.895497],durat[268],fnum=154504, cum_cl_rew = 16, cum_rew = 245,tot_cl = 10 , tot = 164
# epis[980],eps[0.893724],durat[189],fnum=156277, cum_cl_rew = 7, cum_rew = 80,tot_cl = 10 , tot = 172
# epis[990],eps[0.892200],durat[122],fnum=157801, cum_cl_rew = 6, cum_rew = 60,tot_cl = 11 , tot = 168
# epis[1000],eps[0.890598],durat[138],fnum=159403, cum_cl_rew = 3, cum_rew = 40,tot_cl = 10 , tot = 162
# epis[1010],eps[0.889155],durat[83],fnum=160846, cum_cl_rew = 3, cum_rew = 30,tot_cl = 10 , tot = 150
# epis[1020],eps[0.887335],durat[181],fnum=162666, cum_cl_rew = 7, cum_rew = 85,tot_cl = 10 , tot = 149
# epis[1030],eps[0.885812],durat[93],fnum=164189, cum_cl_rew = 4, cum_rew = 30,tot_cl = 10 , tot = 136
# epis[1040],eps[0.884092],durat[132],fnum=165909, cum_cl_rew = 9, cum_rew = 125,tot_cl = 9 , tot = 135
# epis[1050],eps[0.882536],durat[121],fnum=167465, cum_cl_rew = 6, cum_rew = 80,tot_cl = 9 , tot = 133
# epis[1060],eps[0.880755],durat[223],fnum=169246, cum_cl_rew = 12, cum_rew = 150,tot_cl = 10 , tot = 152
# epis[1070],eps[0.879161],durat[178],fnum=170840, cum_cl_rew = 9, cum_rew = 135,tot_cl = 9 , tot = 141
# epis[1080],eps[0.877459],durat[114],fnum=172542, cum_cl_rew = 4, cum_rew = 35,tot_cl = 10 , tot = 154
# epis[1090],eps[0.875873],durat[97],fnum=174128, cum_cl_rew = 7, cum_rew = 80,tot_cl = 10 , tot = 159
# epis[1100],eps[0.874255],durat[99],fnum=175746, cum_cl_rew = 2, cum_rew = 10,tot_cl = 11 , tot = 169
# epis[1110],eps[0.872441],durat[168],fnum=177560, cum_cl_rew = 12, cum_rew = 140,tot_cl = 10 , tot = 154
# epis[1120],eps[0.870623],durat[276],fnum=179378, cum_cl_rew = 21, cum_rew = 340,tot_cl = 11 , tot = 172
# epis[1130],eps[0.869064],durat[282],fnum=180937, cum_cl_rew = 25, cum_rew = 545,tot_cl = 11 , tot = 162
# epis[1140],eps[0.867309],durat[226],fnum=182692, cum_cl_rew = 13, cum_rew = 190,tot_cl = 11 , tot = 165
# epis[1150],eps[0.865840],durat[122],fnum=184161, cum_cl_rew = 8, cum_rew = 120,tot_cl = 10 , tot = 157
# epis[1160],eps[0.863967],durat[280],fnum=186034, cum_cl_rew = 22, cum_rew = 290,tot_cl = 10 , tot = 168
# epis[1170],eps[0.862289],durat[88],fnum=187712, cum_cl_rew = 3, cum_rew = 45,tot_cl = 10 , tot = 157
# epis[1180],eps[0.860477],durat[155],fnum=189524, cum_cl_rew = 5, cum_rew = 40,tot_cl = 11 , tot = 159
# epis[1190],eps[0.858392],durat[294],fnum=191609, cum_cl_rew = 27, cum_rew = 620,tot_cl = 11 , tot = 162
# epis[1200],eps[0.856944],durat[235],fnum=193057, cum_cl_rew = 18, cum_rew = 215,tot_cl = 10 , tot = 165
# epis[1210],eps[0.855699],durat[147],fnum=194302, cum_cl_rew = 9, cum_rew = 85,tot_cl = 10 , tot = 147
# epis[1220],eps[0.854193],durat[179],fnum=195808, cum_cl_rew = 15, cum_rew = 240,tot_cl = 9 , tot = 140
# epis[1230],eps[0.852367],durat[187],fnum=197634, cum_cl_rew = 10, cum_rew = 130,tot_cl = 9 , tot = 144
# epis[1240],eps[0.850772],durat[91],fnum=199229, cum_cl_rew = 6, cum_rew = 85,tot_cl = 9 , tot = 135
# epis[1250],eps[0.849004],durat[92],fnum=200997, cum_cl_rew = 6, cum_rew = 85,tot_cl = 10 , tot = 146
# epis[1260],eps[0.847183],durat[233],fnum=202818, cum_cl_rew = 15, cum_rew = 190,tot_cl = 10 , tot = 156
# epis[1270],eps[0.845270],durat[179],fnum=204731, cum_cl_rew = 9, cum_rew = 95,tot_cl = 11 , tot = 167
# epis[1280],eps[0.843684],durat[234],fnum=206317, cum_cl_rew = 19, cum_rew = 275,tot_cl = 10 , tot = 155
# epis[1290],eps[0.841918],durat[233],fnum=208083, cum_cl_rew = 15, cum_rew = 215,tot_cl = 11 , tot = 160
# epis[1300],eps[0.840606],durat[86],fnum=209395, cum_cl_rew = 4, cum_rew = 30,tot_cl = 10 , tot = 143
# epis[1310],eps[0.838991],durat[248],fnum=211010, cum_cl_rew = 21, cum_rew = 480,tot_cl = 9 , tot = 136
# epis[1320],eps[0.837310],durat[155],fnum=212691, cum_cl_rew = 9, cum_rew = 135,tot_cl = 9 , tot = 134
# epis[1330],eps[0.835758],durat[149],fnum=214243, cum_cl_rew = 9, cum_rew = 140,tot_cl = 10 , tot = 142
# epis[1340],eps[0.834156],durat[218],fnum=215845, cum_cl_rew = 20, cum_rew = 300,tot_cl = 9 , tot = 138
# epis[1350],eps[0.832629],durat[148],fnum=217372, cum_cl_rew = 9, cum_rew = 100,tot_cl = 10 , tot = 162
# epis[1360],eps[0.830890],durat[187],fnum=219111, cum_cl_rew = 14, cum_rew = 195,tot_cl = 11 , tot = 171
# epis[1370],eps[0.829636],durat[135],fnum=220365, cum_cl_rew = 6, cum_rew = 65,tot_cl = 10 , tot = 152
# epis[1380],eps[0.828192],durat[152],fnum=221809, cum_cl_rew = 12, cum_rew = 110,tot_cl = 9 , tot = 147
# epis[1390],eps[0.826645],durat[102],fnum=223356, cum_cl_rew = 3, cum_rew = 35,tot_cl = 10 , tot = 145
# epis[1400],eps[0.825104],durat[154],fnum=224897, cum_cl_rew = 10, cum_rew = 155,tot_cl = 9 , tot = 129
# epis[1410],eps[0.823556],durat[159],fnum=226445, cum_cl_rew = 7, cum_rew = 70,tot_cl = 9 , tot = 124
# epis[1420],eps[0.822053],durat[215],fnum=227948, cum_cl_rew = 16, cum_rew = 200,tot_cl = 9 , tot = 128
# epis[1430],eps[0.820305],durat[278],fnum=229696, cum_cl_rew = 20, cum_rew = 290,tot_cl = 9 , tot = 134
# epis[1440],eps[0.818754],durat[143],fnum=231247, cum_cl_rew = 3, cum_rew = 25,tot_cl = 10 , tot = 142
# epis[1450],eps[0.817057],durat[144],fnum=232944, cum_cl_rew = 8, cum_rew = 115,tot_cl = 10 , tot = 143
# epis[1460],eps[0.815500],durat[153],fnum=234501, cum_cl_rew = 11, cum_rew = 115,tot_cl = 10 , tot = 144
# epis[1470],eps[0.813786],durat[186],fnum=236215, cum_cl_rew = 12, cum_rew = 110,tot_cl = 10 , tot = 152
# epis[1480],eps[0.811850],durat[145],fnum=238151, cum_cl_rew = 14, cum_rew = 175,tot_cl = 11 , tot = 158
# epis[1490],eps[0.810048],durat[202],fnum=239953, cum_cl_rew = 22, cum_rew = 275,tot_cl = 11 , tot = 157
# epis[1500],eps[0.808063],durat[186],fnum=241938, cum_cl_rew = 15, cum_rew = 160,tot_cl = 12 , tot = 175
# epis[1510],eps[0.806423],durat[204],fnum=243578, cum_cl_rew = 12, cum_rew = 170,tot_cl = 12 , tot = 177
# epis[1520],eps[0.804481],durat[198],fnum=245520, cum_cl_rew = 6, cum_rew = 60,tot_cl = 13 , tot = 199
# epis[1530],eps[0.802990],durat[122],fnum=247011, cum_cl_rew = 6, cum_rew = 50,tot_cl = 12 , tot = 196
# epis[1540],eps[0.801443],durat[117],fnum=248558, cum_cl_rew = 7, cum_rew = 55,tot_cl = 12 , tot = 182
# epis[1550],eps[0.799812],durat[157],fnum=250189, cum_cl_rew = 9, cum_rew = 95,tot_cl = 11 , tot = 161
# epis[1560],eps[0.798195],durat[135],fnum=251806, cum_cl_rew = 9, cum_rew = 90,tot_cl = 11 , tot = 160
# epis[1570],eps[0.796577],durat[186],fnum=253424, cum_cl_rew = 11, cum_rew = 120,tot_cl = 10 , tot = 135
# epis[1580],eps[0.794912],durat[241],fnum=255089, cum_cl_rew = 16, cum_rew = 205,tot_cl = 11 , tot = 141
# epis[1590],eps[0.793510],durat[168],fnum=256491, cum_cl_rew = 13, cum_rew = 170,tot_cl = 11 , tot = 143
# epis[1600],eps[0.792165],durat[233],fnum=257836, cum_cl_rew = 24, cum_rew = 505,tot_cl = 10 , tot = 140
# epis[1610],eps[0.790587],durat[133],fnum=259414, cum_cl_rew = 6, cum_rew = 65,tot_cl = 10 , tot = 145
# epis[1620],eps[0.788926],durat[278],fnum=261075, cum_cl_rew = 22, cum_rew = 300,tot_cl = 10 , tot = 145
# epis[1630],eps[0.787441],durat[113],fnum=262560, cum_cl_rew = 5, cum_rew = 45,tot_cl = 10 , tot = 132
# epis[1640],eps[0.785972],durat[217],fnum=264029, cum_cl_rew = 20, cum_rew = 265,tot_cl = 9 , tot = 121
# epis[1650],eps[0.784420],durat[165],fnum=265581, cum_cl_rew = 15, cum_rew = 170,tot_cl = 10 , tot = 130
# epis[1660],eps[0.782954],durat[132],fnum=267047, cum_cl_rew = 7, cum_rew = 70,tot_cl = 9 , tot = 125
# epis[1670],eps[0.781541],durat[153],fnum=268460, cum_cl_rew = 6, cum_rew = 40,tot_cl = 9 , tot = 117
# epis[1680],eps[0.779775],durat[267],fnum=270226, cum_cl_rew = 22, cum_rew = 345,tot_cl = 9 , tot = 118
# epis[1690],eps[0.778320],durat[153],fnum=271681, cum_cl_rew = 8, cum_rew = 85,tot_cl = 10 , tot = 129
# epis[1700],eps[0.776865],durat[277],fnum=273136, cum_cl_rew = 19, cum_rew = 240,tot_cl = 9 , tot = 118
# epis[1710],eps[0.775375],durat[107],fnum=274626, cum_cl_rew = 9, cum_rew = 75,tot_cl = 9 , tot = 119
# epis[1720],eps[0.773676],durat[158],fnum=276325, cum_cl_rew = 8, cum_rew = 100,tot_cl = 10 , tot = 129
# epis[1730],eps[0.772344],durat[173],fnum=277657, cum_cl_rew = 11, cum_rew = 100,tot_cl = 9 , tot = 123
# epis[1740],eps[0.770807],durat[90],fnum=279194, cum_cl_rew = 3, cum_rew = 30,tot_cl = 9 , tot = 120
# epis[1750],eps[0.769179],durat[84],fnum=280822, cum_cl_rew = 7, cum_rew = 70,tot_cl = 10 , tot = 137
# epis[1760],eps[0.767637],durat[89],fnum=282364, cum_cl_rew = 5, cum_rew = 35,tot_cl = 9 , tot = 129
# epis[1770],eps[0.766179],durat[107],fnum=283822, cum_cl_rew = 4, cum_rew = 45,tot_cl = 9 , tot = 122
# epis[1780],eps[0.764803],durat[79],fnum=285198, cum_cl_rew = 5, cum_rew = 55,tot_cl = 9 , tot = 122
# epis[1790],eps[0.763082],durat[206],fnum=286919, cum_cl_rew = 19, cum_rew = 230,tot_cl = 9 , tot = 121
# epis[1800],eps[0.761948],durat[136],fnum=288053, cum_cl_rew = 9, cum_rew = 90,tot_cl = 8 , tot = 101
# epis[1810],eps[0.760279],durat[159],fnum=289722, cum_cl_rew = 5, cum_rew = 40,tot_cl = 9 , tot = 108
# epis[1820],eps[0.758803],durat[156],fnum=291198, cum_cl_rew = 7, cum_rew = 70,tot_cl = 9 , tot = 102
# epis[1830],eps[0.757438],durat[90],fnum=292563, cum_cl_rew = 0, cum_rew = 0,tot_cl = 9 , tot = 104
# epis[1840],eps[0.756278],durat[104],fnum=293723, cum_cl_rew = 4, cum_rew = 25,tot_cl = 9 , tot = 101
# epis[1850],eps[0.754619],durat[85],fnum=295382, cum_cl_rew = 5, cum_rew = 50,tot_cl = 9 , tot = 111
# epis[1860],eps[0.753223],durat[117],fnum=296778, cum_cl_rew = 8, cum_rew = 80,tot_cl = 9 , tot = 100
# epis[1870],eps[0.751526],durat[103],fnum=298475, cum_cl_rew = 6, cum_rew = 70,tot_cl = 9 , tot = 118
# epis[1880],eps[0.750407],durat[107],fnum=299594, cum_cl_rew = 9, cum_rew = 125,tot_cl = 9 , tot = 109
# epis[1890],eps[0.748555],durat[117],fnum=301446, cum_cl_rew = 4, cum_rew = 35,tot_cl = 10 , tot = 129
# epis[1900],eps[0.747259],durat[87],fnum=302742, cum_cl_rew = 7, cum_rew = 45,tot_cl = 10 , tot = 124
# epis[1910],eps[0.745900],durat[121],fnum=304101, cum_cl_rew = 9, cum_rew = 90,tot_cl = 10 , tot = 133
# epis[1920],eps[0.744316],durat[210],fnum=305685, cum_cl_rew = 18, cum_rew = 240,tot_cl = 10 , tot = 126
# epis[1930],eps[0.742959],durat[89],fnum=307042, cum_cl_rew = 5, cum_rew = 60,tot_cl = 10 , tot = 142
# epis[1940],eps[0.741487],durat[247],fnum=308514, cum_cl_rew = 22, cum_rew = 500,tot_cl = 9 , tot = 122
# epis[1950],eps[0.740088],durat[125],fnum=309913, cum_cl_rew = 8, cum_rew = 140,tot_cl = 9 , tot = 131
# epis[1960],eps[0.738568],durat[217],fnum=311433, cum_cl_rew = 11, cum_rew = 150,tot_cl = 9 , tot = 127
# epis[1970],eps[0.736997],durat[147],fnum=313004, cum_cl_rew = 13, cum_rew = 135,tot_cl = 10 , tot = 133
# epis[1980],eps[0.735366],durat[140],fnum=314635, cum_cl_rew = 6, cum_rew = 70,tot_cl = 10 , tot = 132
# epis[1990],eps[0.733600],durat[148],fnum=316401, cum_cl_rew = 8, cum_rew = 55,tot_cl = 11 , tot = 147
# epis[2000],eps[0.731976],durat[210],fnum=318025, cum_cl_rew = 22, cum_rew = 300,tot_cl = 10 , tot = 131
# epis[2010],eps[0.730362],durat[120],fnum=319639, cum_cl_rew = 9, cum_rew = 110,tot_cl = 11 , tot = 140
# epis[2020],eps[0.728784],durat[205],fnum=321217, cum_cl_rew = 14, cum_rew = 155,tot_cl = 11 , tot = 141
# epis[2030],eps[0.727436],durat[164],fnum=322565, cum_cl_rew = 15, cum_rew = 345,tot_cl = 10 , tot = 132
# epis[2040],eps[0.726181],durat[166],fnum=323820, cum_cl_rew = 15, cum_rew = 160,tot_cl = 9 , tot = 118
# epis[2050],eps[0.724620],durat[207],fnum=325381, cum_cl_rew = 11, cum_rew = 130,tot_cl = 9 , tot = 123
# epis[2060],eps[0.722841],durat[120],fnum=327160, cum_cl_rew = 6, cum_rew = 50,tot_cl = 10 , tot = 130
# epis[2070],eps[0.721608],durat[120],fnum=328393, cum_cl_rew = 8, cum_rew = 80,tot_cl = 9 , tot = 116
# epis[2080],eps[0.719945],durat[227],fnum=330056, cum_cl_rew = 20, cum_rew = 250,tot_cl = 9 , tot = 117
# epis[2090],eps[0.718408],durat[73],fnum=331593, cum_cl_rew = 4, cum_rew = 30,tot_cl = 10 , tot = 129
# epis[2100],eps[0.716709],durat[214],fnum=333292, cum_cl_rew = 16, cum_rew = 220,tot_cl = 10 , tot = 136
# epis[2110],eps[0.715140],durat[120],fnum=334861, cum_cl_rew = 6, cum_rew = 65,tot_cl = 9 , tot = 128
# epis[2120],eps[0.713722],durat[146],fnum=336279, cum_cl_rew = 6, cum_rew = 45,tot_cl = 10 , tot = 133
# epis[2130],eps[0.712450],durat[74],fnum=337551, cum_cl_rew = 2, cum_rew = 35,tot_cl = 9 , tot = 126
# epis[2140],eps[0.711141],durat[119],fnum=338860, cum_cl_rew = 6, cum_rew = 45,tot_cl = 9 , tot = 118
# epis[2150],eps[0.709556],durat[96],fnum=340445, cum_cl_rew = 6, cum_rew = 50,tot_cl = 9 , tot = 116
# epis[2160],eps[0.707930],durat[255],fnum=342071, cum_cl_rew = 19, cum_rew = 250,tot_cl = 9 , tot = 116
# epis[2170],eps[0.706345],durat[102],fnum=343656, cum_cl_rew = 6, cum_rew = 55,tot_cl = 9 , tot = 118
# epis[2180],eps[0.704620],durat[178],fnum=345381, cum_cl_rew = 12, cum_rew = 140,tot_cl = 10 , tot = 137
# epis[2190],eps[0.703069],durat[186],fnum=346932, cum_cl_rew = 11, cum_rew = 115,tot_cl = 11 , tot = 138
# epis[2200],eps[0.701485],durat[184],fnum=348516, cum_cl_rew = 12, cum_rew = 150,tot_cl = 10 , tot = 135
# epis[2210],eps[0.700007],durat[112],fnum=349994, cum_cl_rew = 8, cum_rew = 90,tot_cl = 10 , tot = 130
# epis[2220],eps[0.698479],durat[145],fnum=351522, cum_cl_rew = 8, cum_rew = 105,tot_cl = 10 , tot = 123
# epis[2230],eps[0.696940],durat[158],fnum=353061, cum_cl_rew = 11, cum_rew = 110,tot_cl = 10 , tot = 122
# epis[2240],eps[0.695330],durat[130],fnum=354671, cum_cl_rew = 12, cum_rew = 170,tot_cl = 10 , tot = 138
# epis[2250],eps[0.693649],durat[227],fnum=356352, cum_cl_rew = 22, cum_rew = 300,tot_cl = 10 , tot = 144
# epis[2260],eps[0.692070],durat[272],fnum=357931, cum_cl_rew = 21, cum_rew = 305,tot_cl = 10 , tot = 140
# epis[2270],eps[0.690644],durat[145],fnum=359357, cum_cl_rew = 6, cum_rew = 45,tot_cl = 10 , tot = 148
# epis[2280],eps[0.689169],durat[137],fnum=360832, cum_cl_rew = 6, cum_rew = 50,tot_cl = 10 , tot = 137
# epis[2290],eps[0.687450],durat[155],fnum=362551, cum_cl_rew = 11, cum_rew = 135,tot_cl = 10 , tot = 125
# epis[2300],eps[0.685900],durat[121],fnum=364101, cum_cl_rew = 7, cum_rew = 70,tot_cl = 10 , tot = 131
# epis[2310],eps[0.684691],durat[120],fnum=365310, cum_cl_rew = 6, cum_rew = 75,tot_cl = 9 , tot = 125
# epis[2320],eps[0.683249],durat[90],fnum=366752, cum_cl_rew = 2, cum_rew = 15,tot_cl = 9 , tot = 119
# epis[2330],eps[0.681518],durat[215],fnum=368483, cum_cl_rew = 14, cum_rew = 210,tot_cl = 9 , tot = 127
# epis[2340],eps[0.679956],durat[216],fnum=370045, cum_cl_rew = 14, cum_rew = 170,tot_cl = 9 , tot = 123
# epis[2350],eps[0.678429],durat[248],fnum=371572, cum_cl_rew = 16, cum_rew = 230,tot_cl = 9 , tot = 109
# epis[2360],eps[0.676883],durat[110],fnum=373118, cum_cl_rew = 5, cum_rew = 55,tot_cl = 9 , tot = 121
# epis[2370],eps[0.675254],durat[254],fnum=374747, cum_cl_rew = 18, cum_rew = 260,tot_cl = 10 , tot = 131
# epis[2380],eps[0.674105],durat[128],fnum=375896, cum_cl_rew = 11, cum_rew = 125,tot_cl = 9 , tot = 117
# epis[2390],eps[0.672491],durat[229],fnum=377510, cum_cl_rew = 15, cum_rew = 205,tot_cl = 9 , tot = 121
# epis[2400],eps[0.671237],durat[82],fnum=378764, cum_cl_rew = 3, cum_rew = 20,tot_cl = 9 , tot = 119
# epis[2410],eps[0.669930],durat[97],fnum=380071, cum_cl_rew = 7, cum_rew = 60,tot_cl = 9 , tot = 110
# epis[2420],eps[0.668197],durat[167],fnum=381804, cum_cl_rew = 12, cum_rew = 150,tot_cl = 8 , tot = 104
# epis[2430],eps[0.666551],durat[238],fnum=383450, cum_cl_rew = 20, cum_rew = 280,tot_cl = 9 , tot = 115
# epis[2440],eps[0.665048],durat[160],fnum=384953, cum_cl_rew = 14, cum_rew = 210,tot_cl = 9 , tot = 117
# epis[2450],eps[0.663581],durat[162],fnum=386420, cum_cl_rew = 13, cum_rew = 160,tot_cl = 9 , tot = 118
# epis[2460],eps[0.662005],durat[214],fnum=387996, cum_cl_rew = 10, cum_rew = 325,tot_cl = 9 , tot = 129
# epis[2470],eps[0.660465],durat[108],fnum=389536, cum_cl_rew = 2, cum_rew = 10,tot_cl = 9 , tot = 136
# epis[2480],eps[0.658851],durat[149],fnum=391150, cum_cl_rew = 8, cum_rew = 75,tot_cl = 10 , tot = 139
# epis[2490],eps[0.657261],durat[271],fnum=392740, cum_cl_rew = 13, cum_rew = 175,tot_cl = 9 , tot = 124
# epis[2500],eps[0.655450],durat[230],fnum=394551, cum_cl_rew = 17, cum_rew = 440,tot_cl = 10 , tot = 138
# epis[2510],eps[0.653443],durat[202],fnum=396558, cum_cl_rew = 20, cum_rew = 490,tot_cl = 11 , tot = 156
# epis[2520],eps[0.651937],durat[131],fnum=398064, cum_cl_rew = 9, cum_rew = 105,tot_cl = 11 , tot = 158
# epis[2530],eps[0.650720],durat[112],fnum=399281, cum_cl_rew = 7, cum_rew = 80,tot_cl = 10 , tot = 150
# epis[2540],eps[0.649172],durat[198],fnum=400829, cum_cl_rew = 11, cum_rew = 95,tot_cl = 11 , tot = 172
# epis[2550],eps[0.647777],durat[241],fnum=402224, cum_cl_rew = 14, cum_rew = 210,tot_cl = 10 , tot = 149
# epis[2560],eps[0.646005],durat[223],fnum=403996, cum_cl_rew = 14, cum_rew = 225,tot_cl = 9 , tot = 137
# epis[2570],eps[0.644325],durat[149],fnum=405676, cum_cl_rew = 15, cum_rew = 215,tot_cl = 9 , tot = 136
# epis[2580],eps[0.642617],durat[160],fnum=407384, cum_cl_rew = 10, cum_rew = 110,tot_cl = 10 , tot = 144
# epis[2590],eps[0.641132],durat[118],fnum=408869, cum_cl_rew = 7, cum_rew = 60,tot_cl = 10 , tot = 142
# epis[2600],eps[0.639506],durat[244],fnum=410495, cum_cl_rew = 17, cum_rew = 440,tot_cl = 11 , tot = 152
# epis[2610],eps[0.637999],durat[114],fnum=412002, cum_cl_rew = 7, cum_rew = 60,tot_cl = 10 , tot = 139
# epis[2620],eps[0.636498],durat[80],fnum=413503, cum_cl_rew = 4, cum_rew = 25,tot_cl = 10 , tot = 138
# epis[2630],eps[0.634816],durat[232],fnum=415185, cum_cl_rew = 21, cum_rew = 275,tot_cl = 10 , tot = 134
# epis[2640],eps[0.632943],durat[82],fnum=417058, cum_cl_rew = 3, cum_rew = 20,tot_cl = 10 , tot = 147
# epis[2650],eps[0.631181],durat[256],fnum=418820, cum_cl_rew = 16, cum_rew = 170,tot_cl = 11 , tot = 155
# epis[2660],eps[0.629720],durat[91],fnum=420281, cum_cl_rew = 6, cum_rew = 45,tot_cl = 11 , tot = 160
# epis[2670],eps[0.628318],durat[113],fnum=421683, cum_cl_rew = 5, cum_rew = 40,tot_cl = 11 , tot = 155
# epis[2680],eps[0.626961],durat[159],fnum=423040, cum_cl_rew = 9, cum_rew = 125,tot_cl = 10 , tot = 152
# epis[2690],eps[0.625695],durat[80],fnum=424306, cum_cl_rew = 5, cum_rew = 50,tot_cl = 9 , tot = 122
# epis[2700],eps[0.624521],durat[208],fnum=425480, cum_cl_rew = 13, cum_rew = 170,tot_cl = 8 , tot = 103
# epis[2710],eps[0.623066],durat[145],fnum=426935, cum_cl_rew = 10, cum_rew = 110,tot_cl = 8 , tot = 97
# epis[2720],eps[0.621309],durat[195],fnum=428692, cum_cl_rew = 8, cum_rew = 80,tot_cl = 8 , tot = 106
# epis[2730],eps[0.619662],durat[126],fnum=430339, cum_cl_rew = 4, cum_rew = 50,tot_cl = 9 , tot = 122
# epis[2740],eps[0.618049],durat[144],fnum=431952, cum_cl_rew = 5, cum_rew = 35,tot_cl = 9 , tot = 128
# epis[2750],eps[0.616640],durat[102],fnum=433361, cum_cl_rew = 5, cum_rew = 55,tot_cl = 10 , tot = 137
# epis[2760],eps[0.614973],durat[85],fnum=435028, cum_cl_rew = 5, cum_rew = 35,tot_cl = 10 , tot = 141
# epis[2770],eps[0.613239],durat[121],fnum=436762, cum_cl_rew = 4, cum_rew = 40,tot_cl = 10 , tot = 143
# epis[2780],eps[0.611540],durat[126],fnum=438461, cum_cl_rew = 6, cum_rew = 80,tot_cl = 9 , tot = 135
# epis[2790],eps[0.609972],durat[150],fnum=440029, cum_cl_rew = 10, cum_rew = 95,tot_cl = 9 , tot = 135
# epis[2800],eps[0.608590],durat[93],fnum=441411, cum_cl_rew = 4, cum_rew = 45,tot_cl = 10 , tot = 142
# epis[2810],eps[0.606993],durat[117],fnum=443008, cum_cl_rew = 3, cum_rew = 20,tot_cl = 9 , tot = 134
# epis[2820],eps[0.605517],durat[101],fnum=444484, cum_cl_rew = 4, cum_rew = 35,tot_cl = 9 , tot = 131
# epis[2830],eps[0.604076],durat[120],fnum=445925, cum_cl_rew = 6, cum_rew = 75,tot_cl = 9 , tot = 121
# epis[2840],eps[0.602563],durat[94],fnum=447438, cum_cl_rew = 2, cum_rew = 15,tot_cl = 9 , tot = 126
# epis[2850],eps[0.600997],durat[155],fnum=449004, cum_cl_rew = 13, cum_rew = 120,tot_cl = 9 , tot = 127
# epis[2860],eps[0.599316],durat[137],fnum=450685, cum_cl_rew = 10, cum_rew = 125,tot_cl = 10 , tot = 146
# epis[2870],eps[0.597481],durat[140],fnum=452520, cum_cl_rew = 10, cum_rew = 110,tot_cl = 11 , tot = 144
# epis[2880],eps[0.595786],durat[143],fnum=454215, cum_cl_rew = 7, cum_rew = 100,tot_cl = 11 , tot = 150
# epis[2890],eps[0.594051],durat[177],fnum=455950, cum_cl_rew = 12, cum_rew = 150,tot_cl = 11 , tot = 151
# epis[2900],eps[0.592645],durat[148],fnum=457356, cum_cl_rew = 15, cum_rew = 225,tot_cl = 11 , tot = 149
# epis[2910],eps[0.590919],durat[210],fnum=459082, cum_cl_rew = 11, cum_rew = 95,tot_cl = 10 , tot = 139
# epis[2920],eps[0.589426],durat[233],fnum=460575, cum_cl_rew = 16, cum_rew = 215,tot_cl = 10 , tot = 130
# epis[2930],eps[0.587867],durat[272],fnum=462134, cum_cl_rew = 20, cum_rew = 285,tot_cl = 10 , tot = 126
# epis[2940],eps[0.585918],durat[269],fnum=464083, cum_cl_rew = 19, cum_rew = 265,tot_cl = 10 , tot = 129
# epis[2950],eps[0.584222],durat[154],fnum=465779, cum_cl_rew = 14, cum_rew = 190,tot_cl = 11 , tot = 142
# epis[2960],eps[0.582560],durat[226],fnum=467441, cum_cl_rew = 15, cum_rew = 195,tot_cl = 10 , tot = 137
# epis[2970],eps[0.580713],durat[144],fnum=469288, cum_cl_rew = 5, cum_rew = 35,tot_cl = 11 , tot = 151
# epis[2980],eps[0.579223],durat[89],fnum=470778, cum_cl_rew = 2, cum_rew = 10,tot_cl = 11 , tot = 152
# epis[2990],eps[0.577566],durat[193],fnum=472435, cum_cl_rew = 8, cum_rew = 95,tot_cl = 10 , tot = 136
# epis[3000],eps[0.575955],durat[222],fnum=474046, cum_cl_rew = 15, cum_rew = 230,tot_cl = 10 , tot = 131
# epis[3010],eps[0.574306],durat[156],fnum=475695, cum_cl_rew = 14, cum_rew = 175,tot_cl = 10 , tot = 137
# epis[3020],eps[0.572756],durat[114],fnum=477245, cum_cl_rew = 5, cum_rew = 55,tot_cl = 10 , tot = 127
# epis[3030],eps[0.571184],durat[153],fnum=478817, cum_cl_rew = 7, cum_rew = 110,tot_cl = 10 , tot = 132
# epis[3040],eps[0.569535],durat[241],fnum=480466, cum_cl_rew = 18, cum_rew = 240,tot_cl = 10 , tot = 140
# epis[3050],eps[0.567749],durat[151],fnum=482252, cum_cl_rew = 7, cum_rew = 70,tot_cl = 11 , tot = 145
# epis[3060],eps[0.566281],durat[215],fnum=483720, cum_cl_rew = 7, cum_rew = 65,tot_cl = 10 , tot = 135
# epis[3070],eps[0.564804],durat[161],fnum=485197, cum_cl_rew = 9, cum_rew = 95,tot_cl = 9 , tot = 128
# epis[3080],eps[0.563350],durat[115],fnum=486651, cum_cl_rew = 7, cum_rew = 50,tot_cl = 9 , tot = 121
# epis[3090],eps[0.561696],durat[121],fnum=488305, cum_cl_rew = 8, cum_rew = 65,tot_cl = 10 , tot = 123
# epis[3100],eps[0.560014],durat[237],fnum=489987, cum_cl_rew = 19, cum_rew = 435,tot_cl = 9 , tot = 108
# epis[3110],eps[0.558283],durat[155],fnum=491718, cum_cl_rew = 14, cum_rew = 160,tot_cl = 10 , tot = 123
# epis[3120],eps[0.556381],durat[176],fnum=493620, cum_cl_rew = 8, cum_rew = 80,tot_cl = 11 , tot = 141
# epis[3130],eps[0.554284],durat[235],fnum=495717, cum_cl_rew = 22, cum_rew = 280,tot_cl = 12 , tot = 168
# epis[3140],eps[0.552821],durat[151],fnum=497180, cum_cl_rew = 10, cum_rew = 75,tot_cl = 12 , tot = 169
# epis[3150],eps[0.551197],durat[208],fnum=498804, cum_cl_rew = 13, cum_rew = 170,tot_cl = 12 , tot = 172
# epis[3160],eps[0.549454],durat[266],fnum=500547, cum_cl_rew = 13, cum_rew = 215,tot_cl = 11 , tot = 160
# epis[3170],eps[0.547862],durat[147],fnum=502139, cum_cl_rew = 5, cum_rew = 35,tot_cl = 11 , tot = 149
# epis[3180],eps[0.546243],durat[303],fnum=503758, cum_cl_rew = 22, cum_rew = 480,tot_cl = 10 , tot = 124
# epis[3190],eps[0.544556],durat[153],fnum=505445, cum_cl_rew = 13, cum_rew = 130,tot_cl = 10 , tot = 131
# epis[3200],eps[0.542940],durat[321],fnum=507061, cum_cl_rew = 21, cum_rew = 275,tot_cl = 10 , tot = 128
# epis[3210],eps[0.541509],durat[84],fnum=508492, cum_cl_rew = 6, cum_rew = 80,tot_cl = 10 , tot = 131
# epis[3220],eps[0.539791],durat[102],fnum=510210, cum_cl_rew = 4, cum_rew = 20,tot_cl = 10 , tot = 134
# epis[3230],eps[0.538013],durat[115],fnum=511988, cum_cl_rew = 5, cum_rew = 50,tot_cl = 10 , tot = 146
# epis[3240],eps[0.536295],durat[112],fnum=513706, cum_cl_rew = 3, cum_rew = 30,tot_cl = 10 , tot = 139
# epis[3250],eps[0.534618],durat[115],fnum=515383, cum_cl_rew = 5, cum_rew = 40,tot_cl = 11 , tot = 143
# epis[3260],eps[0.532980],durat[113],fnum=517021, cum_cl_rew = 7, cum_rew = 95,tot_cl = 11 , tot = 152
# epis[3270],eps[0.531219],durat[139],fnum=518782, cum_cl_rew = 11, cum_rew = 125,tot_cl = 11 , tot = 162
# epis[3280],eps[0.529837],durat[142],fnum=520164, cum_cl_rew = 7, cum_rew = 85,tot_cl = 11 , tot = 147
# epis[3290],eps[0.528053],durat[166],fnum=521948, cum_cl_rew = 11, cum_rew = 95,tot_cl = 11 , tot = 156
# epis[3300],eps[0.526087],durat[161],fnum=523914, cum_cl_rew = 8, cum_rew = 95,tot_cl = 11 , tot = 173
# epis[3310],eps[0.524496],durat[152],fnum=525505, cum_cl_rew = 12, cum_rew = 135,tot_cl = 11 , tot = 167
# epis[3320],eps[0.522700],durat[211],fnum=527301, cum_cl_rew = 11, cum_rew = 140,tot_cl = 11 , tot = 157
# epis[3330],eps[0.521076],durat[125],fnum=528925, cum_cl_rew = 10, cum_rew = 80,tot_cl = 12 , tot = 173
# epis[3340],eps[0.519328],durat[219],fnum=530673, cum_cl_rew = 15, cum_rew = 260,tot_cl = 12 , tot = 163
# epis[3350],eps[0.517724],durat[196],fnum=532277, cum_cl_rew = 19, cum_rew = 250,tot_cl = 12 , tot = 151
# epis[3360],eps[0.516163],durat[81],fnum=533838, cum_cl_rew = 5, cum_rew = 40,tot_cl = 11 , tot = 153
# epis[3370],eps[0.513992],durat[245],fnum=536009, cum_cl_rew = 22, cum_rew = 285,tot_cl = 12 , tot = 164
# epis[3380],eps[0.512191],durat[190],fnum=537810, cum_cl_rew = 9, cum_rew = 305,tot_cl = 12 , tot = 160
# epis[3390],eps[0.510420],durat[113],fnum=539581, cum_cl_rew = 6, cum_rew = 40,tot_cl = 12 , tot = 163
# epis[3400],eps[0.508813],durat[175],fnum=541188, cum_cl_rew = 17, cum_rew = 220,tot_cl = 12 , tot = 158
# epis[3410],eps[0.507022],durat[220],fnum=542979, cum_cl_rew = 16, cum_rew = 205,tot_cl = 12 , tot = 159
# epis[3420],eps[0.505473],durat[130],fnum=544528, cum_cl_rew = 9, cum_rew = 105,tot_cl = 11 , tot = 145
# epis[3430],eps[0.503976],durat[112],fnum=546025, cum_cl_rew = 5, cum_rew = 50,tot_cl = 11 , tot = 137
# epis[3440],eps[0.502460],durat[240],fnum=547541, cum_cl_rew = 18, cum_rew = 220,tot_cl = 10 , tot = 120
# epis[3450],eps[0.501030],durat[136],fnum=548971, cum_cl_rew = 12, cum_rew = 145,tot_cl = 10 , tot = 121
# epis[3460],eps[0.499465],durat[93],fnum=550536, cum_cl_rew = 7, cum_rew = 60,tot_cl = 9 , tot = 122
# epis[3470],eps[0.497643],durat[215],fnum=552358, cum_cl_rew = 15, cum_rew = 160,tot_cl = 9 , tot = 129
# epis[3480],eps[0.496073],durat[119],fnum=553928, cum_cl_rew = 6, cum_rew = 55,tot_cl = 10 , tot = 138
# epis[3490],eps[0.494497],durat[148],fnum=555504, cum_cl_rew = 13, cum_rew = 190,tot_cl = 10 , tot = 147
# epis[3500],eps[0.492906],durat[89],fnum=557095, cum_cl_rew = 5, cum_rew = 30,tot_cl = 11 , tot = 150
# epis[3510],eps[0.491319],durat[256],fnum=558682, cum_cl_rew = 19, cum_rew = 230,tot_cl = 10 , tot = 137
# epis[3520],eps[0.489583],durat[262],fnum=560418, cum_cl_rew = 15, cum_rew = 205,tot_cl = 11 , tot = 134
# epis[3530],eps[0.487917],durat[268],fnum=562084, cum_cl_rew = 16, cum_rew = 185,tot_cl = 10 , tot = 124
# epis[3540],eps[0.486231],durat[141],fnum=563770, cum_cl_rew = 9, cum_rew = 105,tot_cl = 11 , tot = 133
# epis[3550],eps[0.484750],durat[117],fnum=565251, cum_cl_rew = 7, cum_rew = 110,tot_cl = 10 , tot = 131
# epis[3560],eps[0.483086],durat[121],fnum=566915, cum_cl_rew = 5, cum_rew = 40,tot_cl = 10 , tot = 134
# epis[3570],eps[0.481535],durat[77],fnum=568466, cum_cl_rew = 5, cum_rew = 40,tot_cl = 10 , tot = 134
# epis[3580],eps[0.480155],durat[85],fnum=569846, cum_cl_rew = 6, cum_rew = 70,tot_cl = 10 , tot = 132
# epis[3590],eps[0.478563],durat[215],fnum=571438, cum_cl_rew = 15, cum_rew = 235,tot_cl = 9 , tot = 120
# epis[3600],eps[0.476898],durat[124],fnum=573103, cum_cl_rew = 7, cum_rew = 60,tot_cl = 10 , tot = 124
# epis[3610],eps[0.474860],durat[257],fnum=575141, cum_cl_rew = 17, cum_rew = 425,tot_cl = 10 , tot = 144
# epis[3620],eps[0.473368],durat[106],fnum=576633, cum_cl_rew = 1, cum_rew = 5,tot_cl = 11 , tot = 154
# epis[3630],eps[0.471784],durat[152],fnum=578217, cum_cl_rew = 9, cum_rew = 75,tot_cl = 11 , tot = 154
# epis[3640],eps[0.470150],durat[153],fnum=579851, cum_cl_rew = 12, cum_rew = 150,tot_cl = 11 , tot = 157
# epis[3650],eps[0.468417],durat[191],fnum=581584, cum_cl_rew = 13, cum_rew = 130,tot_cl = 11 , tot = 161
# epis[3660],eps[0.466892],durat[228],fnum=583109, cum_cl_rew = 15, cum_rew = 190,tot_cl = 11 , tot = 138
# epis[3670],eps[0.465076],durat[234],fnum=584925, cum_cl_rew = 12, cum_rew = 190,tot_cl = 10 , tot = 129
# epis[3680],eps[0.463469],durat[214],fnum=586532, cum_cl_rew = 16, cum_rew = 200,tot_cl = 11 , tot = 136
# epis[3690],eps[0.461994],durat[140],fnum=588007, cum_cl_rew = 6, cum_rew = 45,tot_cl = 11 , tot = 139
# epis[3700],eps[0.460144],durat[148],fnum=589857, cum_cl_rew = 11, cum_rew = 120,tot_cl = 10 , tot = 130
# epis[3710],eps[0.458222],durat[169],fnum=591779, cum_cl_rew = 12, cum_rew = 135,tot_cl = 11 , tot = 145
# epis[3720],eps[0.456676],durat[207],fnum=593325, cum_cl_rew = 24, cum_rew = 325,tot_cl = 11 , tot = 146
# epis[3730],eps[0.454955],durat[190],fnum=595046, cum_cl_rew = 18, cum_rew = 220,tot_cl = 11 , tot = 155
# epis[3740],eps[0.453084],durat[222],fnum=596917, cum_cl_rew = 14, cum_rew = 160,tot_cl = 12 , tot = 166
# epis[3750],eps[0.451294],durat[162],fnum=598707, cum_cl_rew = 10, cum_rew = 140,tot_cl = 12 , tot = 177
# epis[3760],eps[0.449233],durat[88],fnum=600768, cum_cl_rew = 6, cum_rew = 65,tot_cl = 12 , tot = 187
# epis[3770],eps[0.447534],durat[152],fnum=602467, cum_cl_rew = 14, cum_rew = 145,tot_cl = 12 , tot = 185
# epis[3780],eps[0.445965],durat[282],fnum=604036, cum_cl_rew = 20, cum_rew = 305,tot_cl = 11 , tot = 169
# epis[3790],eps[0.444337],durat[88],fnum=605664, cum_cl_rew = 7, cum_rew = 45,tot_cl = 12 , tot = 173
# epis[3800],eps[0.442631],durat[109],fnum=607370, cum_cl_rew = 5, cum_rew = 55,tot_cl = 12 , tot = 166
# epis[3810],eps[0.440870],durat[214],fnum=609131, cum_cl_rew = 20, cum_rew = 250,tot_cl = 11 , tot = 149
# epis[3820],eps[0.439425],durat[129],fnum=610576, cum_cl_rew = 11, cum_rew = 115,tot_cl = 11 , tot = 143
# epis[3830],eps[0.437811],durat[137],fnum=612190, cum_cl_rew = 11, cum_rew = 120,tot_cl = 11 , tot = 146
# epis[3840],eps[0.436435],durat[146],fnum=613566, cum_cl_rew = 12, cum_rew = 115,tot_cl = 11 , tot = 132
# epis[3850],eps[0.434663],durat[156],fnum=615338, cum_cl_rew = 12, cum_rew = 125,tot_cl = 10 , tot = 125
# epis[3860],eps[0.432850],durat[124],fnum=617151, cum_cl_rew = 8, cum_rew = 110,tot_cl = 10 , tot = 129
# epis[3870],eps[0.431100],durat[150],fnum=618901, cum_cl_rew = 11, cum_rew = 105,tot_cl = 11 , tot = 146
# epis[3880],eps[0.429552],durat[165],fnum=620449, cum_cl_rew = 13, cum_rew = 170,tot_cl = 11 , tot = 143
# epis[3890],eps[0.427883],durat[250],fnum=622118, cum_cl_rew = 11, cum_rew = 135,tot_cl = 11 , tot = 149
# epis[3900],eps[0.426273],durat[183],fnum=623728, cum_cl_rew = 14, cum_rew = 390,tot_cl = 12 , tot = 150
# epis[3910],eps[0.424824],durat[96],fnum=625177, cum_cl_rew = 6, cum_rew = 55,tot_cl = 11 , tot = 150
# epis[3920],eps[0.423160],durat[322],fnum=626841, cum_cl_rew = 15, cum_rew = 200,tot_cl = 10 , tot = 136
# epis[3930],eps[0.421407],durat[111],fnum=628594, cum_cl_rew = 7, cum_rew = 55,tot_cl = 11 , tot = 147
# epis[3940],eps[0.420185],durat[89],fnum=629816, cum_cl_rew = 7, cum_rew = 70,tot_cl = 10 , tot = 136
# epis[3950],eps[0.418792],durat[160],fnum=631209, cum_cl_rew = 11, cum_rew = 110,tot_cl = 9 , tot = 126
# epis[3960],eps[0.417218],durat[150],fnum=632783, cum_cl_rew = 13, cum_rew = 180,tot_cl = 9 , tot = 119
# epis[3970],eps[0.415633],durat[236],fnum=634368, cum_cl_rew = 19, cum_rew = 255,tot_cl = 9 , tot = 117
# epis[3980],eps[0.414150],durat[168],fnum=635851, cum_cl_rew = 12, cum_rew = 175,tot_cl = 9 , tot = 109
# epis[3990],eps[0.412509],durat[211],fnum=637492, cum_cl_rew = 15, cum_rew = 225,tot_cl = 9 , tot = 121
# epis[4000],eps[0.410897],durat[154],fnum=639104, cum_cl_rew = 9, cum_rew = 125,tot_cl = 10 , tot = 135
# epis[4010],eps[0.409498],durat[125],fnum=640503, cum_cl_rew = 10, cum_rew = 90,tot_cl = 9 , tot = 129
# epis[4020],eps[0.407728],durat[201],fnum=642273, cum_cl_rew = 18, cum_rew = 205,tot_cl = 10 , tot = 139
# epis[4030],eps[0.405904],durat[210],fnum=644097, cum_cl_rew = 8, cum_rew = 95,tot_cl = 11 , tot = 145
# epis[4040],eps[0.404211],durat[282],fnum=645790, cum_cl_rew = 18, cum_rew = 430,tot_cl = 11 , tot = 143
# epis[4050],eps[0.402768],durat[164],fnum=647233, cum_cl_rew = 14, cum_rew = 145,tot_cl = 10 , tot = 140
# epis[4060],eps[0.401065],durat[156],fnum=648936, cum_cl_rew = 9, cum_rew = 90,tot_cl = 11 , tot = 144
# epis[4070],eps[0.399245],durat[222],fnum=650756, cum_cl_rew = 16, cum_rew = 180,tot_cl = 11 , tot = 143
# epis[4080],eps[0.397599],durat[159],fnum=652402, cum_cl_rew = 6, cum_rew = 70,tot_cl = 10 , tot = 150
# epis[4090],eps[0.395699],durat[160],fnum=654302, cum_cl_rew = 12, cum_rew = 190,tot_cl = 10 , tot = 149
# epis[4100],eps[0.394047],durat[124],fnum=655954, cum_cl_rew = 12, cum_rew = 130,tot_cl = 10 , tot = 157
# epis[4110],eps[0.392044],durat[204],fnum=657957, cum_cl_rew = 8, cum_rew = 120,tot_cl = 11 , tot = 167
# epis[4120],eps[0.390397],durat[162],fnum=659604, cum_cl_rew = 9, cum_rew = 75,tot_cl = 11 , tot = 159
# epis[4130],eps[0.388527],durat[273],fnum=661474, cum_cl_rew = 16, cum_rew = 255,tot_cl = 11 , tot = 153
# epis[4140],eps[0.386811],durat[96],fnum=663190, cum_cl_rew = 6, cum_rew = 55,tot_cl = 11 , tot = 155
# epis[4150],eps[0.385023],durat[179],fnum=664978, cum_cl_rew = 11, cum_rew = 145,tot_cl = 11 , tot = 150
# epis[4160],eps[0.383522],durat[118],fnum=666479, cum_cl_rew = 9, cum_rew = 75,tot_cl = 10 , tot = 142
# epis[4170],eps[0.381934],durat[113],fnum=668067, cum_cl_rew = 7, cum_rew = 60,tot_cl = 10 , tot = 144
# epis[4180],eps[0.380260],durat[216],fnum=669741, cum_cl_rew = 13, cum_rew = 340,tot_cl = 10 , tot = 141
# epis[4190],eps[0.378440],durat[254],fnum=671561, cum_cl_rew = 15, cum_rew = 230,tot_cl = 10 , tot = 136
# epis[4200],eps[0.376469],durat[231],fnum=673532, cum_cl_rew = 13, cum_rew = 160,tot_cl = 10 , tot = 145
# epis[4210],eps[0.374528],durat[154],fnum=675473, cum_cl_rew = 15, cum_rew = 205,tot_cl = 11 , tot = 161
# epis[4220],eps[0.372714],durat[247],fnum=677287, cum_cl_rew = 17, cum_rew = 440,tot_cl = 12 , tot = 166
# epis[4230],eps[0.370967],durat[119],fnum=679034, cum_cl_rew = 9, cum_rew = 100,tot_cl = 12 , tot = 173
# epis[4240],eps[0.369356],durat[125],fnum=680645, cum_cl_rew = 7, cum_rew = 65,tot_cl = 12 , tot = 179
# epis[4250],eps[0.367544],durat[207],fnum=682457, cum_cl_rew = 16, cum_rew = 220,tot_cl = 12 , tot = 175
# epis[4260],eps[0.366115],durat[123],fnum=683886, cum_cl_rew = 5, cum_rew = 30,tot_cl = 11 , tot = 161
# epis[4270],eps[0.364490],durat[89],fnum=685511, cum_cl_rew = 4, cum_rew = 30,tot_cl = 11 , tot = 150
# epis[4280],eps[0.362980],durat[119],fnum=687021, cum_cl_rew = 11, cum_rew = 105,tot_cl = 11 , tot = 145
# epis[4290],eps[0.361544],durat[158],fnum=688457, cum_cl_rew = 11, cum_rew = 130,tot_cl = 10 , tot = 136
# epis[4300],eps[0.360053],durat[107],fnum=689948, cum_cl_rew = 3, cum_rew = 20,tot_cl = 10 , tot = 126
# epis[4310],eps[0.358399],durat[154],fnum=691602, cum_cl_rew = 10, cum_rew = 85,tot_cl = 10 , tot = 126
# epis[4320],eps[0.356697],durat[193],fnum=693304, cum_cl_rew = 12, cum_rew = 350,tot_cl = 10 , tot = 126
# epis[4330],eps[0.354848],durat[152],fnum=695153, cum_cl_rew = 14, cum_rew = 140,tot_cl = 10 , tot = 133
# epis[4340],eps[0.353324],durat[162],fnum=696677, cum_cl_rew = 12, cum_rew = 125,tot_cl = 10 , tot = 137
# epis[4350],eps[0.351457],durat[207],fnum=698544, cum_cl_rew = 17, cum_rew = 280,tot_cl = 11 , tot = 147
# epis[4360],eps[0.349727],durat[172],fnum=700274, cum_cl_rew = 11, cum_rew = 110,tot_cl = 12 , tot = 154
# epis[4370],eps[0.347854],durat[199],fnum=702147, cum_cl_rew = 10, cum_rew = 130,tot_cl = 12 , tot = 166
# epis[4380],eps[0.346199],durat[118],fnum=703802, cum_cl_rew = 15, cum_rew = 175,tot_cl = 13 , tot = 167
# epis[4390],eps[0.344535],durat[188],fnum=705466, cum_cl_rew = 14, cum_rew = 200,tot_cl = 12 , tot = 164
# epis[4400],eps[0.342998],durat[83],fnum=707003, cum_cl_rew = 4, cum_rew = 20,tot_cl = 12 , tot = 159
# epis[4410],eps[0.341525],durat[247],fnum=708476, cum_cl_rew = 18, cum_rew = 265,tot_cl = 11 , tot = 145
# epis[4420],eps[0.339682],durat[264],fnum=710319, cum_cl_rew = 14, cum_rew = 165,tot_cl = 10 , tot = 140
# epis[4430],eps[0.338234],durat[124],fnum=711767, cum_cl_rew = 8, cum_rew = 80,tot_cl = 10 , tot = 127
# epis[4440],eps[0.336400],durat[230],fnum=713601, cum_cl_rew = 22, cum_rew = 345,tot_cl = 10 , tot = 122
# epis[4450],eps[0.335020],durat[97],fnum=714981, cum_cl_rew = 5, cum_rew = 35,tot_cl = 9 , tot = 124
# epis[4460],eps[0.333645],durat[89],fnum=716356, cum_cl_rew = 6, cum_rew = 45,tot_cl = 10 , tot = 123
# epis[4470],eps[0.331931],durat[138],fnum=718070, cum_cl_rew = 10, cum_rew = 80,tot_cl = 10 , tot = 120
# epis[4480],eps[0.330343],durat[200],fnum=719658, cum_cl_rew = 14, cum_rew = 175,tot_cl = 9 , tot = 113
# epis[4490],eps[0.328461],durat[232],fnum=721540, cum_cl_rew = 18, cum_rew = 200,tot_cl = 10 , tot = 125
# epis[4500],eps[0.326866],durat[155],fnum=723135, cum_cl_rew = 14, cum_rew = 125,tot_cl = 10 , tot = 130
# epis[4510],eps[0.325331],durat[127],fnum=724670, cum_cl_rew = 4, cum_rew = 45,tot_cl = 10 , tot = 137
# epis[4520],eps[0.323488],durat[134],fnum=726513, cum_cl_rew = 8, cum_rew = 65,tot_cl = 10 , tot = 140
# epis[4530],eps[0.321579],durat[203],fnum=728422, cum_cl_rew = 22, cum_rew = 315,tot_cl = 11 , tot = 154
# epis[4540],eps[0.319661],durat[264],fnum=730340, cum_cl_rew = 17, cum_rew = 405,tot_cl = 11 , tot = 153
# epis[4550],eps[0.317729],durat[155],fnum=732272, cum_cl_rew = 11, cum_rew = 155,tot_cl = 11 , tot = 162
# epis[4560],eps[0.316166],durat[153],fnum=733835, cum_cl_rew = 14, cum_rew = 165,tot_cl = 11 , tot = 163
# epis[4570],eps[0.314451],durat[116],fnum=735550, cum_cl_rew = 9, cum_rew = 85,tot_cl = 11 , tot = 170
# epis[4580],eps[0.312903],durat[120],fnum=737098, cum_cl_rew = 11, cum_rew = 125,tot_cl = 11 , tot = 169
# epis[4590],eps[0.310890],durat[160],fnum=739111, cum_cl_rew = 9, cum_rew = 75,tot_cl = 11 , tot = 174
# epis[4600],eps[0.309355],durat[217],fnum=740646, cum_cl_rew = 15, cum_rew = 220,tot_cl = 11 , tot = 154
# epis[4610],eps[0.307336],durat[150],fnum=742665, cum_cl_rew = 11, cum_rew = 175,tot_cl = 11 , tot = 157
# epis[4620],eps[0.305630],durat[144],fnum=744371, cum_cl_rew = 5, cum_rew = 30,tot_cl = 11 , tot = 148
# epis[4630],eps[0.303765],durat[190],fnum=746236, cum_cl_rew = 13, cum_rew = 140,tot_cl = 11 , tot = 152
# epis[4640],eps[0.301959],durat[174],fnum=748042, cum_cl_rew = 12, cum_rew = 185,tot_cl = 10 , tot = 140
# epis[4650],eps[0.300326],durat[119],fnum=749675, cum_cl_rew = 5, cum_rew = 30,tot_cl = 11 , tot = 148
# epis[4660],eps[0.298593],durat[189],fnum=751408, cum_cl_rew = 10, cum_rew = 270,tot_cl = 10 , tot = 140
# epis[4670],eps[0.297191],durat[130],fnum=752810, cum_cl_rew = 5, cum_rew = 55,tot_cl = 10 , tot = 134
# epis[4680],eps[0.295326],durat[157],fnum=754675, cum_cl_rew = 12, cum_rew = 135,tot_cl = 9 , tot = 124
# ...
# epis[6400],eps[0.100000],durat[163],fnum=1089819, cum_cl_rew = 10, cum_rew = 95,tot_cl = 15 , tot = 242
# epis[6410],eps[0.100000],durat[292],fnum=1092045, cum_cl_rew = 18, cum_rew = 290,tot_cl = 14 , tot = 207
# epis[6420],eps[0.100000],durat[197],fnum=1094054, cum_cl_rew = 17, cum_rew = 215,tot_cl = 14 , tot = 198
# epis[6430],eps[0.100000],durat[128],fnum=1096208, cum_cl_rew = 14, cum_rew = 150,tot_cl = 14 , tot = 204
# epis[6440],eps[0.100000],durat[189],fnum=1097895, cum_cl_rew = 15, cum_rew = 230,tot_cl = 13 , tot = 190
# epis[6450],eps[0.100000],durat[237],fnum=1100019, cum_cl_rew = 18, cum_rew = 275,tot_cl = 13 , tot = 188
# epis[6460],eps[0.100000],durat[306],fnum=1102620, cum_cl_rew = 18, cum_rew = 425,tot_cl = 14 , tot = 209
# epis[6470],eps[0.100000],durat[203],fnum=1105045, cum_cl_rew = 13, cum_rew = 155,tot_cl = 14 , tot = 222
# epis[6480],eps[0.100000],durat[123],fnum=1106952, cum_cl_rew = 5, cum_rew = 45,tot_cl = 13 , tot = 215
# epis[6490],eps[0.100000],durat[254],fnum=1109083, cum_cl_rew = 17, cum_rew = 440,tot_cl = 14 , tot = 224
# epis[6500],eps[0.100000],durat[187],fnum=1111148, cum_cl_rew = 19, cum_rew = 260,tot_cl = 14 , tot = 234
# epis[6510],eps[0.100000],durat[240],fnum=1113314, cum_cl_rew = 22, cum_rew = 275,tot_cl = 14 , tot = 229
# epis[6520],eps[0.100000],durat[242],fnum=1115482, cum_cl_rew = 22, cum_rew = 500,tot_cl = 14 , tot = 221
# epis[6530],eps[0.100000],durat[254],fnum=1117677, cum_cl_rew = 17, cum_rew = 415,tot_cl = 14 , tot = 229
# epis[6540],eps[0.100000],durat[164],fnum=1119632, cum_cl_rew = 19, cum_rew = 280,tot_cl = 15 , tot = 237
# epis[6550],eps[0.100000],durat[231],fnum=1121937, cum_cl_rew = 10, cum_rew = 125,tot_cl = 16 , tot = 254
# epis[6560],eps[0.100000],durat[209],fnum=1124197, cum_cl_rew = 10, cum_rew = 95,tot_cl = 16 , tot = 255
# epis[6570],eps[0.100000],durat[343],fnum=1126819, cum_cl_rew = 23, cum_rew = 320,tot_cl = 16 , tot = 251
# epis[6580],eps[0.100000],durat[165],fnum=1128967, cum_cl_rew = 15, cum_rew = 205,tot_cl = 16 , tot = 251
# epis[6590],eps[0.100000],durat[233],fnum=1131332, cum_cl_rew = 23, cum_rew = 350,tot_cl = 16 , tot = 266
# epis[6600],eps[0.100000],durat[220],fnum=1133148, cum_cl_rew = 12, cum_rew = 155,tot_cl = 15 , tot = 241
# epis[6610],eps[0.100000],durat[192],fnum=1135421, cum_cl_rew = 17, cum_rew = 210,tot_cl = 15 , tot = 235
# epis[6620],eps[0.100000],durat[172],fnum=1138116, cum_cl_rew = 17, cum_rew = 205,tot_cl = 15 , tot = 243
# epis[6630],eps[0.100000],durat[371],fnum=1140319, cum_cl_rew = 28, cum_rew = 435,tot_cl = 15 , tot = 240
# epis[6640],eps[0.100000],durat[255],fnum=1142527, cum_cl_rew = 16, cum_rew = 235,tot_cl = 16 , tot = 240
# epis[6650],eps[0.100000],durat[249],fnum=1144908, cum_cl_rew = 15, cum_rew = 205,tot_cl = 16 , tot = 256
# epis[6660],eps[0.100000],durat[259],fnum=1147255, cum_cl_rew = 16, cum_rew = 185,tot_cl = 16 , tot = 265
# epis[6670],eps[0.100000],durat[461],fnum=1149562, cum_cl_rew = 20, cum_rew = 660,tot_cl = 15 , tot = 258
# epis[6680],eps[0.100000],durat[156],fnum=1151820, cum_cl_rew = 13, cum_rew = 125,tot_cl = 15 , tot = 275
# epis[6690],eps[0.100000],durat[149],fnum=1153808, cum_cl_rew = 9, cum_rew = 95,tot_cl = 15 , tot = 256
# epis[6700],eps[0.100000],durat[162],fnum=1156330, cum_cl_rew = 12, cum_rew = 120,tot_cl = 14 , tot = 243
# epis[6710],eps[0.100000],durat[165],fnum=1158116, cum_cl_rew = 11, cum_rew = 150,tot_cl = 14 , tot = 220
# epis[6720],eps[0.100000],durat[274],fnum=1160274, cum_cl_rew = 18, cum_rew = 455,tot_cl = 14 , tot = 215
# epis[6730],eps[0.100000],durat[216],fnum=1162801, cum_cl_rew = 14, cum_rew = 160,tot_cl = 14 , tot = 209
# epis[6740],eps[0.100000],durat[261],fnum=1165092, cum_cl_rew = 16, cum_rew = 620,tot_cl = 14 , tot = 206
# epis[6750],eps[0.100000],durat[150],fnum=1167308, cum_cl_rew = 10, cum_rew = 85,tot_cl = 14 , tot = 214
# epis[6760],eps[0.100000],durat[215],fnum=1169592, cum_cl_rew = 13, cum_rew = 350,tot_cl = 14 , tot = 207
# epis[6770],eps[0.100000],durat[299],fnum=1171996, cum_cl_rew = 15, cum_rew = 380,tot_cl = 14 , tot = 221
# epis[6780],eps[0.100000],durat[149],fnum=1174421, cum_cl_rew = 11, cum_rew = 125,tot_cl = 13 , tot = 217
# epis[6790],eps[0.100000],durat[304],fnum=1176577, cum_cl_rew = 19, cum_rew = 285,tot_cl = 13 , tot = 214
# epis[6800],eps[0.100000],durat[251],fnum=1178733, cum_cl_rew = 14, cum_rew = 200,tot_cl = 13 , tot = 207
# epis[6810],eps[0.100000],durat[205],fnum=1181208, cum_cl_rew = 17, cum_rew = 195,tot_cl = 14 , tot = 229
# epis[6820],eps[0.100000],durat[344],fnum=1183520, cum_cl_rew = 20, cum_rew = 295,tot_cl = 14 , tot = 217
# epis[6830],eps[0.100000],durat[473],fnum=1186171, cum_cl_rew = 26, cum_rew = 600,tot_cl = 14 , tot = 210
# epis[6840],eps[0.100000],durat[296],fnum=1188708, cum_cl_rew = 15, cum_rew = 200,tot_cl = 15 , tot = 240
# epis[6850],eps[0.100000],durat[183],fnum=1190843, cum_cl_rew = 20, cum_rew = 300,tot_cl = 15 , tot = 232
# epis[6860],eps[0.100000],durat[219],fnum=1193004, cum_cl_rew = 15, cum_rew = 170,tot_cl = 15 , tot = 233
# epis[6870],eps[0.100000],durat[245],fnum=1195458, cum_cl_rew = 13, cum_rew = 170,tot_cl = 15 , tot = 243
# epis[6880],eps[0.100000],durat[250],fnum=1197930, cum_cl_rew = 14, cum_rew = 185,tot_cl = 15 , tot = 248
# epis[6890],eps[0.100000],durat[230],fnum=1200420, cum_cl_rew = 16, cum_rew = 350,tot_cl = 15 , tot = 242
# epis[6900],eps[0.100000],durat[129],fnum=1202410, cum_cl_rew = 11, cum_rew = 95,tot_cl = 15 , tot = 246
# epis[6910],eps[0.100000],durat[240],fnum=1204399, cum_cl_rew = 16, cum_rew = 180,tot_cl = 15 , tot = 247
# epis[6920],eps[0.100000],durat[261],fnum=1206883, cum_cl_rew = 15, cum_rew = 225,tot_cl = 15 , tot = 237
# epis[6930],eps[0.100000],durat[249],fnum=1209277, cum_cl_rew = 16, cum_rew = 205,tot_cl = 15 , tot = 247
# epis[6940],eps[0.100000],durat[146],fnum=1211487, cum_cl_rew = 10, cum_rew = 120,tot_cl = 15 , tot = 232
# epis[6950],eps[0.100000],durat[210],fnum=1213897, cum_cl_rew = 18, cum_rew = 230,tot_cl = 15 , tot = 235
# epis[6960],eps[0.100000],durat[222],fnum=1216001, cum_cl_rew = 15, cum_rew = 185,tot_cl = 16 , tot = 235
# epis[6970],eps[0.100000],durat[202],fnum=1218272, cum_cl_rew = 8, cum_rew = 115,tot_cl = 16 , tot = 240
# epis[6980],eps[0.100000],durat[121],fnum=1220326, cum_cl_rew = 10, cum_rew = 140,tot_cl = 15 , tot = 232
# epis[6990],eps[0.100000],durat[160],fnum=1222761, cum_cl_rew = 15, cum_rew = 190,tot_cl = 16 , tot = 247
# epis[7000],eps[0.100000],durat[221],fnum=1224929, cum_cl_rew = 13, cum_rew = 175,tot_cl = 16 , tot = 255
# epis[7010],eps[0.100000],durat[313],fnum=1227784, cum_cl_rew = 34, cum_rew = 575,tot_cl = 17 , tot = 267
# epis[7020],eps[0.100000],durat[254],fnum=1230409, cum_cl_rew = 12, cum_rew = 175,tot_cl = 17 , tot = 282
# epis[7030],eps[0.100000],durat[292],fnum=1232897, cum_cl_rew = 14, cum_rew = 180,tot_cl = 17 , tot = 278
# epis[7040],eps[0.100000],durat[281],fnum=1235381, cum_cl_rew = 15, cum_rew = 215,tot_cl = 17 , tot = 277
# epis[7050],eps[0.100000],durat[259],fnum=1237732, cum_cl_rew = 13, cum_rew = 355,tot_cl = 17 , tot = 284
# epis[7060],eps[0.100000],durat[212],fnum=1240201, cum_cl_rew = 18, cum_rew = 235,tot_cl = 18 , tot = 294
# epis[7070],eps[0.100000],durat[339],fnum=1243087, cum_cl_rew = 18, cum_rew = 270,tot_cl = 18 , tot = 302
# epis[7080],eps[0.100000],durat[349],fnum=1245464, cum_cl_rew = 21, cum_rew = 275,tot_cl = 18 , tot = 302
# epis[7090],eps[0.100000],durat[327],fnum=1248035, cum_cl_rew = 19, cum_rew = 255,tot_cl = 18 , tot = 293
# epis[7100],eps[0.100000],durat[252],fnum=1250205, cum_cl_rew = 16, cum_rew = 220,tot_cl = 17 , tot = 278
# epis[7110],eps[0.100000],durat[354],fnum=1252925, cum_cl_rew = 29, cum_rew = 840,tot_cl = 17 , tot = 254
# epis[7120],eps[0.100000],durat[209],fnum=1255443, cum_cl_rew = 18, cum_rew = 220,tot_cl = 16 , tot = 255
# epis[7130],eps[0.100000],durat[276],fnum=1257727, cum_cl_rew = 16, cum_rew = 220,tot_cl = 17 , tot = 267
# epis[7140],eps[0.100000],durat[330],fnum=1260264, cum_cl_rew = 21, cum_rew = 295,tot_cl = 16 , tot = 271
# epis[7150],eps[0.100000],durat[172],fnum=1262433, cum_cl_rew = 16, cum_rew = 200,tot_cl = 17 , tot = 271
# epis[7160],eps[0.100000],durat[227],fnum=1264698, cum_cl_rew = 15, cum_rew = 205,tot_cl = 16 , tot = 268
# epis[7170],eps[0.100000],durat[270],fnum=1267212, cum_cl_rew = 29, cum_rew = 620,tot_cl = 16 , tot = 253
# epis[7180],eps[0.100000],durat[215],fnum=1269446, cum_cl_rew = 16, cum_rew = 190,tot_cl = 16 , tot = 243
# epis[7190],eps[0.100000],durat[148],fnum=1271493, cum_cl_rew = 14, cum_rew = 185,tot_cl = 17 , tot = 245
# epis[7200],eps[0.100000],durat[307],fnum=1273678, cum_cl_rew = 19, cum_rew = 275,tot_cl = 16 , tot = 248
# epis[7210],eps[0.100000],durat[279],fnum=1276438, cum_cl_rew = 13, cum_rew = 345,tot_cl = 17 , tot = 269
# epis[7220],eps[0.100000],durat[251],fnum=1278782, cum_cl_rew = 24, cum_rew = 345,tot_cl = 17 , tot = 266
# epis[7230],eps[0.100000],durat[241],fnum=1281025, cum_cl_rew = 14, cum_rew = 195,tot_cl = 17 , tot = 265
# epis[7240],eps[0.100000],durat[233],fnum=1283154, cum_cl_rew = 17, cum_rew = 245,tot_cl = 16 , tot = 255
# epis[7250],eps[0.100000],durat[140],fnum=1285099, cum_cl_rew = 5, cum_rew = 55,tot_cl = 17 , tot = 256
# epis[7260],eps[0.100000],durat[270],fnum=1287526, cum_cl_rew = 24, cum_rew = 365,tot_cl = 15 , tot = 233
# epis[7270],eps[0.100000],durat[223],fnum=1290158, cum_cl_rew = 13, cum_rew = 175,tot_cl = 16 , tot = 243
# epis[7280],eps[0.100000],durat[159],fnum=1292308, cum_cl_rew = 15, cum_rew = 205,tot_cl = 15 , tot = 234
# epis[7290],eps[0.100000],durat[168],fnum=1294449, cum_cl_rew = 11, cum_rew = 110,tot_cl = 15 , tot = 233
# epis[7300],eps[0.100000],durat[357],fnum=1297183, cum_cl_rew = 20, cum_rew = 455,tot_cl = 16 , tot = 233
# epis[7310],eps[0.100000],durat[249],fnum=1299707, cum_cl_rew = 15, cum_rew = 180,tot_cl = 16 , tot = 243
# epis[7320],eps[0.100000],durat[201],fnum=1301838, cum_cl_rew = 17, cum_rew = 260,tot_cl = 15 , tot = 225
# epis[7330],eps[0.100000],durat[159],fnum=1303976, cum_cl_rew = 12, cum_rew = 130,tot_cl = 15 , tot = 217
# epis[7340],eps[0.100000],durat[331],fnum=1306316, cum_cl_rew = 26, cum_rew = 390,tot_cl = 15 , tot = 229
# epis[7350],eps[0.100000],durat[281],fnum=1308494, cum_cl_rew = 21, cum_rew = 300,tot_cl = 15 , tot = 229
# epis[7360],eps[0.100000],durat[193],fnum=1310853, cum_cl_rew = 22, cum_rew = 320,tot_cl = 16 , tot = 230
# epis[7370],eps[0.100000],durat[283],fnum=1313513, cum_cl_rew = 16, cum_rew = 215,tot_cl = 16 , tot = 231
# epis[7380],eps[0.100000],durat[277],fnum=1315968, cum_cl_rew = 22, cum_rew = 305,tot_cl = 17 , tot = 250
# epis[7390],eps[0.100000],durat[416],fnum=1318869, cum_cl_rew = 28, cum_rew = 415,tot_cl = 17 , tot = 259
# epis[7400],eps[0.100000],durat[218],fnum=1321163, cum_cl_rew = 17, cum_rew = 205,tot_cl = 18 , tot = 278
# epis[7410],eps[0.100000],durat[297],fnum=1323660, cum_cl_rew = 22, cum_rew = 305,tot_cl = 18 , tot = 277
# epis[7420],eps[0.100000],durat[317],fnum=1326177, cum_cl_rew = 21, cum_rew = 325,tot_cl = 18 , tot = 289
# epis[7430],eps[0.100000],durat[261],fnum=1328541, cum_cl_rew = 19, cum_rew = 280,tot_cl = 18 , tot = 297
# epis[7440],eps[0.100000],durat[250],fnum=1330888, cum_cl_rew = 21, cum_rew = 320,tot_cl = 18 , tot = 293
# epis[7450],eps[0.100000],durat[142],fnum=1333658, cum_cl_rew = 14, cum_rew = 175,tot_cl = 19 , tot = 306
# epis[7460],eps[0.100000],durat[129],fnum=1336268, cum_cl_rew = 11, cum_rew = 155,tot_cl = 19 , tot = 304
# epis[7470],eps[0.100000],durat[333],fnum=1338830, cum_cl_rew = 24, cum_rew = 535,tot_cl = 19 , tot = 302
# epis[7480],eps[0.100000],durat[268],fnum=1341247, cum_cl_rew = 21, cum_rew = 485,tot_cl = 19 , tot = 296
# epis[7490],eps[0.100000],durat[313],fnum=1343895, cum_cl_rew = 22, cum_rew = 350,tot_cl = 18 , tot = 292
# epis[7500],eps[0.100000],durat[197],fnum=1346342, cum_cl_rew = 11, cum_rew = 95,tot_cl = 17 , tot = 265
# epis[7510],eps[0.100000],durat[203],fnum=1348457, cum_cl_rew = 19, cum_rew = 235,tot_cl = 17 , tot = 258
# epis[7520],eps[0.100000],durat[186],fnum=1350827, cum_cl_rew = 16, cum_rew = 160,tot_cl = 17 , tot = 268
# epis[7530],eps[0.100000],durat[238],fnum=1353430, cum_cl_rew = 21, cum_rew = 300,tot_cl = 17 , tot = 283
# epis[7540],eps[0.100000],durat[310],fnum=1355941, cum_cl_rew = 22, cum_rew = 300,tot_cl = 17 , tot = 284
# epis[7550],eps[0.100000],durat[310],fnum=1357982, cum_cl_rew = 23, cum_rew = 330,tot_cl = 17 , tot = 277
# epis[7560],eps[0.100000],durat[367],fnum=1360445, cum_cl_rew = 27, cum_rew = 380,tot_cl = 17 , tot = 283
# epis[7570],eps[0.100000],durat[328],fnum=1363024, cum_cl_rew = 23, cum_rew = 320,tot_cl = 17 , tot = 281
# epis[7580],eps[0.100000],durat[193],fnum=1365177, cum_cl_rew = 20, cum_rew = 310,tot_cl = 17 , tot = 274
# epis[7590],eps[0.100000],durat[177],fnum=1367825, cum_cl_rew = 19, cum_rew = 275,tot_cl = 18 , tot = 289
# epis[7600],eps[0.100000],durat[278],fnum=1370138, cum_cl_rew = 22, cum_rew = 320,tot_cl = 18 , tot = 306
# epis[7610],eps[0.100000],durat[166],fnum=1372457, cum_cl_rew = 17, cum_rew = 195,tot_cl = 18 , tot = 305
# epis[7620],eps[0.100000],durat[218],fnum=1374765, cum_cl_rew = 19, cum_rew = 240,tot_cl = 18 , tot = 299
# epis[7630],eps[0.100000],durat[180],fnum=1377379, cum_cl_rew = 16, cum_rew = 225,tot_cl = 19 , tot = 305
# epis[7640],eps[0.100000],durat[173],fnum=1379543, cum_cl_rew = 18, cum_rew = 235,tot_cl = 18 , tot = 283
# epis[7650],eps[0.100000],durat[256],fnum=1381907, cum_cl_rew = 25, cum_rew = 385,tot_cl = 18 , tot = 264
# epis[7660],eps[0.100000],durat[255],fnum=1384514, cum_cl_rew = 17, cum_rew = 210,tot_cl = 19 , tot = 288
# epis[7670],eps[0.100000],durat[269],fnum=1387181, cum_cl_rew = 20, cum_rew = 285,tot_cl = 18 , tot = 300
# epis[7680],eps[0.100000],durat[382],fnum=1389691, cum_cl_rew = 29, cum_rew = 640,tot_cl = 18 , tot = 301
# epis[7690],eps[0.100000],durat[263],fnum=1391954, cum_cl_rew = 25, cum_rew = 365,tot_cl = 18 , tot = 314
# epis[7700],eps[0.100000],durat[278],fnum=1394356, cum_cl_rew = 27, cum_rew = 420,tot_cl = 19 , tot = 330
# epis[7710],eps[0.100000],durat[187],fnum=1396713, cum_cl_rew = 15, cum_rew = 165,tot_cl = 19 , tot = 313
# epis[7720],eps[0.100000],durat[484],fnum=1399246, cum_cl_rew = 31, cum_rew = 500,tot_cl = 18 , tot = 295
# epis[7730],eps[0.100000],durat[180],fnum=1401574, cum_cl_rew = 17, cum_rew = 205,tot_cl = 19 , tot = 292
# epis[7740],eps[0.100000],durat[227],fnum=1403772, cum_cl_rew = 15, cum_rew = 160,tot_cl = 19 , tot = 284
# epis[7750],eps[0.100000],durat[250],fnum=1406401, cum_cl_rew = 14, cum_rew = 180,tot_cl = 19 , tot = 287
# epis[7760],eps[0.100000],durat[306],fnum=1408965, cum_cl_rew = 15, cum_rew = 225,tot_cl = 18 , tot = 284
# epis[7770],eps[0.100000],durat[407],fnum=1411534, cum_cl_rew = 29, cum_rew = 445,tot_cl = 18 , tot = 291
# epis[7780],eps[0.100000],durat[376],fnum=1414293, cum_cl_rew = 34, cum_rew = 585,tot_cl = 18 , tot = 307
# epis[7790],eps[0.100000],durat[357],fnum=1416878, cum_cl_rew = 27, cum_rew = 415,tot_cl = 19 , tot = 321
# epis[7800],eps[0.100000],durat[247],fnum=1419558, cum_cl_rew = 14, cum_rew = 420,tot_cl = 19 , tot = 335
# epis[7810],eps[0.100000],durat[197],fnum=1421961, cum_cl_rew = 24, cum_rew = 530,tot_cl = 19 , tot = 342
# epis[7820],eps[0.100000],durat[169],fnum=1424578, cum_cl_rew = 13, cum_rew = 130,tot_cl = 20 , tot = 368
# epis[7830],eps[0.100000],durat[156],fnum=1427066, cum_cl_rew = 14, cum_rew = 170,tot_cl = 20 , tot = 358
# epis[7840],eps[0.100000],durat[178],fnum=1430055, cum_cl_rew = 14, cum_rew = 130,tot_cl = 20 , tot = 364
# epis[7850],eps[0.100000],durat[239],fnum=1432906, cum_cl_rew = 23, cum_rew = 350,tot_cl = 20 , tot = 375
# epis[7860],eps[0.100000],durat[212],fnum=1435416, cum_cl_rew = 17, cum_rew = 230,tot_cl = 21 , tot = 375
# epis[7870],eps[0.100000],durat[280],fnum=1437963, cum_cl_rew = 19, cum_rew = 295,tot_cl = 20 , tot = 346
# epis[7880],eps[0.100000],durat[280],fnum=1440675, cum_cl_rew = 21, cum_rew = 290,tot_cl = 20 , tot = 337
# epis[7890],eps[0.100000],durat[224],fnum=1443197, cum_cl_rew = 16, cum_rew = 205,tot_cl = 20 , tot = 338
# epis[7900],eps[0.100000],durat[258],fnum=1445417, cum_cl_rew = 20, cum_rew = 300,tot_cl = 19 , tot = 303
# epis[7910],eps[0.100000],durat[268],fnum=1448022, cum_cl_rew = 22, cum_rew = 290,tot_cl = 19 , tot = 313

# %% [markdown]
# ### Plot the overall performace

# %%
bandwidth = 1000 # Moving average bandwidth
total_clipped = np.zeros(int(epis_count)-bandwidth)
total_rew = np.zeros(int(epis_count)-bandwidth)
for i in range(int(epis_count)-bandwidth):
    total_clipped[i] = np.sum(tot_clipped_reward[i:i+bandwidth])/bandwidth
    total_rew[i] = np.sum(tot_reward[i:i+bandwidth])/bandwidth
t = np.arange(int(epis_count)-bandwidth)
belplt = plt.plot(t,total_rew[0:int(epis_count)-bandwidth],"r", label = "Return")
plt.legend()#handles[likplt,belplt])
print('Running after %d number of episodes' %epis_count)
plt.xlabel("Number of episode")
plt.ylabel("Average Reward per episode")
plt.show()
likplt = plt.plot(t,total_clipped[0:opt.num_episode-bandwidth],"b", label = "Clipped Return")
plt.legend()#handles[likplt,belplt])
plt.xlabel("Number of episode")
plt.ylabel("Average clipped Reward per episode")
plt.show()

# %% [markdown]
# ### Accumulated average reward after 1000 episodes of game Assault
# |![](./Assault.png)|![](./Assault-clipped.png)|
# |:---------------:|:---------------:|
# |Average reward|Average clipped reward|
